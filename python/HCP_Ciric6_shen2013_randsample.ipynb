# %% [markdown]
# This notebook runs a defined pipeline on HCP subjects, on the Cedars-Sinai cluster.
# After it is done preprocessing all subjects, it runs the leave-one-out IQ prediction a la Finn.

# %% [markdown]
# # Load libraries & helper functions

# %%
from helpers import *
# %matplotlib inline

# %% [markdown]
# # Declare parameters

# %%
config.DATADIR                 = '/scratch/duboisjx/data/HCP/MRI'
# fMRI runs
session                        = 'REST1'
fmriRuns                       = ['rfMRI_'+session+'_LR','rfMRI_'+session+'_RL']
# use volume or surface data
config.fmriFileTemplate        = '#fMRIrun#.nii.gz'
#config.fmriFileTemplate        = '#fMRIrun#_Atlas.dtseries.nii'
#config.fmriFileTemplate        = '#fMRIrun#_Atlas_MSMAll.dtseries.nii'
config.overwrite               = False
config.pipelineName            = 'Ciric6'
config.useFIX                  = False
config.preWhitening            = False
config.Operations              = config.operationDict[config.pipelineName]
config.melodicFolder           = op.join('#fMRIrun#_hp2000.ica','filtered_func_data.ica') #the code #fMRIrun# will be replaced
config.movementRelativeRMSFile = 'Movement_RelativeRMS.txt'
config.movementRegressorsFile  = 'Movement_Regressors_dt.txt'
# whether to use memmapping (which involves unzipping)
config.useMemMap               = False
# parcellation for FC matrix
config.parcellationName        = 'shen2013'
config.parcellationFile        = '/scratch/duboisjx/data/parcellations/shenetal_neuroimage2013_new/shen_2mm_268_parcellation.nii.gz'
config.nParcels                = 268
config.maskParcelswithAll      = True
config.maskParcelswithGM       = False
# subject selection parameters
config.behavFile               = '/scratch/duboisjx/data/HCP/neuropsych/unrestricted_luckydjuju_6_7_2017_0_44_41.csv'
config.release                 = 'all'
config.outScore                = 'PMAT24_A_CR'


# do not alter the following lines
if config.maskParcelswithGM:
    config.parcellationName = config.parcellationName + '_GM'
tmp = config.fmriFileTemplate.split('.')
if tmp[1]=='nii':
    config.isCifti = False
elif tmp[1]=='dtseries':
    config.isCifti = True
else:
    print 'unknown file extension'

# %% [markdown]
# # Subject selection

# %%
df = pd.read_csv(config.behavFile)
# select subjects according to release
if config.release == 'Q2':
    ind = (df['Release'] == 'Q2') | (df['Release'] == 'Q1')
elif config.release == 'S500':
    ind = (df['Release'] == 'Q3') | (df['Release'] == 'S500')
elif config.release == 'Q2+S500':
    ind = (df['Release'] == 'Q2') | (df['Release'] == 'Q1') | (df['Release'] == 'Q3') | (df['Release'] == 'S500')
elif config.release == 'S900':
    ind = (df['Release'] == 'S900')
elif config.release == 'S1200':
    ind = (df['Release'] == 'S1200')
elif config.release == 'all':
    ind = ((df['Release'] == 'Q1') | (df['Release'] == 'Q2') | (df['Release'] == 'Q3') 
           | (df['Release'] == 'S500') | (df['Release'] == 'S900') | (df['Release'] == 'S1200'))
else:
    sys.exit("Invalid release code")
# select subjects that have completed all fMRI
ind = ind & ((df['fMRI_WM_PctCompl']==100) & (df['fMRI_Mot_PctCompl']==100) 
             & (df['fMRI_Lang_PctCompl']==100) & (df['fMRI_Emo_PctCompl']==100)         
             & (df['3T_RS-fMRI_PctCompl']==100) & (df['PMAT_Compl']==True))
df = df[ind]  
# check if either of the two subjects recommended for exclusion by HCP are still present
df = df[~df['Subject'].isin(['209733','528446'])]
df.index = range(df.shape[0])
tmpAgeRanges = sorted(df['Age'].unique())
# list of all selected subjects
subjects = df['Subject']
# pull their IQ, Age, Gender
age = df['Age']
gender = df['Gender']
score = df[config.outScore]

print 'Selected', str(df.shape[0]), 'from the release',config.release
print 'Number of males is:', df[df['Gender']=='M'].shape[0]
try:
    print 'Age range is', tmpAgeRanges[0].split('-')[0], '-', tmpAgeRanges[-1].split('-')[1]
except:
    print 'Age range is', tmpAgeRanges[0].split('-')[0], '-', tmpAgeRanges[-1]
# Exclusion of high-motion subjects
# exclude subjects with >0.14 frame-to-frame head motion estimate averged across both rest runs (arbitrary threshold as in Finn et al 2015)
subjects   = [str(subject) for subject in subjects]
RelRMSMean = np.zeros([len(subjects), len(fmriRuns)],dtype=np.float32)
compSub    = np.zeros((len(subjects)),dtype=np.bool_)
keepSub    = np.zeros((len(subjects)),dtype=np.bool_)
iSub=0
for config.subject in subjects:
    i=0
    for config.fmriRun in fmriRuns:
        RelRMSMeanFile = op.join(buildpath(), 'Movement_RelativeRMS_mean.txt')
        #print RelRMSMeanFile
        if op.isfile(RelRMSMeanFile):
            with open(RelRMSMeanFile,'r') as tmp:
                RelRMSMean[iSub,i] = float(tmp.read())
        else:
            print RelRMSMeanFile+' File missing'
            break
        i=i+1
    if i==len(fmriRuns): # all RelRMSMeanFile exist
        compSub[iSub]=True
        if np.mean(RelRMSMean[iSub,:]) > 0.14:
            print config.subject, ': too much motion, exclude'
        else:
            keepSub[iSub]=True
    iSub=iSub+1

#### motion vs. score correlation
plt.scatter(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1),c='r')
plt.scatter(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1),c='b')
# fit a curve to the data using a least squares 1st order polynomial fit
z1 = np.polyfit(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1),1)
z2 = np.polyfit(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1),1)
p1 = np.poly1d(z1)
p2 = np.poly1d(z2)                
fit1 = p1(score[keepSub])
fit2 = p2(score[compSub])
# get the coordinates for the fit curve
c1_x = [np.min(score[keepSub]),np.max(score[keepSub])]
c1_y = p1(c1_x)
c2_x = [np.min(score[compSub]),np.max(score[compSub])]
c2_y = p2(c2_x)
# plot line of best fit
plt.plot(c2_x,c2_y,'r-',label='before exclusion')
plt.plot(c1_x,c1_y,'b-',label='after exclusion')
plt.xlabel('Score [{}]'.format(config.outScore))
plt.ylabel('RelRMSMean')
plt.legend(loc=0)
plt.show()
rho1,p1 = stats.pearsonr(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1))
rho2,p2 = stats.pearsonr(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1))            
print 'With all subjects: corr(IQ,motion) = {:.3f} (p = {:.3f})'.format(rho2,p2)
print 'After discarding high movers: corr(IQ,motion) = {:.3f} (p = {:.3f})'.format(rho1,p1)
    
subjects   = [subject for (subject, keep) in zip(subjects, keepSub) if keep]
age        = age[keepSub]
gender     = gender[keepSub]
score      = score[keepSub]
RelRMSMean = RelRMSMean[keepSub,:]
print 'Keeping {} subjects [{} M]'.format(len(subjects),sum([g=='M' for g in gender]))
# Out:
# Selected 957 from the release all
# Number of males is: 452
# Age range is 22 - Age range is 22 - 36+
# 104820 : too much motion, exclude
# 108121 : too much motion, exclude
# 114924 : too much motion, exclude
# 123117 : too much motion, exclude
# 124220 : too much motion, exclude
# 136732 : too much motion, exclude
# 140824 : too much motion, exclude
# 140925 : too much motion, exclude
# 147030 : too much motion, exclude
# 151223 : too much motion, exclude
# 151324 : too much motion, exclude
# 151526 : too much motion, exclude
# 151728 : too much motion, exclude
# 153833 : too much motion, exclude
# 156637 : too much motion, exclude
# 159138 : too much motion, exclude
# 161327 : too much motion, exclude
# 161832 : too much motion, exclude
# 163331 : too much motion, exclude
# 163836 : too much motion, exclude
# 166640 : too much motion, exclude
# /scratch/duboisjx/data/HCP/MRI/169040/MNINonLinear/Results/rfMRI_REST1_LR/Movement_RelativeRMS_mean.txt File missing
# 171532 : too much motion, exclude
# 176239 : too much motion, exclude
# 180129 : too much motion, exclude
# 181636 : too much motion, exclude
# 191437 : too much motion, exclude
# 197348 : too much motion, exclude
# 198249 : too much motion, exclude
# 199150 : too much motion, exclude
# 205220 : too much motion, exclude
# 207123 : too much motion, exclude
# 207426 : too much motion, exclude
# 209834 : too much motion, exclude
# 212217 : too much motion, exclude
# 223929 : too much motion, exclude
# 233326 : too much motion, exclude
# 250427 : too much motion, exclude
# 295146 : too much motion, exclude
# 298051 : too much motion, exclude
# 311320 : too much motion, exclude
# 346137 : too much motion, exclude
# 352132 : too much motion, exclude
# 366446 : too much motion, exclude
# 378756 : too much motion, exclude
# 382242 : too much motion, exclude
# 392447 : too much motion, exclude
# 397861 : too much motion, exclude
# 453542 : too much motion, exclude
# 465852 : too much motion, exclude
# 468050 : too much motion, exclude
# 555348 : too much motion, exclude
# 562345 : too much motion, exclude
# 576255 : too much motion, exclude
# 609143 : too much motion, exclude
# 633847 : too much motion, exclude
# 680250 : too much motion, exclude
# 686969 : too much motion, exclude
# 698168 : too much motion, exclude
# 748662 : too much motion, exclude
# 779370 : too much motion, exclude
# 788876 : too much motion, exclude
# 833249 : too much motion, exclude
# 837964 : too much motion, exclude
# 901038 : too much motion, exclude
# 919966 : too much motion, exclude
# 922854 : too much motion, exclude
# 937160 : too much motion, exclude
# 947668 : too much motion, exclude
# With all subjects: corr(IQ,motion) = -0.147 (p = 0.000)
# After discarding high movers: corr(IQ,motion) = -0.134 (p = 0.000)
# Keeping 888 subjects [420 M]

# %% [markdown]
# # Do work

# %% [markdown]
# ### preprocess everybody

# %%
# submit jobs with sge
config.queue        = True
config.sgeopts      = '-l mem_free=25G -pe smp 6' 

keepSub = np.zeros((len(subjects)),dtype=np.bool_)
iSub=0
for config.subject in subjects:
    iRun = 0
    for config.fmriRun in fmriRuns:
        keepSub[iSub] = runPipelinePar(launchSubproc=False)
        if not keepSub[iSub]:
            break
        iRun=iRun+1
    iSub = iSub + 1
print 'Keeping {}/{} subjects'.format(np.sum(keepSub),len(subjects))

subjects = [subject for (iSub,subject) in enumerate(subjects) if keepSub[iSub]]
checkProgress()
# Out:
# submitted s100206_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513549)
# submitted s100206_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513550)
# submitted s100408_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513551)
# submitted s100408_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513552)
# submitted s100610_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513553)
# submitted s100610_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513554)
# submitted s101006_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513555)
# submitted s101006_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513556)
# submitted s101107_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513557)
# submitted s101107_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513558)
# submitted s101309_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513559)
# submitted s101309_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513560)
# submitted s101915_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513561)
# submitted s101915_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513562)
# submitted s102008_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513563)
# submitted s102008_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513564)
# submitted s102109_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513565)
# submitted s102109_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513566)
# submitted s102311_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513567)
# submitted s102311_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513568)
# submitted s102513_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513569)
# submitted s102513_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513570)
# submitted s102614_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513571)
# submitted s102614_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513572)
# submitted s102715_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513573)
# submitted s102715_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513574)
# submitted s102816_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513575)
# submitted s102816_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513576)
# submitted s103111_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513577)
# submitted s103111_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513578)
# submitted s103212_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513579)
# submitted s103212_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513580)
# submitted s104416_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513581)
# submitted s104416_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513582)
# submitted s105014_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513583)
# submitted s105014_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513584)
# submitted s105216_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513585)
# submitted s105216_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513586)
# submitted s105620_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513587)
# submitted s105620_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513588)
# submitted s106016_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513589)
# submitted s106016_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513590)
# submitted s106319_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513591)
# submitted s106319_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513592)
# submitted s106521_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513593)
# submitted s106521_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513594)
# submitted s106824_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513595)
# submitted s106824_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513596)
# submitted s107018_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513597)
# submitted s107018_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513598)
# submitted s107321_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513599)
# submitted s107321_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513600)
# submitted s107422_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513601)
# submitted s107422_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513602)
# submitted s107725_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513603)
# submitted s107725_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513604)
# submitted s108020_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513605)
# submitted s108020_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513606)
# submitted s108222_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513607)
# submitted s108222_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513608)
# submitted s108323_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513609)
# submitted s108323_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513610)
# submitted s108525_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513611)
# submitted s108525_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513612)
# submitted s108828_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513613)
# submitted s108828_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513614)
# submitted s109123_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513615)
# submitted s109123_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513616)
# submitted s109325_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513617)
# submitted s109325_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513618)
# submitted s110007_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513619)
# submitted s110007_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513620)
# submitted s110613_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513621)
# submitted s110613_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513622)
# submitted s111009_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513623)
# submitted s111009_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513624)
# submitted s111211_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513625)
# submitted s111211_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513626)
# submitted s111413_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513627)
# submitted s111413_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513628)
# submitted s111716_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513629)
# submitted s111716_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513630)
# submitted s112112_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513631)
# submitted s112112_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513632)
# submitted s112314_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513633)
# submitted s112314_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513634)
# submitted s112516_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513635)
# submitted s112516_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513636)
# submitted s112920_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513637)
# submitted s112920_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513638)
# submitted s113215_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513639)
# submitted s113215_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513640)
# submitted s113316_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513641)
# submitted s113316_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513642)
# submitted s113922_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513643)
# submitted s113922_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513644)
# submitted s114217_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513645)
# submitted s114217_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513646)
# submitted s114318_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513647)
# submitted s114318_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513648)
# submitted s114419_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513649)
# submitted s114419_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513650)
# submitted s114621_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513651)
# submitted s114621_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513652)
# submitted s114823_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513653)
# submitted s114823_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513654)
# submitted s115017_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513655)
# submitted s115017_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513656)
# submitted s115219_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513657)
# submitted s115219_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513658)
# submitted s115724_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513659)
# submitted s115724_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513660)
# submitted s115825_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513661)
# submitted s115825_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513662)
# submitted s116524_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513663)
# submitted s116524_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513664)
# submitted s116726_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513665)
# submitted s116726_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513666)
# submitted s117021_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513667)
# submitted s117021_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513668)
# submitted s117324_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513669)
# submitted s117324_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513670)
# submitted s117930_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513671)
# submitted s117930_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513672)
# submitted s118023_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513673)
# submitted s118023_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513674)
# submitted s118124_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513675)
# submitted s118124_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513676)
# submitted s118225_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513677)
# submitted s118225_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513678)
# submitted s118528_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513679)
# submitted s118528_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513680)
# submitted s118831_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513681)
# submitted s118831_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513682)
# submitted s119025_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513683)
# submitted s119025_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513684)
# submitted s119126_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513685)
# submitted s119126_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513686)
# submitted s120111_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513687)
# submitted s120111_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513688)
# submitted s120414_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513689)
# submitted s120414_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513690)
# submitted s120515_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513691)
# submitted s120515_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513692)
# submitted s120717_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513693)
# submitted s120717_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513694)
# submitted s121416_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513695)
# submitted s121416_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513696)
# submitted s121618_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513697)
# submitted s121618_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513698)
# submitted s121921_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513699)
# submitted s121921_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513700)
# submitted s122317_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513701)
# submitted s122317_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513702)
# submitted s122620_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513703)
# submitted s122620_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513704)
# submitted s122822_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513705)
# submitted s122822_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513706)
# submitted s123420_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513707)
# submitted s123420_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513708)
# submitted s123521_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513709)
# submitted s123521_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513710)
# submitted s123723_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513711)
# submitted s123723_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513712)
# submitted s123824_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513713)
# submitted s123824_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513714)
# submitted s123925_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513715)
# submitted s123925_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513716)
# submitted s124624_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513717)
# submitted s124624_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513718)
# submitted s124826_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513719)
# submitted s124826_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513720)
# submitted s125222_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513721)
# submitted s125222_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513722)
# submitted s125424_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513723)
# submitted s125424_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513724)
# submitted s126325_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513725)
# submitted s126325_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513726)
# submitted s126426_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513727)
# submitted s126426_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513728)
# submitted s126628_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513729)
# submitted s126628_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513730)
# submitted s127226_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513731)
# submitted s127226_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513732)
# submitted s127327_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513733)
# submitted s127327_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513734)
# submitted s127630_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513735)
# submitted s127630_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513736)
# submitted s127832_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513737)
# submitted s127832_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513738)
# submitted s127933_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513739)
# submitted s127933_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513740)
# submitted s128026_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513741)
# submitted s128026_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513742)
# submitted s128127_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513743)
# submitted s128127_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513744)
# submitted s128935_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513745)
# submitted s128935_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513746)
# submitted s129129_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513747)
# submitted s129129_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513748)
# submitted s129331_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513749)
# submitted s129331_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513750)
# submitted s129634_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513751)
# submitted s129634_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513752)
# submitted s130114_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513753)
# submitted s130114_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513754)
# submitted s130316_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513755)
# submitted s130316_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513756)
# submitted s130417_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513757)
# submitted s130417_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513758)
# submitted s130518_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513759)
# submitted s130518_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513760)
# submitted s130619_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513761)
# submitted s130619_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513762)
# submitted s130720_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513763)
# submitted s130720_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513764)
# submitted s130821_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513765)
# submitted s130821_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513766)
# submitted s130922_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513767)
# submitted s130922_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513768)
# submitted s131217_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513769)
# submitted s131217_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513770)
# submitted s131419_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513771)
# submitted s131419_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513772)
# submitted s131722_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513773)
# submitted s131722_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513774)
# submitted s131823_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513775)
# submitted s131823_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513776)
# submitted s131924_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513777)
# submitted s131924_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513778)
# submitted s132017_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513779)
# submitted s132017_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513780)
# submitted s133019_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513781)
# submitted s133019_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513782)
# submitted s133625_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513783)
# submitted s133625_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513784)
# submitted s134021_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513785)
# submitted s134021_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513786)
# submitted s134223_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513787)
# submitted s134223_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513788)
# submitted s134425_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513789)
# submitted s134425_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513790)
# submitted s134728_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513791)
# submitted s134728_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513792)
# submitted s134829_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513793)
# submitted s134829_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513794)
# submitted s135124_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513795)
# submitted s135124_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513796)
# submitted s135225_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513797)
# submitted s135225_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513798)
# submitted s135528_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513799)
# submitted s135528_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513800)
# submitted s135629_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513801)
# submitted s135629_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513802)
# submitted s135730_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513803)
# submitted s135730_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513804)
# submitted s136227_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513805)
# submitted s136227_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513806)
# submitted s136631_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513807)
# submitted s136631_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513808)
# submitted s137027_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513809)
# submitted s137027_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513810)
# submitted s137229_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513811)
# submitted s137229_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513812)
# submitted s137532_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513813)
# submitted s137532_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513814)
# submitted s137633_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513815)
# submitted s137633_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513816)
# submitted s137936_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513817)
# submitted s137936_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513818)
# submitted s138130_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513819)
# submitted s138130_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513820)
# submitted s138332_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513821)
# submitted s138332_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513822)
# submitted s138534_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513823)
# submitted s138534_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513824)
# submitted s138837_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513825)
# submitted s138837_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513826)
# submitted s139233_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513827)
# submitted s139233_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513828)
# submitted s139435_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513829)
# submitted s139435_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513830)
# submitted s139839_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513831)
# submitted s139839_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513832)
# submitted s140117_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513833)
# submitted s140117_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513834)
# submitted s140319_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513835)
# submitted s140319_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513836)
# submitted s141119_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513837)
# submitted s141119_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513838)
# submitted s141422_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513839)
# submitted s141422_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513840)
# submitted s141826_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513841)
# submitted s141826_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513842)
# submitted s143224_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513843)
# submitted s143224_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513844)
# submitted s143426_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513845)
# submitted s143426_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513846)
# submitted s143830_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513847)
# submitted s143830_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513848)
# submitted s144125_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513849)
# submitted s144125_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513850)
# submitted s144428_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513851)
# submitted s144428_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513852)
# submitted s144731_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513853)
# submitted s144731_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513854)
# submitted s144832_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513855)
# submitted s144832_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513856)
# submitted s144933_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513857)
# submitted s144933_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513858)
# submitted s145127_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513859)
# submitted s145127_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513860)
# submitted s145632_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513861)
# submitted s145632_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513862)
# submitted s145834_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513863)
# submitted s145834_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513864)
# submitted s146331_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513865)
# submitted s146331_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513866)
# submitted s146432_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513867)
# submitted s146432_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513868)
# submitted s146533_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513869)
# submitted s146533_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513870)
# submitted s146735_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513871)
# submitted s146735_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513872)
# submitted s146836_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513873)
# submitted s146836_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513874)
# submitted s146937_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513875)
# submitted s146937_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513876)
# submitted s147636_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513877)
# submitted s147636_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513878)
# submitted s147737_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513879)
# submitted s147737_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513880)
# submitted s148032_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513881)
# submitted s148032_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513882)
# submitted s148133_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513883)
# submitted s148133_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513884)
# submitted s148335_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513885)
# submitted s148335_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513886)
# submitted s148436_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513887)
# submitted s148436_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513888)
# submitted s148840_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513889)
# submitted s148840_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513890)
# submitted s148941_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513891)
# submitted s148941_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513892)
# submitted s149236_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513893)
# submitted s149236_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513894)
# submitted s149741_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513895)
# submitted s149741_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513896)
# submitted s149842_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513897)
# submitted s149842_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513898)
# submitted s150625_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513899)
# submitted s150625_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513900)
# submitted s150726_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513901)
# submitted s150726_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513902)
# submitted s150928_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513903)
# submitted s150928_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513904)
# submitted s151425_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513905)
# submitted s151425_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513906)
# submitted s151829_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513907)
# submitted s151829_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513908)
# submitted s151930_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513909)
# submitted s151930_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513910)
# submitted s152225_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513911)
# submitted s152225_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513912)
# submitted s152427_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513913)
# submitted s152427_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513914)
# submitted s152831_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513915)
# submitted s152831_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513916)
# submitted s153025_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513917)
# submitted s153025_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513918)
# submitted s153126_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513919)
# submitted s153126_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513920)
# submitted s153227_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513921)
# submitted s153227_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513922)
# submitted s153631_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513923)
# submitted s153631_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513924)
# submitted s153934_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513925)
# submitted s153934_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513926)
# submitted s154229_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513927)
# submitted s154229_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513928)
# submitted s154330_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513929)
# submitted s154330_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513930)
# submitted s154431_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513931)
# submitted s154431_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513932)
# submitted s154532_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513933)
# submitted s154532_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513934)
# submitted s154734_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513935)
# submitted s154734_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513936)
# submitted s154835_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513937)
# submitted s154835_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513938)
# submitted s154936_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513939)
# submitted s154936_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513940)
# submitted s155635_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513941)
# submitted s155635_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513942)
# submitted s155938_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513943)
# submitted s155938_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513944)
# submitted s156031_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513945)
# submitted s156031_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513946)
# submitted s156233_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513947)
# submitted s156233_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513948)
# submitted s156435_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513949)
# submitted s156435_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513950)
# submitted s156536_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513951)
# submitted s156536_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513952)
# submitted s157437_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513953)
# submitted s157437_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513954)
# submitted s157942_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513955)
# submitted s157942_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513956)
# submitted s158136_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513957)
# submitted s158136_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513958)
# submitted s158338_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513959)
# submitted s158338_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513960)
# submitted s158843_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513961)
# submitted s158843_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513962)
# submitted s159340_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513963)
# submitted s159340_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513964)
# submitted s159441_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513965)
# submitted s159441_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513966)
# submitted s159744_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513967)
# submitted s159744_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513968)
# submitted s160123_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513969)
# submitted s160123_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513970)
# submitted s160729_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513971)
# submitted s160729_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513972)
# submitted s160830_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513973)
# submitted s160830_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513974)
# submitted s161630_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513975)
# submitted s161630_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513976)
# submitted s162026_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513977)
# submitted s162026_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513978)
# submitted s162228_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513979)
# submitted s162228_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513980)
# submitted s162733_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513981)
# submitted s162733_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513982)
# submitted s162935_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513983)
# submitted s162935_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513984)
# submitted s163129_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513985)
# submitted s163129_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513986)
# submitted s164030_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513987)
# submitted s164030_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513988)
# submitted s164131_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513989)
# submitted s164131_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513990)
# submitted s164636_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513991)
# submitted s164636_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513992)
# submitted s164939_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513993)
# submitted s164939_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513994)
# submitted s165436_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513995)
# submitted s165436_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513996)
# submitted s165638_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513997)
# submitted s165638_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #513998)
# submitted s165941_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #513999)
# submitted s165941_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514000)
# submitted s166438_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514001)
# submitted s166438_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514002)
# submitted s167036_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514003)
# submitted s167036_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514004)
# submitted s167238_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514005)
# submitted s167238_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514006)
# submitted s167440_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514007)
# submitted s167440_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514008)
# submitted s168139_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514009)
# submitted s168139_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514010)
# submitted s168240_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514011)
# submitted s168240_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514012)
# submitted s168341_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514013)
# submitted s168341_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514014)
# submitted s168745_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514015)
# submitted s168745_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514016)
# submitted s168947_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514017)
# submitted s168947_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514018)
# submitted s169444_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514019)
# submitted s169444_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514020)
# submitted s169545_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514021)
# submitted s169545_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514022)
# submitted s169949_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514023)
# submitted s169949_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514024)
# submitted s170631_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514025)
# submitted s170631_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514026)
# submitted s171330_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514027)
# submitted s171330_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514028)
# submitted s171633_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514029)
# submitted s171633_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514030)
# submitted s172029_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514031)
# submitted s172029_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514032)
# submitted s172130_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514033)
# submitted s172130_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514034)
# submitted s172433_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514035)
# submitted s172433_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514036)
# submitted s172534_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514037)
# submitted s172534_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514038)
# submitted s172938_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514039)
# submitted s172938_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514040)
# submitted s173334_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514041)
# submitted s173334_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514042)
# submitted s173435_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514043)
# submitted s173435_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514044)
# submitted s173536_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514045)
# submitted s173536_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514046)
# submitted s173637_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514047)
# submitted s173637_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514048)
# submitted s173738_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514049)
# submitted s173738_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514050)
# submitted s173839_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514051)
# submitted s173839_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514052)
# submitted s173940_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514053)
# submitted s173940_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514054)
# submitted s174437_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514055)
# submitted s174437_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514056)
# submitted s174841_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514057)
# submitted s174841_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514058)
# submitted s175035_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514059)
# submitted s175035_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514060)
# submitted s175136_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514061)
# submitted s175136_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514062)
# submitted s175237_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514063)
# submitted s175237_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514064)
# submitted s175338_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514065)
# submitted s175338_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514066)
# submitted s175742_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514067)
# submitted s175742_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514068)
# submitted s176037_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514069)
# submitted s176037_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514070)
# submitted s176441_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514071)
# submitted s176441_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514072)
# submitted s176542_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514073)
# submitted s176542_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514074)
# submitted s176845_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514075)
# submitted s176845_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514076)
# submitted s177140_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514077)
# submitted s177140_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514078)
# submitted s177241_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514079)
# submitted s177241_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514080)
# submitted s177645_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514081)
# submitted s177645_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514082)
# submitted s178142_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514083)
# submitted s178142_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514084)
# submitted s178243_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514085)
# submitted s178243_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514086)
# submitted s178647_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514087)
# submitted s178647_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514088)
# submitted s178748_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514089)
# submitted s178748_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514090)
# submitted s178849_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514091)
# submitted s178849_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514092)
# submitted s178950_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514093)
# submitted s178950_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514094)
# submitted s179245_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514095)
# submitted s179245_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514096)
# submitted s179346_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514097)
# submitted s179346_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514098)
# submitted s180230_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514099)
# submitted s180230_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514100)
# submitted s180432_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514101)
# submitted s180432_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514102)
# submitted s180533_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514103)
# submitted s180533_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514104)
# submitted s180735_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514105)
# submitted s180735_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514106)
# submitted s180836_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514107)
# submitted s180836_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514108)
# submitted s180937_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514109)
# submitted s180937_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514110)
# submitted s181131_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514111)
# submitted s181131_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514112)
# submitted s181232_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514113)
# submitted s181232_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514114)
# submitted s182032_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514115)
# submitted s182032_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514116)
# submitted s182436_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514117)
# submitted s182436_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514118)
# submitted s183034_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514119)
# submitted s183034_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514120)
# submitted s185038_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514121)
# submitted s185038_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514122)
# submitted s185341_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514123)
# submitted s185341_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514124)
# submitted s185442_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514125)
# submitted s185442_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514126)
# submitted s185947_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514127)
# submitted s185947_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514128)
# submitted s186040_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514129)
# submitted s186040_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514130)
# submitted s186141_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514131)
# submitted s186141_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514132)
# submitted s186444_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514133)
# submitted s186444_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514134)
# submitted s186545_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514135)
# submitted s186545_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514136)
# submitted s186848_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514137)
# submitted s186848_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514138)
# submitted s187143_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514139)
# submitted s187143_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514140)
# submitted s187345_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514141)
# submitted s187345_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514142)
# submitted s187547_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514143)
# submitted s187547_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514144)
# submitted s187850_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514145)
# submitted s187850_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514146)
# submitted s188145_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514147)
# submitted s188145_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514148)
# submitted s188347_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514149)
# submitted s188347_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514150)
# submitted s188448_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514151)
# submitted s188448_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514152)
# submitted s188549_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514153)
# submitted s188549_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514154)
# submitted s188751_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514155)
# submitted s188751_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514156)
# submitted s189349_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514157)
# submitted s189349_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514158)
# submitted s189450_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514159)
# submitted s189450_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514160)
# submitted s189652_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514161)
# submitted s189652_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514162)
# submitted s190031_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514163)
# submitted s190031_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514164)
# submitted s191033_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514165)
# submitted s191033_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514166)
# submitted s191235_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514167)
# submitted s191235_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514168)
# submitted s191336_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514169)
# submitted s191336_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514170)
# submitted s191841_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514171)
# submitted s191841_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514172)
# submitted s191942_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514173)
# submitted s191942_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514174)
# submitted s192035_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514175)
# submitted s192035_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514176)
# submitted s192136_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514177)
# submitted s192136_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514178)
# submitted s192237_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514179)
# submitted s192237_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514180)
# submitted s192843_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514181)
# submitted s192843_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514182)
# submitted s193845_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514183)
# submitted s193845_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514184)
# submitted s194443_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514185)
# submitted s194443_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514186)
# submitted s194645_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514187)
# submitted s194645_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514188)
# submitted s194746_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514189)
# submitted s194746_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514190)
# submitted s194847_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514191)
# submitted s194847_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514192)
# submitted s195041_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514193)
# submitted s195041_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514194)
# submitted s195445_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514195)
# submitted s195445_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514196)
# submitted s195849_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514197)
# submitted s195849_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514198)
# submitted s195950_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514199)
# submitted s195950_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514200)
# submitted s196346_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514201)
# submitted s196346_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514202)
# submitted s196750_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514203)
# submitted s196750_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514204)
# submitted s198047_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514205)
# submitted s198047_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514206)
# submitted s198350_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514207)
# submitted s198350_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514208)
# submitted s198451_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514209)
# submitted s198451_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514210)
# submitted s198653_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514211)
# submitted s198653_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514212)
# submitted s198855_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514213)
# submitted s198855_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514214)
# submitted s199352_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514215)
# submitted s199352_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514216)
# submitted s199453_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514217)
# submitted s199453_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514218)
# submitted s199655_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514219)
# submitted s199655_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514220)
# submitted s199958_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514221)
# submitted s199958_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514222)
# submitted s200008_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514223)
# submitted s200008_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514224)
# submitted s200109_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514225)
# submitted s200109_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514226)
# submitted s200311_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514227)
# submitted s200311_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514228)
# submitted s200513_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514229)
# submitted s200513_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514230)
# submitted s200917_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514231)
# submitted s200917_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514232)
# submitted s201414_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514233)
# submitted s201414_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514234)
# submitted s201515_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514235)
# submitted s201515_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514236)
# submitted s201818_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514237)
# submitted s201818_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514238)
# submitted s202113_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514239)
# submitted s202113_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514240)
# submitted s202719_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514241)
# submitted s202719_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514242)
# submitted s203418_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514243)
# submitted s203418_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514244)
# submitted s203923_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514245)
# submitted s203923_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514246)
# submitted s204016_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514247)
# submitted s204016_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514248)
# submitted s204218_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514249)
# submitted s204218_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514250)
# submitted s204319_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514251)
# submitted s204319_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514252)
# submitted s204420_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514253)
# submitted s204420_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514254)
# submitted s204521_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514255)
# submitted s204521_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514256)
# submitted s204622_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514257)
# submitted s204622_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514258)
# submitted s205826_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514259)
# submitted s205826_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514260)
# submitted s206222_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514261)
# submitted s206222_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514262)
# submitted s206323_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514263)
# submitted s206323_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514264)
# submitted s206525_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514265)
# submitted s206525_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514266)
# submitted s206727_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514267)
# submitted s206727_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514268)
# submitted s206828_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514269)
# submitted s206828_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514270)
# submitted s206929_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514271)
# submitted s206929_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514272)
# submitted s208024_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514273)
# submitted s208024_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514274)
# submitted s208125_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514275)
# submitted s208125_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514276)
# submitted s208226_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514277)
# submitted s208226_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514278)
# submitted s208327_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514279)
# submitted s208327_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514280)
# submitted s209127_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514281)
# submitted s209127_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514282)
# submitted s209228_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514283)
# submitted s209228_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514284)
# submitted s209329_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514285)
# submitted s209329_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514286)
# submitted s209935_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514287)
# submitted s209935_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514288)
# submitted s210011_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514289)
# submitted s210011_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514290)
# submitted s210112_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514291)
# submitted s210112_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514292)
# submitted s210415_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514293)
# submitted s210415_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514294)
# submitted s211114_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514295)
# submitted s211114_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514296)
# submitted s211215_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514297)
# submitted s211215_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514298)
# submitted s211316_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514299)
# submitted s211316_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514300)
# submitted s211417_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514301)
# submitted s211417_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514302)
# submitted s211619_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514303)
# submitted s211619_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514304)
# submitted s211720_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514305)
# submitted s211720_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514306)
# submitted s211821_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514307)
# submitted s211821_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514308)
# submitted s211922_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514309)
# submitted s211922_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514310)
# submitted s212015_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514311)
# submitted s212015_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514312)
# submitted s212116_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514313)
# submitted s212116_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514314)
# submitted s212419_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514315)
# submitted s212419_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514316)
# submitted s212823_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514317)
# submitted s212823_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514318)
# submitted s213017_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514319)
# submitted s213017_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514320)
# submitted s213421_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514321)
# submitted s213421_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514322)
# submitted s213522_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514323)
# submitted s213522_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514324)
# submitted s214524_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514325)
# submitted s214524_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514326)
# submitted s214726_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514327)
# submitted s214726_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514328)
# submitted s217126_rfMRI_REST1_LR_Ciric6_ciftiFalse (SGE job #514329)
# submitted s217126_rfMRI_REST1_RL_Ciric6_ciftiFalse (SGE job #514330)

# %% [markdown]
# ### run prediction in 100 random samples

# %%
# Generate random sample
nSubPerSample = 115
nRep = 100
sampleFile = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}.txt'.format(nSubPerSample,nRep))
if not op.isfile(sampleFile) or config.overwrite:
    samples = np.vstack([random.sample(range(len(subjects)),nSubPerSample) for i in range(nRep)])
    np.savetxt(sampleFile, samples)
else:
    samples = np.loadtxt(sampleFile,dtype=np.int16)

# %%
config.queue        = True
config.sgeopts      = '-l mem_free=25G -pe smp 6' 
config.overwrite    = False
config.fmriFile_dn  = ''

for iSample in range(nRep):
    idx_smpl      = samples[iSample,:]
    smpl_subjects = subjects[idx_smpl]
    smpl_score    = score[idx_smpl]
    smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
    motFile = op.join(config.DATADIR,'Results','RMS_{}_samples_nsub{}_nsamp{}_{}.txt'.format(session,nSubPerSample,nRep,iSample+1))
    np.savetxt(motFile, smpl_motscore)
    fcMatFile =  op.join(config.DATADIR,'Results','fcMats_{}_{}_{}_{}_samples_nsub{}_nsamp{}_{}.mat'.format(
        session,config.pipelineName, config.parcellationName, config.release,nSubPerSample,nRep,iSample+1))
    if not op.isfile(fcMatFile) or config.overwrite:
        fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
        iSub= 0
        for config.subject in smpl_subjects:
            iRun = 0
            for config.fmriRun in fmriRuns:
                # set the global variable config
                runPipelinePar(launchSubproc=False)
                #print 'Found denoised data: {}'.format(config.fmriFile_dn)
                tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
                rstring = get_rcode(config.fmriFile_dn)
                fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
                fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
                iRun = iRun+1
            iSub = iSub + 1
        fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
        results = {}
        results['fcMats']        = fcMats_dn
        results['subjects']      = smpl_subjects
        results[config.outScore] = np.asarray(smpl_score)
        sio.savemat(fcMatFile, results)
        
    fcMats_dn = sio.loadmat(fcMatFile)['fcMats']

    # prediction!
    idcode           = session
    predict          = 'IQ'
    config.queue     = True
    launchSubproc    = False
    config.sgeopts   = '-l mem_free=2G' 
    config.overwrite = True
    
    newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
    # run the IQ prediction for each subject
    for model in ['IQ']:
        for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
            score = np.ravel(newdf[config.outScore])
            for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
                resFile = op.join(config.DATADIR,'Results','{}_{}pred_{}_{}_{}_{}_{}_samples_nsub{}_nsamp{}_{}.mat'.format(
                    model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                    config.release,nSubPerSample,nRep,iSample+1))
                if not op.isfile(resFile):
                    runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, regression=regression)
                    checkProgress(pause=10,verbose=False)
                    config.joblist = []
                    # merge cross-validation folds, save results
                    n_subs          = fcMats_dn.shape[-1]
                    predictions_pos = np.zeros([n_subs,1])
                    predictions_neg = np.zeros([n_subs,1])
                    iSub = 0
                    for subject in subjects:
                        results = sio.loadmat(op.join(config.DATADIR,'Results','{}_{}pred_{}_{}_{}_{}_{}_{}_samples_nsub{}_nsamp{}_{}.mat'.format(
                            model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                            config.release,nSubPerSample,nRep,iSample+1))) 
                        if regression=='Finn':
                            predictions_neg[iSub] = results['pred_neg']
                            predictions_pos[iSub] = results['pred_pos']
                        else:
                            predictions_pos[iSub] = results['pred']
                        iSub = iSub + 1
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(score)))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                    if regression=='Finn':
                        results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                    else:
                        results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                    if regression=='Finn':
                        if predict=='IQ':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(score)))
                        elif predict=='motion':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                        results['rho_neg'] = rho
                        results['p_neg'] = p
                    # save result
                    sio.savemat(resFile,results)

                results = sio.loadmat(resFile)

                if regression=='Finn':
                    print ('{},nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                          )
                    print ('{},nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                          )
                else:
                    print ('{},nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                          )
