# %% [markdown]
# This notebook runs a defined pipeline on HCP subjects, on the Cedars-Sinai cluster.
# After it is done preprocessing all subjects, it runs the leave-one-out IQ prediction a la Finn.

# %% [markdown]
# # Load libraries & helper functions

# %%
from helpers import *
# %matplotlib inline

# %% [markdown]
# # Declare parameters

# %%
config.DATADIR                 = '/scratch/duboisjx/data/HCP/MRI'
# fMRI runs
session                        = 'REST2'
fmriRuns                       = ['rfMRI_'+session+'_LR','rfMRI_'+session+'_RL']
# use volume or surface data
config.fmriFileTemplate        = '#fMRIrun#.nii.gz'
#config.fmriFileTemplate        = '#fMRIrun#_Atlas.dtseries.nii'
#config.fmriFileTemplate        = '#fMRIrun#_Atlas_MSMAll.dtseries.nii'
config.overwrite               = False
config.pipelineName            = 'Ciric9'
config.Operations              = config.operationDict[config.pipelineName]
config.melodicFolder           = op.join('#fMRIrun#_hp2000.ica','filtered_func_data.ica') #the code #fMRIrun# will be replaced
config.movementRelativeRMSFile = 'Movement_RelativeRMS.txt'
config.movementRegressorsFile  = 'Movement_Regressors_dt.txt'
# parcellation for FC matrix
config.parcellationName        = 'shen2013'
config.parcellationFile        = '/scratch/duboisjx/data/parcellations/shenetal_neuroimage2013_new/shen_2mm_268_parcellation.nii.gz'
config.nParcels                = 268
config.maskParcelswithAll      = True
config.maskParcelswithGM       = False
# subject selection parameters
config.behavFile               = '/scratch/duboisjx/data/HCP/neuropsych/unrestricted_luckydjuju_6_7_2017_0_44_41.csv'
config.release                 = 'all'
config.outScore                = 'PMAT24_A_CR'
# submit jobs with sge
config.queue        = True

# do not alter the following lines
if config.maskParcelswithGM:
    config.parcellationName = config.parcellationName + '_GM'
tmp = config.fmriFileTemplate.split('.')
if tmp[1]=='nii':
    config.isCifti = False
elif tmp[1]=='dtseries':
    config.isCifti = True
else:
    print 'unknown file extension'

if config.pipelineName is 'SiegelB':
    config.useFIX              = True
else:
    config.useFIX              = False
config.preWhitening            = False

# whether to use memmapping (which involves unzipping)
# deprecated
config.useMemMap               = False

# %% [markdown]
# # Subject selection

# %%
df = pd.read_csv(config.behavFile)
# select subjects according to release
if config.release == 'Q2':
    ind = (df['Release'] == 'Q2') | (df['Release'] == 'Q1')
elif config.release == 'S500':
    ind = (df['Release'] == 'Q3') | (df['Release'] == 'S500')
elif config.release == 'Q2+S500':
    ind = (df['Release'] == 'Q2') | (df['Release'] == 'Q1') | (df['Release'] == 'Q3') | (df['Release'] == 'S500')
elif config.release == 'S900':
    ind = (df['Release'] == 'S900')
elif config.release == 'S1200':
    ind = (df['Release'] == 'S1200')
elif config.release == 'all':
    ind = ((df['Release'] == 'Q1') | (df['Release'] == 'Q2') | (df['Release'] == 'Q3') 
           | (df['Release'] == 'S500') | (df['Release'] == 'S900') | (df['Release'] == 'S1200'))
else:
    sys.exit("Invalid release code")
# select subjects that have completed all fMRI
ind = ind & ((df['fMRI_WM_PctCompl']==100) & (df['fMRI_Mot_PctCompl']==100) 
             & (df['fMRI_Lang_PctCompl']==100) & (df['fMRI_Emo_PctCompl']==100)         
             & (df['3T_RS-fMRI_PctCompl']==100) & (df['PMAT_Compl']==True))
df = df[ind]  
# check if either of the two subjects recommended for exclusion by HCP are still present
df = df[~df['Subject'].isin(['209733','528446'])]
df.index     = range(df.shape[0])
tmpAgeRanges = sorted(df['Age'].unique())
# list of all selected subjects
subjects     = [str(subject) for subject in df['Subject']]
# pull their IQ, Age, Gender
age          = [str(a) for a in df['Age']]
gender       = [str(g) for g in df['Gender']]
score        = np.asarray([s for s in df[config.outScore]])

print 'Selected', str(df.shape[0]), 'from the release',config.release
print 'Number of males is:', df[df['Gender']=='M'].shape[0]
try:
    print 'Age range is', tmpAgeRanges[0].split('-')[0], '-', tmpAgeRanges[-1].split('-')[1]
except:
    print 'Age range is', tmpAgeRanges[0].split('-')[0], '-', tmpAgeRanges[-1]
# Exclusion of high-motion subjects
# exclude subjects with >0.14 frame-to-frame head motion estimate averged across both rest runs (arbitrary threshold as in Finn et al 2015)
RelRMSMean = np.zeros([len(subjects), len(fmriRuns)],dtype=np.float32)
compSub    = np.zeros((len(subjects)),dtype=np.bool_)
keepSub    = np.zeros((len(subjects)),dtype=np.bool_)
iSub=0
for config.subject in subjects:
    i=0
    for config.fmriRun in fmriRuns:
        RelRMSMeanFile = op.join(buildpath(), 'Movement_RelativeRMS_mean.txt')
        #print RelRMSMeanFile
        if op.isfile(RelRMSMeanFile):
            with open(RelRMSMeanFile,'r') as tmp:
                RelRMSMean[iSub,i] = float(tmp.read())
        else:
            print RelRMSMeanFile+' File missing'
            break
        i=i+1
    if i==len(fmriRuns): # all RelRMSMeanFile exist
        compSub[iSub]=True
        if np.mean(RelRMSMean[iSub,:]) > 0.14:
            print config.subject, ': too much motion, exclude'
        else:
            keepSub[iSub]=True
    iSub=iSub+1

#### motion vs. score correlation
plt.scatter(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1),c='r')
plt.scatter(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1),c='b')
# fit a curve to the data using a least squares 1st order polynomial fit
z1 = np.polyfit(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1),1)
z2 = np.polyfit(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1),1)
p1 = np.poly1d(z1)
p2 = np.poly1d(z2)                
fit1 = p1(score[keepSub])
fit2 = p2(score[compSub])
# get the coordinates for the fit curve
c1_x = [np.min(score[keepSub]),np.max(score[keepSub])]
c1_y = p1(c1_x)
c2_x = [np.min(score[compSub]),np.max(score[compSub])]
c2_y = p2(c2_x)
# plot line of best fit
plt.plot(c2_x,c2_y,'r-',label='before exclusion')
plt.plot(c1_x,c1_y,'b-',label='after exclusion')
plt.xlabel('Score [{}]'.format(config.outScore))
plt.ylabel('RelRMSMean')
plt.legend(loc=0)
plt.show()
rho1,p1 = stats.pearsonr(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1))
rho2,p2 = stats.pearsonr(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1))            
print 'With all subjects: corr(IQ,motion) = {:.3f} (p = {:.3f})'.format(rho2,p2)
print 'After discarding high movers: corr(IQ,motion) = {:.3f} (p = {:.3f})'.format(rho1,p1)
    
subjects   = [subject for (subject, keep) in zip(subjects, keepSub) if keep]
age        = [a for (a, keep) in zip(age, keepSub) if keep]
gender     = [g for (g, keep) in zip(gender, keepSub) if keep]
score      = score[keepSub]
RelRMSMean = RelRMSMean[keepSub,:]
print 'Keeping {} subjects [{} M]'.format(len(subjects),sum([g=='M' for g in gender]))
# Out:
# Selected 957 from the release all
# Number of males is: 452
# Age range is 22 - Age range is 22 - 36+
# 102008 : too much motion, exclude
# 103515 : too much motion, exclude
# 104820 : too much motion, exclude
# 107725 : too much motion, exclude
# 108121 : too much motion, exclude
# 114924 : too much motion, exclude
# 116524 : too much motion, exclude
# 123420 : too much motion, exclude
# 123723 : too much motion, exclude
# 124220 : too much motion, exclude
# 124624 : too much motion, exclude
# 130518 : too much motion, exclude
# 136732 : too much motion, exclude
# 139435 : too much motion, exclude
# 140824 : too much motion, exclude
# 141119 : too much motion, exclude
# 147030 : too much motion, exclude
# 151324 : too much motion, exclude
# 151526 : too much motion, exclude
# 151728 : too much motion, exclude
# 153833 : too much motion, exclude
# 154330 : too much motion, exclude
# 156233 : too much motion, exclude
# 156637 : too much motion, exclude
# 160830 : too much motion, exclude
# 161327 : too much motion, exclude
# 161832 : too much motion, exclude
# 163331 : too much motion, exclude
# 163836 : too much motion, exclude
# 166640 : too much motion, exclude
# 168240 : too much motion, exclude
# /scratch/duboisjx/data/HCP/MRI/169040/MNINonLinear/Results/rfMRI_REST2_LR/Movement_RelativeRMS_mean.txt File missing
# 171532 : too much motion, exclude
# 175035 : too much motion, exclude
# 175439 : too much motion, exclude
# 176239 : too much motion, exclude
# 181636 : too much motion, exclude
# 182436 : too much motion, exclude
# 188751 : too much motion, exclude
# 191437 : too much motion, exclude
# 198249 : too much motion, exclude
# 199150 : too much motion, exclude
# 205220 : too much motion, exclude
# 207123 : too much motion, exclude
# 209127 : too much motion, exclude
# 209834 : too much motion, exclude
# 210415 : too much motion, exclude
# 223929 : too much motion, exclude
# 224022 : too much motion, exclude
# 227432 : too much motion, exclude
# 250427 : too much motion, exclude
# 295146 : too much motion, exclude
# 298051 : too much motion, exclude
# 308331 : too much motion, exclude
# 311320 : too much motion, exclude
# 346137 : too much motion, exclude
# 352132 : too much motion, exclude
# 366446 : too much motion, exclude
# 382242 : too much motion, exclude
# 390645 : too much motion, exclude
# 392447 : too much motion, exclude
# 453441 : too much motion, exclude
# 453542 : too much motion, exclude
# 465852 : too much motion, exclude
# 468050 : too much motion, exclude
# 555348 : too much motion, exclude
# 562345 : too much motion, exclude
# 581349 : too much motion, exclude
# 609143 : too much motion, exclude
# 680250 : too much motion, exclude
# 686969 : too much motion, exclude
# 735148 : too much motion, exclude
# 748662 : too much motion, exclude
# 779370 : too much motion, exclude
# 788876 : too much motion, exclude
# 810843 : too much motion, exclude
# 856968 : too much motion, exclude
# 919966 : too much motion, exclude
# 922854 : too much motion, exclude
# 937160 : too much motion, exclude
# 947668 : too much motion, exclude
# With all subjects: corr(IQ,motion) = -0.175 (p = 0.000)
# After discarding high movers: corr(IQ,motion) = -0.149 (p = 0.000)
# Keeping 876 subjects [414 M]

# %% [markdown]
# # Do work

# %% [markdown]
# ### preprocess everybody

# %%
config.scriptlist = []
keepSub = np.zeros((len(subjects)),dtype=np.bool_)
iSub    = 0
for config.subject in subjects:
    iRun = 0
    for config.fmriRun in fmriRuns:
        keepSub[iSub] = runPipelinePar(launchSubproc=False)
        if not keepSub[iSub]:
            break
        iRun=iRun+1
    iSub = iSub + 1
print 'Keeping {}/{} subjects'.format(np.sum(keepSub),len(subjects))
subjects   = [subject for (subject, keep) in zip(subjects, keepSub) if keep]
age        = [a for (a, keep) in zip(age, keepSub) if keep]
gender     = [g for (g, keep) in zip(gender, keepSub) if keep]
score      = score[keepSub]
RelRMSMean = RelRMSMean[keepSub,:]

# launch array job (if there is something to do)
if len(config.scriptlist)>0:
#     print config.scriptlist
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    JobID = fnSubmitJobArrayFromJobList()
    print 'Running array job {} ({} sub jobs)'.format(JobID.split('.')[0],JobID.split('.')[1].split('-')[1].split(':')[0])
    config.joblist.append(JobID.split('.')[0])
    checkProgress(pause=60,verbose=False)
# Out:
# Keeping 876/876 subjects

# %% [markdown]
# ### run prediction in Q2 (sanity check)

# %%
#----------------------
# prepare
#----------------------
config.queue        = True
config.sgeopts      = '-l mem_free=25G -pe smp 6' 
config.overwrite    = False
config.fmriFile_dn  = ''
newdf = df[df['Subject'].isin([int(s) for s in subjects])]  
idx_smpl      = np.where(np.ravel(newdf['Release'].isin(['Q1','Q2'])))[0]
# define nSubPerSample
nSubPerSample = idx_smpl.shape[0]
outDir = op.join(config.DATADIR,'Results','samples_nsub{}_{}'.format(nSubPerSample,0))
if not op.isdir(outDir):
    mkdir(outDir)
smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
smpl_score    = score[idx_smpl]
smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
motFile = op.join(outDir,'RMS_{}.txt'.format(session))
np.savetxt(motFile, smpl_motscore)
fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
    session,config.pipelineName, config.parcellationName, config.release))
overwrite = False
if not op.isfile(fcMatFile) or overwrite:
    fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
    iSub= 0
    for config.subject in smpl_subjects:
        iRun = 0
        for config.fmriRun in fmriRuns:
            # set the global variable config
            runPipelinePar(launchSubproc=False)
            #print 'Found denoised data: {}'.format(config.fmriFile_dn)
            tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
            rstring = get_rcode(config.fmriFile_dn)
            fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
            fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
            iRun = iRun+1
        iSub = iSub + 1
    fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
    results = {}
    results['fcMats']        = fcMats_dn
    results['subjects']      = smpl_subjects
    results[config.outScore] = np.asarray(smpl_score)
    sio.savemat(fcMatFile, results)
fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
#----------------------
# predict!
#----------------------
idcode           = session
predict          = 'IQ'
config.queue     = True
launchSubproc    = False
config.sgeopts   = '-l mem_free=2G' 
config.overwrite = False
newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
# run the IQ prediction for each subject
for model in ['IQ']:
    for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
        for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
            resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                config.release))
            if not op.isfile(resFile) or config.overwrite:
                runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                 regression=regression, outDir=outDir)
                checkProgress(pause=10,verbose=False)
                # merge cross-validation folds, save results
                n_subs          = fcMats_dn.shape[-1]
                predictions_pos = np.zeros([n_subs,1])
                predictions_neg = np.zeros([n_subs,1])
                iSub = 0
                for subject in smpl_subjects:
                    subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                        model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                        config.release))
                    while not op.isfile(subResFile):
                        sleep(.1)
                    results = sio.loadmat(subResFile) 
                    if regression=='Finn':
                        predictions_neg[iSub] = results['pred_neg']
                        predictions_pos[iSub] = results['pred_pos']
                    else:
                        predictions_pos[iSub] = results['pred']
                    iSub = iSub + 1
                if predict=='IQ':
                    rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                elif predict=='motion':
                    rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                if regression=='Finn':
                    results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                else:
                    results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                if regression=='Finn':
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                    results['rho_neg'] = rho
                    results['p_neg'] = p
                # save result
                sio.savemat(resFile,results)

            while not op.isfile(resFile):
                sleep(.1)
            results = sio.loadmat(resFile)

            if regression=='Finn':
                print ('{},nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                    config.release,nSubPerSample,0,0,config.pipelineName,config.parcellationName,
                    config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                      )
                print ('{},nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                    config.release,nSubPerSample,0,0,config.pipelineName,config.parcellationName,
                    config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                      )
            else:
                print ('{},nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                    config.release,nSubPerSample,0,0,config.pipelineName,config.parcellationName,
                    config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                      )
# Out:
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:38: RuntimeWarning: divide by zero encountered in arctanh
# all,nsub112,nsamp0,0,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.358352090211,p=0.000104645706844
# all,nsub112,nsamp0,0,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.237693572185,p=0.0116170065099

# %% [markdown]
# ### run prediction in random samples (from all subjects)

# %%
# Generate random samples from all subjects
nRep = 1000
sampleFile = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_{}.txt'.format(nSubPerSample,nRep,session))
if not op.isfile(sampleFile) or config.overwrite:
    samples = np.vstack([random.sample(range(len(subjects)),nSubPerSample) for i in range(nRep)])
    np.savetxt(sampleFile, samples)
else:
    samples = np.loadtxt(sampleFile,dtype=np.int16)

#do work
outDir_ = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}'.format(nSubPerSample,nRep))
if not op.isdir(outDir_):
    mkdir(outDir_)
for iSample in range(500):#nRep):
    outDir = op.join(outDir_,'{}'.format(iSample+1))
    if not op.isdir(outDir):
        mkdir(outDir)
    #----------------------
    # prepare
    #----------------------
    config.queue        = True
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    config.overwrite    = False
    config.fmriFile_dn  = ''
    idx_smpl      = samples[iSample,:]
    # reorder indices!
    idx_smpl      = np.sort(idx_smpl)
    smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
    smpl_score    = score[idx_smpl]
    smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
    motFile = op.join(outDir,'RMS_{}.txt'.format(session))
    np.savetxt(motFile, smpl_motscore)
    fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
        session,config.pipelineName, config.parcellationName, config.release))
    overwrite = False
    if not op.isfile(fcMatFile) or overwrite:
        fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
        iSub= 0
        for config.subject in smpl_subjects:
            iRun = 0
            for config.fmriRun in fmriRuns:
                # set the global variable config
                runPipelinePar(launchSubproc=False)
                #print 'Found denoised data: {}'.format(config.fmriFile_dn)
                tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
                rstring = get_rcode(config.fmriFile_dn)
                fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
                fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
                iRun = iRun+1
            iSub = iSub + 1
        fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
        results = {}
        results['fcMats']        = fcMats_dn
        results['subjects']      = smpl_subjects
        results[config.outScore] = np.asarray(smpl_score)
        sio.savemat(fcMatFile, results)
    fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
    #----------------------
    # predict!
    #----------------------
    idcode           = session
    predict          = 'IQ'
    config.queue     = True
    launchSubproc    = False
    config.sgeopts   = '-l mem_free=2G' 
    config.overwrite = False
    newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
    # run the IQ prediction for each subject
    for model in ['IQ']:
        for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
            for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
                resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                    model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                    config.release))
                if not op.isfile(resFile) or config.overwrite:
                    runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                     regression=regression, outDir=outDir)
                    checkProgress(pause=10,verbose=False)
                    # merge cross-validation folds, save results
                    n_subs          = fcMats_dn.shape[-1]
                    predictions_pos = np.zeros([n_subs,1])
                    predictions_neg = np.zeros([n_subs,1])
                    iSub = 0
                    for subject in smpl_subjects:
                        subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                            model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                            config.release))
                        while not op.isfile(subResFile):
                            sleep(.1)
                        results = sio.loadmat(subResFile) 
                        if regression=='Finn':
                            predictions_neg[iSub] = results['pred_neg']
                            predictions_pos[iSub] = results['pred_pos']
                        else:
                            predictions_pos[iSub] = results['pred']
                        iSub = iSub + 1
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                    if regression=='Finn':
                        results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                    else:
                        results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                    if regression=='Finn':
                        if predict=='IQ':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                        elif predict=='motion':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                        results['rho_neg'] = rho
                        results['p_neg'] = p
                    # save result
                    sio.savemat(resFile,results)

                while not op.isfile(resFile):
                    sleep(.1)
                results = sio.loadmat(resFile)

                if regression=='Finn':
                    print ('{},nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                          )
                    print ('{},nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                          )
                else:
                    print ('{},nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                          )
# Out:
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:51: RuntimeWarning: divide by zero encountered in arctanh
# all,nsub112,nsamp1000,1,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.245159157215,p=0.00917938498434
# all,nsub112,nsamp1000,1,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.211763497274,p=0.0249977719262
# all,nsub112,nsamp1000,2,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0530855215703,p=0.578283331715
# all,nsub112,nsamp1000,2,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0161602301779,p=0.865705232592
# all,nsub112,nsamp1000,3,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0546398030648,p=0.567190598704
# all,nsub112,nsamp1000,3,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.24103829335,p=0.0104624819829
# all,nsub112,nsamp1000,4,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00146267664135,p=0.987788163352
# all,nsub112,nsamp1000,4,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0979140296428,p=0.304387399064
# all,nsub112,nsamp1000,5,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0267225245657,p=0.779721536069
# all,nsub112,nsamp1000,5,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.110140988049,p=0.247653630476
# all,nsub112,nsamp1000,6,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.294049033673,p=0.00165018332934
# all,nsub112,nsamp1000,6,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.241697337554,p=0.010247261719
# all,nsub112,nsamp1000,7,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.172144678019,p=0.0695324668337
# all,nsub112,nsamp1000,7,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0233818082712,p=0.806683114586
# all,nsub112,nsamp1000,8,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0330405327658,p=0.729463073697
# all,nsub112,nsamp1000,8,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0686962989149,p=0.471704684741
# all,nsub112,nsamp1000,9,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0504602686387,p=0.59724450627
# all,nsub112,nsamp1000,9,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00118911255131,p=0.990072010836
# all,nsub112,nsamp1000,10,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.20810020505,p=0.0276806602614
# all,nsub112,nsamp1000,10,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0714760985056,p=0.453914753509
# all,nsub112,nsamp1000,11,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.165148815692,p=0.0818356011624
# all,nsub112,nsamp1000,11,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0375475181943,p=0.694285203062
# all,nsub112,nsamp1000,12,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0244486218615,p=0.798046988502
# all,nsub112,nsamp1000,12,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.247375785798,p=0.00854822126904
# all,nsub112,nsamp1000,13,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.299633459163,p=0.00132954439213
# all,nsub112,nsamp1000,13,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.187831119008,p=0.0473443854235
# all,nsub112,nsamp1000,14,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.154621592666,p=0.103565379514
# all,nsub112,nsamp1000,14,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.216591971853,p=0.0218032122916
# all,nsub112,nsamp1000,15,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.110139948528,p=0.247658120512
# all,nsub112,nsamp1000,15,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0200791481923,p=0.833562298474
# all,nsub112,nsamp1000,16,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.193935836129,p=0.0404724261814
# all,nsub112,nsamp1000,16,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.317736281025,p=0.000640650856136
# all,nsub112,nsamp1000,17,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.234024863779,p=0.0130101541006
# all,nsub112,nsamp1000,17,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.168462858515,p=0.0758062269751
# all,nsub112,nsamp1000,18,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.130050712326,p=0.171719680237
# all,nsub112,nsamp1000,18,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.165520771409,p=0.0811403456515
# all,nsub112,nsamp1000,19,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0896740942008,p=0.347078598307
# all,nsub112,nsamp1000,19,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0521039593345,p=0.585340056698
# all,nsub112,nsamp1000,20,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0691909088474,p=0.468511866831
# all,nsub112,nsamp1000,20,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.109705301079,p=0.249540433328
# all,nsub112,nsamp1000,21,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0122963151509,p=0.897613279646
# all,nsub112,nsamp1000,21,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.315900327093,p=0.000691343224564
# all,nsub112,nsamp1000,22,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.14547687954,p=0.125901680026
# all,nsub112,nsamp1000,22,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.14544480644,p=0.125986062055
# all,nsub112,nsamp1000,23,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0627929569645,p=0.510709948603
# all,nsub112,nsamp1000,23,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.142778787182,p=0.133153230158
# all,nsub112,nsamp1000,24,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0579662062923,p=0.543794221263
# all,nsub112,nsamp1000,24,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0425355657254,p=0.656098834618
# all,nsub112,nsamp1000,25,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0450060387402,p=0.637501710892
# all,nsub112,nsamp1000,25,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0262404279619,p=0.783597066797
# all,nsub112,nsamp1000,26,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.251434133963,p=0.00749119177869
# all,nsub112,nsamp1000,26,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0700835926825,p=0.462779377554
# all,nsub112,nsamp1000,27,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.11072224984,p=0.245151765484
# all,nsub112,nsamp1000,27,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0658422399494,p=0.490357299393
# all,nsub112,nsamp1000,28,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0
Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.257534041929,p=0.00611949721486
# all,nsub112,nsamp1000,51,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.190182845829,p=0.0445904665097
# all,nsub112,nsamp1000,52,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.205624768592,p=0.0296291002471
# all,nsub112,nsamp1000,52,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.181656968061,p=0.0552518655781
# all,nsub112,nsamp1000,53,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.154414516251,p=0.104034250947
# all,nsub112,nsamp1000,53,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0168054625116,p=0.860396481794
# all,nsub112,nsamp1000,54,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0357972159098,p=0.707874484529
# all,nsub112,nsamp1000,54,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.229086197598,p=0.0151144240799
# all,nsub112,nsamp1000,55,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.113328859614,p=0.234147710047
# all,nsub112,nsamp1000,55,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.155149742648,p=0.102377018705
# all,nsub112,nsamp1000,56,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.212025402882,p=0.0248147721345
# all,nsub112,nsamp1000,56,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.169305992088,p=0.0743307569207
# all,nsub112,nsamp1000,57,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0312722102294,p=0.74342491996
# all,nsub112,nsamp1000,57,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0847757504588,p=0.3741543871
# all,nsub112,nsamp1000,58,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0868340149735,p=0.362623945967
# all,nsub112,nsamp1000,58,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.260763089447,p=0.00548780413876
# all,nsub112,nsamp1000,59,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.116699090295,p=0.220438212343
# all,nsub112,nsamp1000,59,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0123866083662,p=0.896865571319
# all,nsub112,nsamp1000,60,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.206585381973,p=0.0288596045447
# all,nsub112,nsamp1000,60,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.286364132819,p=0.00220623495536
# all,nsub112,nsamp1000,61,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.254480614273,p=0.00677541189802
# all,nsub112,nsamp1000,61,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.250309342273,p=0.00777190416694
# all,nsub112,nsamp1000,62,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0334456424009,p=0.726276744973
# all,nsub112,nsamp1000,62,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.205376861283,p=0.029830487164
# all,nsub112,nsamp1000,63,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.253373426243,p=0.00702821350378
# all,nsub112,nsamp1000,63,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0583850109463,p=0.540882462455
# all,nsub112,nsamp1000,64,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0674720169092,p=0.479658334081
# all,nsub112,nsamp1000,64,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0876933866115,p=0.357875390049
# all,nsub112,nsamp1000,65,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.103211608951,p=0.278839347048
# all,nsub112,nsamp1000,65,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.211412142901,p=0.025245080875
# all,nsub112,nsamp1000,66,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0290887342803,p=0.760779664188
# all,nsub112,nsamp1000,66,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.16227804133,p=0.0873632867796
# all,nsub112,nsamp1000,67,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0744915199263,p=0.435046311833
# all,nsub112,nsamp1000,67,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.25055785734,p=0.00770909498179
# all,nsub112,nsamp1000,68,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0544278491459,p=0.568697352709
# all,nsub112,nsamp1000,68,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0942001422577,p=0.323184177436
# all,nsub112,nsamp1000,69,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0176355112037,p=0.853576298128
# all,nsub112,nsamp1000,69,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.396586805606,p=1.49865441536e-05
# all,nsub112,nsamp1000,70,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.21256841186,p=0.0244390018856
# all,nsub112,nsamp1000,70,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0691207666508,p=0.468963931179
# all,nsub112,nsamp1000,71,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.200033424587,p=0.0344617046579
# all,nsub112,nsamp1000,71,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.239794995721,p=0.0108793182246
# all,nsub112,nsamp1000,72,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.100285398838,p=0.292767686419
# all,nsub112,nsamp1000,72,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.109308475511,p=0.251267542346
# all,nsub112,nsamp1000,73,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.333434374473,p=0.000327485848233
# all,nsub112,nsamp1000,73,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0841024078166,p=0.377974491741
# all,nsub112,nsamp1000,74,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.231077216873,p=0.0142329501984
# all,nsub112,nsamp1000,74,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0925548429557,p=0.331744926058
# all,nsub112,nsamp1000,75,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.155739896469,p=0.101061834152
# all,nsub112,nsamp1000,75,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0398397534172,p=0.676634521582
# all,nsub112,nsamp1000,76,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0504653825719,p=0.59720730069
# all,nsub112,nsamp1000,76,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.23492651481,p=0.0126548999896
# all,nsub112,nsamp1000,77,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.266513568549,p=0.00450517919369
# all,nsub112,nsamp1000,77,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0813714919775,p=0.393709393536
# all,nsub112,nsamp1000,78,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.085966062868,p=0.367459213065
# all,nsub112,nsamp1000,78,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0701486423631,p=0.462363165816
# all,nsub112,nsamp1000,79,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.147582318508,p=0.120456835624
# all,nsub112,nsamp1000,79,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.273081253912,p=0.00357764810019
# all,nsub112,nsamp1000,80,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.010315674394,p=0.914036169852
# all,nsub112,nsamp1000,80,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.121294099567,p=0.202675853134
# all,nsub112,nsamp1000,81,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.220884927551,p=0.019263728349
# all,nsub112,nsamp1000,81,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.211706709187,p=0.025037602812
# all,nsub112,nsamp1000,82,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.181008546685,p=0.0561419077045
# all,nsub112,nsamp1000,82,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.147215085828,p=0.121393210241
# all,nsub112,nsamp1000,83,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0299895999096,p=0.753604434941
# all,nsub112,nsamp1000,83,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0941784690221,p=0.323296015143
# all,nsub112,nsamp1000,84,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.137857459641,p=0.147195303775
# all,nsub112,nsamp1000,84,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.236092165007,p=0.0122081999215
# all,nsub112,nsamp1000,85,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00104878991441,p=0.991243525477
# all,nsub112,nsamp1000,85,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0493689932596,p=0.605207555448
# all,nsub112,nsamp1000,86,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.136328709441,p=0.151777028246
# all,nsub112,nsamp1000,86,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.175804413684,p=0.0637198003831
# all,nsub112,nsamp1000,87,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.1289184757,p=0.175513305137
# all,nsub112,nsamp1000,87,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.174986216876,p=0.0649837129457
# all,nsub112,nsamp1000,88,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.253828004097,p=0.00692342721779
# all,nsub112,nsamp1000,88,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.217839522962,p=0.0210371889645
# all,nsub112,nsamp1000,89,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.177947417538,p=0.0605040824418
# all,nsub112,nsamp1000,89,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0972163085434,p=0.307862954362
# all,nsub112,nsamp1000,90,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.287763269012,p=0.00209385562424
# all,nsub112,nsamp1000,90,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.182949975768,p=0.0535116628608
# all,nsub112,nsamp1000,91,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.264666692271,p=0.00480210178637
# all,nsub112,nsamp1000,91,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.246260936705,p=0.00886071261413
# all,nsub112,nsamp1000,92,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0857059383066,p=0.368916018871
# all,nsub112,nsamp1000,92,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.292021900672,p=0.00178293676585
# all,nsub112,nsamp1000,93,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.100710021513,p=0.29071846406
# all,nsub112,nsamp1000,93,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.158356231644,p=0.0953903948994
# all,nsub112,nsamp1000,94,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.26480148258,p=0.00477985507844
# all,nsub112,nsamp1000,94,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0282862808346,p=0.767188215279
# all,nsub112,nsamp1000,95,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0858492480232,p=0.368112987016
# all,nsub112,nsamp1000,95,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.213110600172,p=0.0240686626875
# all,nsub112,nsamp1000,96,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.21347424744,p=0.0238229729599
# all,nsub112,nsamp1000,96,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.170063816431,p=0.0730244096923
# all,nsub112,nsamp1000,97,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.143743776494,p=0.130523905503
# all,nsub112,nsamp1000,97,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.019296573871,p=0.839960852365
# all,nsub112,nsamp1000,98,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0638588955619,p=0.503546122489
# all,nsub112,nsamp1000,98,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0313635800247,p=0.742701419417
# all,nsub112,nsamp1000,99,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0957404201473,p=0.3152997961
# all,nsub112,nsamp1000,99,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.177856901182,p=0.060637171902
# all,nsub112,nsamp1000,100,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.096034377033,p=0.313809372848
# all,nsub112,nsamp1000,100,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.138334322256,p=0.145787686159
# all,nsub112,nsamp1000,101,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.170806883527,p=0.0717615535909
# all,nsub112,nsamp1000,101,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.159447916069,p=0.0930995853283
# all,nsub112,nsamp1000,102,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00614704039446,p=0.948711482793
# all,nsub112,nsamp1000,102,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0657710931921,p=0.490827220641
# all,nsub112,nsamp1000,103,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0139674302441,p=0.883790166899
# all,nsub112,nsamp1000,103,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.257705820987,p=0.00608433237692
# all,nsub112,nsamp1000,104,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.184983276727,p=0.0508666223381
# all,nsub112,nsamp1000,104,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0114056060258,p=0.904993848204
# all,nsub112,nsamp1000,105,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0825142317292,p=0.387078164514
# all,nsub112,nsamp1000,105,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.107707512502,p=0.258318876155
# all,nsub112,nsamp1000,106,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0318953188431,p=0.738495376377
# all,nsub112,nsamp1000,106,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.200337895295,p=0.0341824328992
# all,nsub112,nsamp1000,107,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.165621939484,p=0.0809520636954
# all,nsub112,nsamp1000,107,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.192911942516,p=0.0415630507644
# all,nsub112,nsamp1000,108,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0878847541295,p=0.356823245132
# all,nsub112,nsamp1000,108,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.277442155893,p=0.00306041847199
# all,nsub112,nsamp1000,109,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.302932174231,p=0.00116789774973
# all,nsub112,nsamp1000,109,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0933155323724,p=0.327769130919
# all,nsub112,nsamp1000,110,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.255043345341,p=0.00665004074742
# all,nsub112,nsamp1000,110,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0947078179352,p=0.32057159866
# all,nsub112,nsamp1000,111,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.358617138753,p=0.000103330135669
# all,nsub112,nsamp1000,111,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.3408820359,p=0.00023518352536
# all,nsub112,nsamp1000,112,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0297818310443,p=0.755257440103
# all,nsub112,nsamp1000,112,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0828146651237,p=0.385345992575
# all,nsub112,nsamp1000,113,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.185577225169,p=0.0501146845952
# all,nsub112,nsamp1000,113,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.130865399077,p=0.169027708182
# all,nsub112,nsamp1000,114,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.184620070635,p=0.0513310156052
# all,nsub112,nsamp1000,114,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.16008088874,p=0.0917914226622
# all,nsub112,nsamp1000,115,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0426467610823,p=0.655257138223
# all,nsub112,nsamp1000,115,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0498793051715,p=0.60147795883
# all,nsub112,nsamp1000,116,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.154584578019,p=0.103649067881
# all,nsub112,nsamp1000,116,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0718893566871,p=0.451302264594
# all,nsub112,nsamp1000,117,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0802906015242,p=0.400043726716
# all,nsub112,nsamp1000,117,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.11629968193,p=0.222032604956
# all,nsub112,nsamp1000,118,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.327562043833,p=0.000422706912357
# all,nsub112,nsamp1000,118,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0219141141478,p=0.81860235785
# all,nsub112,nsamp1000,119,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.429996723016,p=2.22730734914e-06
# all,nsub112,nsamp1000,119,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.217801318348,p=0.0210602995205
# all,nsub112,nsamp1000,120,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0
Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.378863213439,p=3.80230777401e-05
# all,nsub112,nsamp1000,189,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.260501655572,p=0.00553669774848
# all,nsub112,nsamp1000,189,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0209004233763,p=0.826858994488
# all,nsub112,nsamp1000,190,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00558218463465,p=0.953418867737
# all,nsub112,nsamp1000,190,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0445714864599,p=0.640757067582
# all,nsub112,nsamp1000,191,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.173743777199,p=0.0669419102682
# all,nsub112,nsamp1000,191,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.226841750511,p=0.0161645976607
# all,nsub112,nsamp1000,192,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.103496898223,p=0.277505605678
# all,nsub112,nsamp1000,192,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0457100247001,p=0.632242578201
# all,nsub112,nsamp1000,193,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00613171591258,p=0.948839171126
# all,nsub112,nsamp1000,193,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0976530248538,p=0.305684521012
# all,nsub112,nsamp1000,194,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0686936600786,p=0.471721750686
# all,nsub112,nsamp1000,194,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0827034399638,p=0.38598672445
# all,nsub112,nsamp1000,195,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.379959698578,p=3.59502281817e-05
# all,nsub112,nsamp1000,195,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.211433327691,p=0.0252301105217
# all,nsub112,nsamp1000,196,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0612421334614,p=0.521225569532
# all,nsub112,nsamp1000,196,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0889438176579,p=0.351035289318
# all,nsub112,nsamp1000,197,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.113274046019,p=0.234375498341
# all,nsub112,nsamp1000,197,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.175545865841,p=0.0641170103899
# all,nsub112,nsamp1000,198,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.259627951946,p=0.00570292370066
# all,nsub112,nsamp1000,198,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0274925638914,p=0.773542482167
# all,nsub112,nsamp1000,199,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0394895342191,p=0.679320259172
# all,nsub112,nsamp1000,199,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.207310451946,p=0.0282900881017
# all,nsub112,nsamp1000,200,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.259550840702,p=0.00571780548368
# all,nsub112,nsamp1000,200,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0128681032685,p=0.892879905097
# all,nsub112,nsamp1000,201,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0971917667049,p=0.307985674196
# all,nsub112,nsamp1000,201,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.138466694495,p=0.145398753734
# all,nsub112,nsamp1000,202,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.249336243036,p=0.00802221690944
# all,nsub112,nsamp1000,202,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.283837165293,p=0.00242310187396
# all,nsub112,nsamp1000,203,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0489001382312,p=0.608643146611
# all,nsub112,nsamp1000,203,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.142041474007,p=0.135189305358
# all,nsub112,nsamp1000,204,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.116985554965,p=0.219299676876
# all,nsub112,nsamp1000,204,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.233217463905,p=0.0133356248351
# all,nsub112,nsamp1000,205,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.149880083607,p=0.114724033607
# all,nsub112,nsamp1000,205,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.193754309651,p=0.0406640192153
# all,nsub112,nsamp1000,206,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0546666895195,p=0.566999601155
# all,nsub112,nsamp1000,206,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.000488529973295,p=0.995921140615
# all,nsub112,nsamp1000,207,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.125987847011,p=0.185618272544
# all,nsub112,nsamp1000,207,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.10902682426,p=0.25249835661
# all,nsub112,nsamp1000,208,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.088007518753,p=0.356149294284
# all,nsub112,nsamp1000,208,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0366195558081,p=0.701478124744
# all,nsub112,nsamp1000,209,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.196304771405,p=0.0380405624657
# all,nsub112,nsamp1000,209,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.198954323622,p=0.0354670261967
# all,nsub112,nsamp1000,210,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.188641694688,p=0.0463796733185
# all,nsub112,nsamp1000,210,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.088226952041,p=0.354946626995
# all,nsub112,nsamp1000,211,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.183055288028,p=0.0533719384559
# all,nsub112,nsamp1000,211,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.
Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.181762894577,p=0.0551075759597
# all,nsub112,nsamp1000,488,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.194831223694,p=0.0395383951991
# all,nsub112,nsamp1000,488,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.285967745294,p=0.00223904923068
# all,nsub112,nsamp1000,489,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0272569549506,p=0.775431604737
# all,nsub112,nsamp1000,489,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0834447195836,p=0.381728569917
# all,nsub112,nsamp1000,490,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.200652414178,p=0.0338959501805
# all,nsub112,nsamp1000,490,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.201414962479,p=0.0332097697559
# all,nsub112,nsamp1000,491,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.172878489014,p=0.0683337805114
# all,nsub112,nsamp1000,491,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.17658324296,p=0.0625353763585
# all,nsub112,nsamp1000,492,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.32908538723,p=0.000395818817815
# all,nsub112,nsamp1000,492,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.361179817053,p=9.13806274837e-05
# all,nsub112,nsamp1000,493,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.290335875001,p=0.00190064650114
# all,nsub112,nsamp1000,493,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.200806576992,p=0.0337562704723
# all,nsub112,nsamp1000,494,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0747390427527,p=0.433517575061
# all,nsub112,nsamp1000,494,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.20304652544,p=0.0317809116947
# all,nsub112,nsamp1000,495,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0338246298367,p=0.723300098424
# all,nsub112,nsamp1000,495,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.181137839328,p=0.0559635031713
# all,nsub112,nsamp1000,496,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.150942895049,p=0.112145051634
# all,nsub112,nsamp1000,496,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.109111748684,p=0.252126801789
# all,nsub112,nsamp1000,497,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0181588115084,p=0.849282053203
# all,nsub112,nsamp1000,497,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.379850486127,p=3.615184216e-05
# all,nsub112,nsamp1000,498,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0884207178324,p=0.353886742573
# all,nsub112,nsamp1000,498,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.197819542582,p=0.0365507291755
# all,nsub112,nsamp1000,499,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.18733628383,p=0.047941455915
# all,nsub112,nsamp1000,499,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.187559469893,p=0.0476713904072
# all,nsub112,nsamp1000,500,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.188037894406,p=0.0470967228197
# all,nsub112,nsamp1000,500,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0572350735001,p=0.548895817604

# %% [markdown]
# ### The recon algorithm changed after Q3
# This could be important, and explain why the random sampling typically gives worse performance
# https://wiki.humanconnectome.org/display/PublicData/Ramifications+of+Image+Reconstruction+Version+Differences

# %% [markdown]
# ### r177 recon

# %%
# Generate random samples from r177 subjects
newdf       = df[df['Subject'].isin([int(s) for s in subjects])]  
idx_smpl  = np.where(np.ravel(newdf['fMRI_3T_ReconVrs'].isin(['r177'])))[0]
print "{} subjects with r177 recon".format(idx_smpl.shape[0])
nRep = 1000
sampleFile = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_{}_r177.txt'.format(nSubPerSample,nRep,session))
if not op.isfile(sampleFile) or config.overwrite:
    samples = np.vstack([random.sample(idx_smpl,nSubPerSample) for i in range(nRep)])
    np.savetxt(sampleFile, samples)
else:
    samples = np.loadtxt(sampleFile,dtype=np.int16)
    
# do work
outDir_ = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_r177'.format(nSubPerSample,nRep))
if not op.isdir(outDir_):
    mkdir(outDir_)
for iSample in range(100):#nRep):
    outDir = op.join(outDir_,'{}'.format(iSample+1))
    if not op.isdir(outDir):
        mkdir(outDir)
    #----------------------
    # prepare
    #----------------------
    config.queue        = True
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    config.overwrite    = False
    config.fmriFile_dn  = ''
    idx_smpl      = samples[iSample,:]
    # reorder indices!
    idx_smpl      = np.sort(idx_smpl)
    smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
    smpl_score    = score[idx_smpl]
    smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
    motFile = op.join(outDir,'RMS_{}.txt'.format(session))
    np.savetxt(motFile, smpl_motscore)
    fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
        session,config.pipelineName, config.parcellationName, config.release))
    overwrite = False
    if not op.isfile(fcMatFile) or overwrite:
        fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
        iSub= 0
        for config.subject in smpl_subjects:
            iRun = 0
            for config.fmriRun in fmriRuns:
                # set the global variable config
                runPipelinePar(launchSubproc=False)
                #print 'Found denoised data: {}'.format(config.fmriFile_dn)
                tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
                rstring = get_rcode(config.fmriFile_dn)
                fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
                fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
                iRun = iRun+1
            iSub = iSub + 1
        fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
        results = {}
        results['fcMats']        = fcMats_dn
        results['subjects']      = smpl_subjects
        results[config.outScore] = np.asarray(smpl_score)
        sio.savemat(fcMatFile, results)
    fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
    #----------------------
    # predict!
    #----------------------
    idcode           = session
    predict          = 'IQ'
    config.queue     = True
    launchSubproc    = False
    config.sgeopts   = '-l mem_free=2G' 
    config.overwrite = False
    newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
    # run the IQ prediction for each subject
    for model in ['IQ']:
        for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
            for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
                resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                    model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                    config.release))
                if not op.isfile(resFile) or config.overwrite:
                    runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                     regression=regression, outDir=outDir)
                    checkProgress(pause=10,verbose=False)
                    # merge cross-validation folds, save results
                    n_subs          = fcMats_dn.shape[-1]
                    predictions_pos = np.zeros([n_subs,1])
                    predictions_neg = np.zeros([n_subs,1])
                    iSub = 0
                    for subject in smpl_subjects:
                        subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                            model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                            config.release))
                        while not op.isfile(subResFile):
                            sleep(.1)
                        results = sio.loadmat(subResFile) 
                        if regression=='Finn':
                            predictions_neg[iSub] = results['pred_neg']
                            predictions_pos[iSub] = results['pred_pos']
                        else:
                            predictions_pos[iSub] = results['pred']
                        iSub = iSub + 1
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                    if regression=='Finn':
                        results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                    else:
                        results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                    if regression=='Finn':
                        if predict=='IQ':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                        elif predict=='motion':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                        results['rho_neg'] = rho
                        results['p_neg'] = p
                    # save result
                    sio.savemat(resFile,results)

                while not op.isfile(resFile):
                    sleep(.1)
                results = sio.loadmat(resFile)

                if regression=='Finn':
                    print ('{}r177,nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                          )
                    print ('{}r177,nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                          )
                else:
                    print ('{}r177,nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                          )
# Out:
# 159 subjects with r177 recon
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:54: RuntimeWarning: divide by zero encountered in arctanh
# allr177,nsub112,nsamp1000,1,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.260957569297,p=0.00545168202647
# allr177,nsub112,nsamp1000,1,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.199977977148,p=0.0345127694748
# allr177,nsub112,nsamp1000,2,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.291240742151,p=0.00183662605675
# allr177,nsub112,nsamp1000,2,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.301105755128,p=0.00125503610056
# allr177,nsub112,nsamp1000,3,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.242431240045,p=0.0100121782714
# allr177,nsub112,nsamp1000,3,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.331135272458,p=0.000362121112005
# allr177,nsub112,nsamp1000,4,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.292178980123,p=0.00177231402152
# allr177,nsub112,nsamp1000,4,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.174424325984,p=0.0658634527825
# allr177,nsub112,nsamp1000,5,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.197452832768,p=0.0369068275268
# allr177,nsub112,nsamp1000,5,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.243897311102,p=0.00955671064565
# allr177,nsub112,nsamp1000,6,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.231927581291,p=0.0138703216747
# allr177,nsub112,nsamp1000,6,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.176945930837,p=0.0619899710807
# allr177,nsub112,nsamp1000,7,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.274774921331,p=0.00336811663074
# allr177,nsub112,nsamp1000,7,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.18678571318,p=0.0486130981059
# allr177,nsub112,nsamp1000,8,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.256026213299,p=0.00643599421505
# allr177,nsub112,nsamp1000,8,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.255183916005,p=0.00661904584291
# allr177,nsub112,nsamp1000,9,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.220167048194,p=0.0196697355877
# allr177,nsub112,nsamp1000,9,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.285387191416,p=0.00228790575691
# allr177,nsub112,nsamp1000,10,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.134831308799,p=0.156367834715
# allr177,nsub112,nsamp1000,10,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.286426564288,p=0.00220110648078
# allr177,nsub112,nsamp1000,11,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.361137547861,p=9.15668225327e-05
# allr177,nsub112,nsamp1000,11,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.400423633792,p=1.21639188788e-05
# allr177,nsub112,nsamp1000,12,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.198310052421,p=0.0360789308858
# allr177,nsub112,nsamp1000,12,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.239649031391,p=0.0109291974524
# allr177,nsub112,nsamp1000,13,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.233103844542,p=0.0133819909207
# allr177,nsub112,nsamp1000,13,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.265612440471,p=0.0046479400988
# allr177,nsub112,nsamp1000,14,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.502700548024,p=1.62224250384e-08
# allr177,nsub112,nsamp1000,14,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.351343043589,p=0.000145640044492
# allr177,nsub112,nsamp1000,15,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.254936150461,p=0.00667376293022
# allr177,nsub112,nsamp1000,15,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.400512418836,p=1.21049518678e-05
# allr177,nsub112,nsamp1000,16,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.282015249162,p=0.00259120439404
# allr177,nsub112,nsamp1000,16,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.293049978602,p=0.00171444567039
# allr177,nsub112,nsamp1000,17,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.292318266532,p=0.00176294259406
# allr177,nsub112,nsamp1000,17,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.174278402304,p=0.0660934988269
# allr177,nsub112,nsamp1000,18,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.276644488875,p=0.00314967671944
# allr177,nsub112,nsamp1000,18,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.277385889959,p=0.00306663918584
# allr177,nsub112,nsamp1000,19,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.285810495238,p=0.00225218864182
# allr177,nsub112,nsamp1000,19,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.206164071905,p=0.029194978582
# allr177,nsub112,nsamp1000,20,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.148386754107,p=0.118425169882
# allr177,nsub112,nsamp1000,20,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.303440551808,p=0.00114464403907
# allr177,nsub112,nsamp1000,21,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00842060541571,p=0.929783581345
# allr177,nsub112,nsamp1000,21,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.322008888876,p=0.000535603210847
# allr177,nsub112,nsamp1000,22,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.083205368653,p=0.383100362817
# allr177,nsub112,nsamp1000,22,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.060121535836,p=0.528891795387
# allr177,nsub112,nsamp1000,23,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0412118154614,p=0.666151838607
# allr177,nsub112,nsamp1000,23,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.109989260312,p=0.248309587476
# allr177,nsub112,nsamp1000,24,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.396747221385,p=1.48571261471e-05
# allr177,nsub112,nsamp1000,24,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.30747692785,p=0.000974469847454
# allr177,nsub112,nsamp1000,25,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.306757458711,p=0.00100299878639
# allr177,nsub112,nsamp1000,25,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.223625567125,p=0.0177794446273
# allr177,nsub112,nsamp1000,26,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00803446697928,p=0.932995796014
# allr177,nsub112,nsamp1000,26,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.192721636192,p=0.0417684408406
# allr177,nsub112,nsamp1000,27,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.238016137566,p=0.0115010036936
# allr177,nsub112,nsamp1000,27,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.302890351634,p=0.00116982979475
# allr177,nsub112,nsamp1000,28,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.287301088466,p=0.00213039201375
# allr177,nsub112,nsamp1000,28,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.197011694538,p=0.0373390573682
# allr177,nsub112,nsamp1000,29,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.15426388759,p=0.104376354681
# allr177,nsub112,nsamp1000,29,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.144086526692,p=0.129599630862
# allr177,nsub112,nsamp1000,30,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.421429439218,p=3.7034056043e-06
# allr177,nsub112,nsamp1000,30,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.280662477227,p=0.00272274687741
# allr177,nsub112,nsamp1000,31,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.393428307044,p=1.7761084983e-05
# allr177,nsub112,nsamp1000,31,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.196997801707,p=0.0373527383753
# allr177,nsub112,nsamp1000,32,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.230637819342,p=0.0144235385721
# allr177,nsub112,nsamp1000,32,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.206753096141,p=0.0287270128614
# allr177,nsub112,nsamp1000,33,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.184023256326,p=0.0521016973274
# allr177,nsub112,nsamp1000,33,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.167863293283,p=0.0768697268667
# allr177,nsub112,nsamp1000,34,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.16159491892,p=0.0887214536447
# allr177,nsub112,nsamp1000,34,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0558192666006,p=0.558840581621
# allr177,nsub112,nsamp1000,35,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.151560036593,p=0.110668346107
# allr177,nsub112,nsamp1000,35,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.347862042423,p=0.000171137666479
# allr177,nsub112,nsamp1000,36,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.224979783399,p=0.0170832449689
# allr177,nsub112,nsamp1000,36,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.402071537702,p=1.11122961461e-05
# allr177,nsub112,nsamp1000,37,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.137503984429,p=0.148245298949
# allr177,nsub112,nsamp1000,37,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.222866007553,p=0.0181805637123
# allr177,nsub112,nsamp1000,38,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.184580241418,p=0.0513821533148
# allr177,nsub112,nsamp1000,38,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.38618134768,p=2.60557554188e-05
# allr177,nsub112,nsamp1000,39,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.239620429055,p=0.0109389949525
# allr177,nsub112,nsamp1000,39,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.261467521679,p=0.00535796821983
# allr177,nsub112,nsamp1000,40,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.180222280184,p=0.0572369207155
# allr177,nsub112,nsamp1000,40,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0570239484823,p=0.550373298838
# allr177,nsub112,nsamp1000,41,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.198959322271,p=0.0354623130236
# allr177,nsub112,nsamp1000,41,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.315929133526,p=0.000690520242814
# allr177,nsub112,nsamp1000,42,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.214788710929,p=0.0229527000685
# allr177,nsub112,nsamp1000,42,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.299552010291,p=0.0013337814278
# allr177,nsub112,nsamp1000,43,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.19392934213,p=0.0404792672631
# allr177,nsub112,nsamp1000,43,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.125321699053,p=0.187973220888
# allr177,nsub112,nsamp1000,44,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.448606437622,p=7.02778574707e-07
# allr177,nsub112,nsamp1000,44,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.313436770809,p=0.000765144964737
# allr177,nsub112,nsamp1000,45,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.217528979775,p=0.0212256742265
# allr177,nsub112,nsamp1000,45,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0405206046177,p=0.671424873385
# allr177,nsub112,nsamp1000,46,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.212398685071,p=0.0245559293311
# allr177,nsub112,nsamp1000,46,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.169986601927,p=0.0731566594274
# allr177,nsub112,nsamp1000,47,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.301347841681,p=0.00124315545009
# allr177,nsub112,nsamp1000,47,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.195975973337,p=0.0383705877019
# allr177,nsub112,nsamp1000,48,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0592980926275,p=0.534560980436
# allr177,nsub112,nsamp1000,48,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.234977580968,p=0.0126350356019
# allr177,nsub112,nsamp1000,49,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.262556984834,p=0.00516254960773
# allr177,nsub112,nsamp1000,49,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.320037471309,p=0.000581932273766
# allr177,nsub112,nsamp1000,50,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.371395234846,p=5.54069207587e-05
# allr177,nsub112,nsamp1000,50,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.293222778538,p=0.00170317080359
# allr177,nsub112,nsamp1000,51,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.275575216407,p=0.00327299736556
# allr177,nsub112,nsamp1000,51,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.214255341304,p=0.0233024905759
# allr177,nsub112,nsamp1000,52,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.271320401045,p=0.00380781978902
# allr177,nsub112,nsamp1000,52,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.239064633233,p=0.0111309124128
# allr177,nsub112,nsamp1000,53,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.349736998191,p=0.000156930691489
# allr177,nsub112,nsamp1000,53,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.109987173627,p=0.248318617088
# allr177,nsub112,nsamp1000,54,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.253277611821,p=0.00705047840178
# allr177,nsub112,nsamp1000,54,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.31904135179,p=0.000606715235308
# allr177,nsub112,nsamp1000,55,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.307573476485,p=0.00097069834909
# allr177,nsub112,nsamp1000,55,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.207833159322,p=0.0278854695019
# allr177,nsub112,nsamp1000,56,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.354033469396,p=0.000128401420386
# allr177,nsub112,nsamp1000,56,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.275427509305,p=0.00329036937714
# allr177,nsub112,nsamp1000,57,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.104846580538,p=0.271253930645
# allr177,nsub112,nsamp1000,57,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.223251811595,p=0.0179758566907
# allr177,nsub112,nsamp1000,58,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.284818531811,p=0.00233669294538
# allr177,nsub112,nsamp1000,58,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.302540120453,p=0.00118612383701
# allr177,nsub112,nsamp1000,59,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.384814790179,p=2.79802995091e-05
# allr177,nsub112,nsamp1000,59,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.267118302712,p=0.0044115842782
# allr177,nsub112,nsamp1000,60,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.234002931866,p=0.0130189026637
# allr177,nsub112,nsamp1000,60,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.265915231065,p=0.00459952624183
# allr177,nsub112,nsamp1000,61,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.217576162454,p=0.0211969434041
# allr177,nsub112,nsamp1000,61,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.252409510244,p=0.00725506762006
# allr177,nsub112,nsamp1000,62,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.212818468082,p=0.0242676013878
# allr177,nsub112,nsamp1000,62,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.121693326839,p=0.201182637608
# allr177,nsub112,nsamp1000,63,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.291513811567,p=0.00181769357901
# allr177,nsub112,nsamp1000,63,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.294731066466,p=0.00160757679487
# allr177,nsub112,nsamp1000,64,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.313998156603,p=0.00074771952492
# allr177,nsub112,nsamp1000,64,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.324540848851,p=0.000481073494185
# allr177,nsub112,nsamp1000,65,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.247024799739,p=0.00864553757824
# allr177,nsub112,nsamp1000,65,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.273236269374,p=0.00355799552727
# allr177,nsub112,nsamp1000,66,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.386416380243,p=2.57375375515e-05
# allr177,nsub112,nsamp1000,66,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.318366936148,p=0.00062404035626
# allr177,nsub112,nsamp1000,67,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.229394041043,p=0.0149751100342
# allr177,nsub112,nsamp1000,67,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0603810177534,p=0.527111606774
# allr177,nsub112,nsamp1000,68,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.421348257205,p=3.72104539922e-06
# allr177,nsub112,nsamp1000,68,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.364329944174,p=7.84558220128e-05
# allr177,nsub112,nsamp1000,69,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.311623306875,p=0.000824006790034
# allr177,nsub112,nsamp1000,69,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.34508495923,p=0.000194384482681
# allr177,nsub112,nsamp1000,70,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.187369725812,p=0.0479009089802
# allr177,nsub112,nsamp1000,70,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0838347476189,p=0.379499578739
# allr177,nsub112,nsamp1000,71,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.164621432362,p=0.0828295410288
# allr177,nsub112,nsamp1000,71,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.109716143344,p=0.249493359516
# allr177,nsub112,nsamp1000,72,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.289841764239,p=0.001936452363
# allr177,nsub112,nsamp1000,72,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.402361800109,p=1.09361691133e-05
# allr177,nsub112,nsamp1000,73,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.225500559183,p=0.016821865092
# allr177,nsub112,nsamp1000,73,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.385056765948,p=2.76300891411e-05
# allr177,nsub112,nsamp1000,74,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.230639738823,p=0.0144227011946
# allr177,nsub112,nsamp1000,74,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.210589455257,p=0.025832331434
# allr177,nsub112,nsamp1000,75,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.441789257094,p=1.08090581663e-06
# allr177,nsub112,nsamp1000,75,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.39194425528,p=1.92252050861e-05
# allr177,nsub112,nsamp1000,76,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.196252408915,p=0.0380929604458
# allr177,nsub112,nsamp1000,76,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.225576806457,p=0.0167838882809
# allr177,nsub112,nsamp1000,77,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.190856706146,p=0.0438263909485
# allr177,nsub112,nsamp1000,77,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.141634617139,p=0.136322944403
# allr177,nsub112,nsamp1000,78,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.152436428644,p=0.108597380336
# allr177,nsub112,nsamp1000,78,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.320507785447,p=0.000570557174287
# allr177,nsub112,nsamp1000,79,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.370286970961,p=5.85452584341e-05
# allr177,nsub112,nsamp1000,79,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.357540699236,p=0.000108770598057
# allr177,nsub112,nsamp1000,80,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.209443419205,p=0.0266697867803
# allr177,nsub112,nsamp1000,80,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.231598111521,p=0.014009854396
# allr177,nsub112,nsamp1000,81,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.255109738154,p=0.00663538556854
# allr177,nsub112,nsamp1000,81,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.331511670308,p=0.000356228846043
# allr177,nsub112,nsamp1000,82,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.298693517385,p=0.00137919408926
# allr177,nsub112,nsamp1000,82,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.364161209476,p=7.910248764e-05
# allr177,nsub112,nsamp1000,83,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0437666032269,p=0.646804682787
# allr177,nsub112,nsamp1000,83,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.202776369347,p=0.0320138479523
# allr177,nsub112,nsamp1000,84,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.505187104981,p=1.34235116886e-08
# allr177,nsub112,nsamp1000,84,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.309256553548,p=0.000907057862895
# allr177,nsub112,nsamp1000,85,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.308014774468,p=0.00095362898401
# allr177,nsub112,nsamp1000,85,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.185247298289,p=0.0505312287234
# allr177,nsub112,nsamp1000,86,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.276809552029,p=0.00313101654644
# allr177,nsub112,nsamp1000,86,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0830042575178,p=0.384255291408
# allr177,nsub112,nsamp1000,87,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.206175379632,p=0.0291859343212
# allr177,nsub112,nsamp1000,87,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.256521395331,p=0.00633048844031
# allr177,nsub112,nsamp1000,88,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.198825431891,p=0.0355887389924
# allr177,nsub112,nsamp1000,88,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.200619140819,p=0.0339261614754
# allr177,nsub112,nsamp1000,89,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.200500821861,p=0.0340337758218
# allr177,nsub112,nsamp1000,89,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.264860884826,p=0.00477008016434
# allr177,nsub112,nsamp1000,90,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.211961292691,p=0.0248594613743
# allr177,nsub112,nsamp1000,90,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.170769463502,p=0.0718247248361
# allr177,nsub112,nsamp1000,91,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.258369267161,p=0.00595019807179
# allr177,nsub112,nsamp1000,91,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.219372897725,p=0.0201274453294
# allr177,nsub112,nsamp1000,92,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.376910457409,p=4.19942714425e-05
# allr177,nsub112,nsamp1000,92,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.335207325278,p=0.000302893859648
# allr177,nsub112,nsamp1000,93,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.186012405193,p=0.0495696004078
# allr177,nsub112,nsamp1000,93,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.194973572625,p=0.039391578357
# allr177,nsub112,nsamp1000,94,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.327541655016,p=0.000423077932409
# allr177,nsub112,nsamp1000,94,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.325868855382,p=0.000454560281536
# allr177,nsub112,nsamp1000,95,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.29247288928,p=0.00175259195134
# allr177,nsub112,nsamp1000,95,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.25398184273,p=0.00688828013203
# allr177,nsub112,nsamp1000,96,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.13571516212,p=0.153645676718
# allr177,nsub112,nsamp1000,96,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.244266320132,p=0.0094449806743
# allr177,nsub112,nsamp1000,97,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.145464267765,p=0.125934855522
# allr177,nsub112,nsamp1000,97,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.227557829272,p=0.0158228776439
# allr177,nsub112,nsamp1000,98,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.265580953983,p=0.00465300057224
# allr177,nsub112,nsamp1000,98,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.396147211224,p=1.53466477713e-05
# allr177,nsub112,nsamp1000,99,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.346364354375,p=0.000183333320101
# allr177,nsub112,nsamp1000,99,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.281217369796,p=0.00266807849266
# allr177,nsub112,nsamp1000,100,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.362012964907,p=8.77818421407e-05
# allr177,nsub112,nsamp1000,100,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.346069164636,p=0.000185830139687

# %% [markdown]
# ### r227 recon

# %%
# Generate random samples from r227 subjects
newdf       = df[df['Subject'].isin([int(s) for s in subjects])]  
idx_smpl    = np.where(np.ravel(newdf['fMRI_3T_ReconVrs'].isin(['r227'])))[0]
print "{} subjects with r227 recon".format(idx_smpl.shape[0])
nRep = 1000
sampleFile = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_{}_r227.txt'.format(nSubPerSample,nRep,session))
if not op.isfile(sampleFile) or config.overwrite:
    samples = np.vstack([random.sample(idx_smpl,nSubPerSample) for i in range(nRep)])
    np.savetxt(sampleFile, samples)
else:
    samples = np.loadtxt(sampleFile,dtype=np.int16)
    
# do work    
outDir_ = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_r227'.format(nSubPerSample,nRep))
if not op.isdir(outDir_):
    mkdir(outDir_)
for iSample in range(500):#nRep):
    outDir = op.join(outDir_,'{}'.format(iSample+1))
    if not op.isdir(outDir):
        mkdir(outDir)
    #----------------------
    # prepare
    #----------------------
    config.queue        = True
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    config.overwrite    = False
    config.fmriFile_dn  = ''
    idx_smpl      = samples[iSample,:]
    # reorder indices!
    idx_smpl      = np.sort(idx_smpl)
    smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
    smpl_score    = score[idx_smpl]
    smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
    motFile = op.join(outDir,'RMS_{}.txt'.format(session))
    np.savetxt(motFile, smpl_motscore)
    fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
        session,config.pipelineName, config.parcellationName, config.release))
    overwrite = False
    if not op.isfile(fcMatFile) or overwrite:
        fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
        iSub= 0
        for config.subject in smpl_subjects:
            iRun = 0
            for config.fmriRun in fmriRuns:
                # set the global variable config
                runPipelinePar(launchSubproc=False)
                #print 'Found denoised data: {}'.format(config.fmriFile_dn)
                tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
                rstring = get_rcode(config.fmriFile_dn)
                fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
                fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
                iRun = iRun+1
            iSub = iSub + 1
        fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
        results = {}
        results['fcMats']        = fcMats_dn
        results['subjects']      = smpl_subjects
        results[config.outScore] = np.asarray(smpl_score)
        sio.savemat(fcMatFile, results)
    fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
    #----------------------
    # predict!
    #----------------------
    idcode           = session
    predict          = 'IQ'
    config.queue     = True
    launchSubproc    = False
    config.sgeopts   = '-l mem_free=2G' 
    config.overwrite = False
    newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
    # run the IQ prediction for each subject
    for model in ['IQ']:
        for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
            for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
                resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                    model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                    config.release))
                if not op.isfile(resFile) or config.overwrite:
                    runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                     regression=regression, outDir=outDir)
                    checkProgress(pause=10,verbose=False)
                    # merge cross-validation folds, save results
                    n_subs          = fcMats_dn.shape[-1]
                    predictions_pos = np.zeros([n_subs,1])
                    predictions_neg = np.zeros([n_subs,1])
                    iSub = 0
                    for subject in smpl_subjects:
                        subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                            model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                            config.release))
                        while not op.isfile(subResFile):
                            sleep(.1)
                        results = sio.loadmat(subResFile) 
                        if regression=='Finn':
                            predictions_neg[iSub] = results['pred_neg']
                            predictions_pos[iSub] = results['pred_pos']
                        else:
                            predictions_pos[iSub] = results['pred']
                        iSub = iSub + 1
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                    if regression=='Finn':
                        results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                    else:
                        results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                    if regression=='Finn':
                        if predict=='IQ':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                        elif predict=='motion':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                        results['rho_neg'] = rho
                        results['p_neg'] = p
                    # save result
                    sio.savemat(resFile,results)

                while not op.isfile(resFile):
                    sleep(.1)
                results = sio.loadmat(resFile)

                if regression=='Finn':
                    print ('{}r227,nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                          )
                    print ('{}r227,nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                          )
                else:
                    print ('{}r227,nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                          )
# Out:
# 712 subjects with r227 recon
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:54: RuntimeWarning: divide by zero encountered in arctanh
# allr227,nsub112,nsamp1000,1,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.199879275449,p=0.0346038274455
# allr227,nsub112,nsamp1000,1,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.168906113001,p=0.0750276272773
# allr227,nsub112,nsamp1000,2,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.030773983185,p=0.747373986985
# allr227,nsub112,nsamp1000,2,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0816763469866,p=0.391933742724
# allr227,nsub112,nsamp1000,3,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0426679190525,p=0.655097031234
# allr227,nsub112,nsamp1000,3,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.133257193292,p=0.161305009166
# allr227,nsub112,nsamp1000,4,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.103058400698,p=0.279557375237
# allr227,nsub112,nsamp1000,4,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.153156907218,p=0.106917602278
# allr227,nsub112,nsamp1000,5,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.209975306085,p=0.0262782826419
# allr227,nsub112,nsamp1000,5,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.24565671788,p=0.00903424504109
# allr227,nsub112,nsamp1000,6,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.236580617517,p=0.0120251511842
# allr227,nsub112,nsamp1000,6,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.116123047133,p=0.222740302551
# allr227,nsub112,nsamp1000,7,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.187588025301,p=0.0476369282263
# allr227,nsub112,nsamp1000,7,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.250902663544,p=0.00762269256152
# allr227,nsub112,nsamp1000,8,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0697423687094,p=0.464966025979
# allr227,nsub112,nsamp1000,8,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.236480637881,p=0.0120624222572
# allr227,nsub112,nsamp1000,9,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.424997242987,p=3.00175300998e-06
# allr227,nsub112,nsamp1000,9,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.128358779166,p=0.177411216927
# allr227,nsub112,nsamp1000,10,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.297519519225,p=0.00144357358419
# allr227,nsub112,nsamp1000,10,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0753091262499,p=0.430008335484
# allr227,nsub112,nsamp1000,11,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.143813311753,p=0.130335987116
# allr227,nsub112,nsamp1000,11,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00757634118887,p=0.936808252394
# allr227,nsub112,nsamp1000,12,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.252467765082,p=0.00724117577806
# allr227,nsub112,nsamp1000,12,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.365878893854,p=7.27456258337e-05
# allr227,nsub112,nsamp1000,13,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.199528465579,p=0.0349291093997
# allr227,nsub112,nsamp1000,13,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.14096175822,p=0.138213614822
# allr227,nsub112,nsamp1000,14,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00330945364232,p=0.972373868521
# allr227,nsub112,nsamp1000,14,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0143657698404,p=0.880500170175
# allr227,nsub112,nsamp1000,15,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0829497380078,p=0.384568744289
# allr227,nsub112,nsamp1000,15,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.127783943133,p=0.179376113736
# allr227,nsub112,nsamp1000,16,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.112224681986,p=0.238766208343
# allr227,nsub112,nsamp1000,16,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0802025948244,p=0.400562118205
# allr227,nsub112,nsamp1000,17,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.000468955490059,p=0.996084571568
# allr227,nsub112,nsamp1000,17,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0287379264343,p=0.763579321833
# allr227,nsub112,nsamp1000,18,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.104488902641,p=0.272901335563
# allr227,nsub112,nsamp1000,18,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.323798430376,p=0.000496508380204
# allr227,nsub112,nsamp1000,19,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.314954074028,p=0.000718882098619
# allr227,nsub112,nsamp1000,19,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.139461175854,p=0.142501815856
# allr227,nsub112,nsamp1000,20,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.466022446966,p=2.24044168671e-07
# allr227,nsub112,nsamp1000,20,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0945970669159,p=0.321140376529
# allr227,nsub112,nsamp1000,21,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.055449655322,p=0.561450901206
# allr227,nsub112,nsamp1000,21,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.125112847058,p=0.188716007212
# allr227,nsub112,nsamp1000,22,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.144144382182,p=0.129444110973
# allr227,nsub112,nsamp1000,22,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0776849271866,p=0.415560046321
# allr227,nsub112,nsamp1000,23,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.338495664862,p=0.000261741055269
# allr227,nsub112,nsamp1000,23,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0566539974197,p=0.552966913829
# allr227,nsub112,nsamp1000,24,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.
Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0333829066643,p=0.726769879465
# allr227,nsub112,nsamp1000,68,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00932028193276,p=0.922303801408
# allr227,nsub112,nsamp1000,68,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.044197385571,p=0.643565038511
# allr227,nsub112,nsamp1000,69,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.303502216308,p=0.00114185233248
# allr227,nsub112,nsamp1000,69,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0951723972017,p=0.31819276474
# allr227,nsub112,nsamp1000,70,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.267112036164,p=0.00441254517388
# allr227,nsub112,nsamp1000,70,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.232195383943,p=0.0137577985169
# allr227,nsub112,nsamp1000,71,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0708701778455,p=0.457760357676
# allr227,nsub112,nsamp1000,71,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.119563886119,p=0.209239354196
# allr227,nsub112,nsamp1000,72,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0728599785996,p=0.445199416416
# allr227,nsub112,nsamp1000,72,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.118903420246,p=0.211784424205
# allr227,nsub112,nsamp1000,73,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.128116311074,p=0.178238081422
# allr227,nsub112,nsamp1000,73,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0400234078518,p=0.675227741806
# allr227,nsub112,nsamp1000,74,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.18904021977,p=0.0459113845797
# allr227,nsub112,nsamp1000,74,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.158786523454,p=0.0944822038412
# allr227,nsub112,nsamp1000,75,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.11558435651,p=0.224908426931
# allr227,nsub112,nsamp1000,75,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0427886882426,p=0.654183443922
# allr227,nsub112,nsamp1000,76,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0860949799337,p=0.366738535722
# allr227,nsub112,nsamp1000,76,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0650324434755,p=0.495720040458
# allr227,nsub112,nsamp1000,77,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.178061462658,p=0.0603367378423
# allr227,nsub112,nsamp1000,77,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.000980236966337,p=0.991815861885
# allr227,nsub112,nsamp1000,78,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.184724476083,p=0.0511971662962
# allr227,nsub112,nsamp1000,78,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.282342235926,p=0.00256028112864
# allr227,nsub112,nsamp1000,79,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.170037990201,p=0.0730686222757
# allr227,nsub112,nsamp1000,79,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.225957564523,p=0.0165953513598
# allr227,nsub112,nsamp1000,80,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0816256917212,p=0.392228455685
# allr227,nsub112,nsamp1000,80,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0967718927566,p=0.310090170503
# allr227,nsub112,nsamp1000,81,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00776236711605,p=0.935259994377
# allr227,nsub112,nsamp1000,81,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0314501207927,p=0.742016363577
# allr227,nsub112,nsamp1000,82,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0992205352097,p=0.297948678645
# allr227,nsub112,nsamp1000,82,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.122624677421,p=0.197729948054
# allr227,nsub112,nsamp1000,83,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0619237157278,p=0.516590484306
# allr227,nsub112,nsamp1000,83,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0451232960284,p=0.636624479646
# allr227,nsub112,nsamp1000,84,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.189774876712,p=0.0450584171396
# allr227,nsub112,nsamp1000,84,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.110714906444,p=0.245183263421
# allr227,nsub112,nsamp1000,85,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0553100517898,p=0.562438339455
# allr227,nsub112,nsamp1000,85,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0481103763965,p=0.614449492499
# allr227,nsub112,nsamp1000,86,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0129375366469,p=0.892305374701
# allr227,nsub112,nsamp1000,86,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0312254362715,p=0.743795380359
# allr227,nsub112,nsamp1000,87,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.150165663731,p=0.114026575192
# allr227,nsub112,nsamp1000,87,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.167794342459,p=0.0769927960469
# allr227,nsub112,nsamp1000,88,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.162056263139,p=0.0878023947222
# allr227,nsub112,nsamp1000,88,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0725499088145,p=0.44714393897
# allr227,nsub112,nsamp1000,89,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.096484067053,p=0.31153821088
# allr227,nsub112,nsamp1000,89,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.339065862569,p=0.000255154612361
# allr227,nsub112,nsamp1000,90,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0144812478313,p=0.879546783245
# allr227,nsub112,nsamp1000,90,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.115680040143,p=0.224522236945
# allr227,nsub112,nsamp1000,91,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0707783021624,p=0.458345036654
# allr227,nsub112,nsamp1000,91,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0243637710613,p=0.798733000537
# allr227,nsub112,nsamp1000,92,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.199396169063,p=0.0350524456906
# allr227,nsub112,nsamp1000,92,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.179288450608,p=0.0585601371584
# allr227,nsub112,nsamp1000,93,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00750306047091,p=0.937418218748
# allr227,nsub112,nsamp1000,93,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0863124461996,p=0.365524818387
# allr227,nsub112,nsamp1000,94,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0774850904934,p=0.416764335651
# allr227,nsub112,nsamp1000,94,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.029640315334,p=0.756383970061
# allr227,nsub112,nsamp1000,95,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.166310765671,p=0.0796793849955
# allr227,nsub112,nsamp1000,95,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.131852682553,p=0.165807427527
# allr227,nsub112,nsamp1000,96,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.037170127282,p=0.697207244253
# allr227,nsub112,nsamp1000,96,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.040425601253,p=0.672150880627
# allr227,nsub112,nsamp1000,97,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.141044218385,p=0.13798084371
# allr227,nsub112,nsamp1000,97,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.176312814056,p=0.062944585899
# allr227,nsub112,nsamp1000,98,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0510486986604,p=0.592970321858
# allr227,nsub112,nsamp1000,98,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0814257135908,p=0.393393224941
# allr227,nsub112,nsamp1000,99,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00117182705914,p=0.990216321509
# allr227,nsub112,nsamp1000,99,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0625598046042,p=0.512283862361
# allr227,nsub112,nsamp1000,100,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.199755216138,p=0.0347185662605
# allr227,nsub112,nsamp1000,100,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.181547365402,p=0.0554014894935
# allr227,nsub112,nsamp1000,101,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.12527516722,p=0.188138527777
# allr227,nsub112,nsamp1000,101,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0898170608354,p=0.346307284036
# allr227,nsub112,nsamp1000,102,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.299166895727,p=0.00135398227114
# allr227,nsub112,nsamp1000,102,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.119115796285,p=0.210963648915
# allr227,nsub112,nsamp1000,103,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.119721626188,p=0.208634757257
# allr227,nsub112,nsamp1000,103,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.264958396485,p=0.00475407285002
# allr227,nsub112,nsamp1000,104,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.134397780952,p=0.157716162242
# allr227,nsub112,nsamp1000,104,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.107585329511,p=0.258862525084
# allr227,nsub112,nsamp1000,105,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.264197580282,p=0.00488024942141
# allr227,nsub112,nsamp1000,105,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.191818968783,p=0.0427542303519
# allr227,nsub112,nsamp1000,106,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.193910609504,p=0.0404990065026
# allr227,nsub112,nsamp1000,106,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.199980708684,p=0.0345102523502
# allr227,nsub112,nsamp1000,107,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.164642260877,p=0.0827901041258
# allr227,nsub112,nsamp1000,107,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0260874438805,p=0.784828004438
# allr227,nsub112,nsamp1000,108,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0468070630917,p=0.624083670876
# allr227,nsub112,nsamp1000,108,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0723073292343,p=0.448668529794
# allr227,nsub112,nsamp1000,109,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.107459462103,p=0.259423384798
# allr227,nsub112,nsamp1000,109,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.203980575041,p=0.0309865615119
# allr227,nsub112,nsamp1000,110,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.231395581922,p=0.014096232177
# allr227,nsub112,nsamp1000,110,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0839658301175,p=0.378752224828
# allr227,nsub112,nsamp1000,111,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0444642788423,p=0.641561243259
# allr227,nsub112,nsamp1000,111,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.108754320514,p=0.253693134832
# allr227,nsub112,nsamp1000,112,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.314335844701,p=0.000737413521832
# allr227,nsub112,nsamp1000,112,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0401025021692,p=0.67462222923
# allr227,nsub112,nsamp1000,113,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.173256844334,p=0.067722312242
# allr227,nsub112,nsamp1000,113,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0220830446459,p=0.817228298812
# allr227,nsub112,nsamp1000,114,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.290473450631,p=0.00189078434685
# allr227,nsub112,nsamp1000,114,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0948676421692,p=0.319751943644
# allr227,nsub112,nsamp1000,115,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.294866955309,p=0.00159920809065
# allr227,nsub112,nsamp1000,115,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.231156865055,p=0.014198638473
# allr227,nsub112,nsamp1000,116,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.17738991002,p=0.0613276124946
# allr227,nsub112,nsamp1000,116,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0959397022684,p=0.314288893906
# allr227,nsub112,nsamp1000,117,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.262839224574,p=0.00511297124805
# allr227,nsub112,nsamp1000,117,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.101730793419,p=0.285831256286
# allr227,nsub112,nsamp1000,118,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.128433751838,p=0.177156116373
# allr227,nsub112,nsamp1000,118,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.415042372262,p=5.3621291861e-06
# allr227,nsub112,nsamp1000,119,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.144061335946,p=0.129667390173
# allr227,nsub112,nsamp1000,119,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0194597050956,p=0.838626168839
# allr227,nsub112,nsamp1000,120,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0998572314247,p=0.294843677742
# allr227,nsub112,nsamp1000,120,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0530566070357,p=0.578490641224
# allr227,nsub112,nsamp1000,121,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0447100282895,p=0.639718466524
# allr227,nsub112,nsamp1000,121,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0437906946099,p=0.646623331445
# allr227,nsub112,nsamp1000,122,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0744036438446,p=0.435589784496
# allr227,nsub112,nsamp1000,122,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.152901121467,p=0.107511620077
# allr227,nsub112,nsamp1000,123,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0766454430513,p=0.421846497067
# allr227,nsub112,nsamp1000,123,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0475376795858,p=0.61867495744
# allr227,nsub112,nsamp1000,124,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0115820877726,p=0.903530826672
# allr227,nsub112,nsamp1000,124,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0126278265583,p=0.894868514361
# allr227,nsub112,nsamp1000,125,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0843320991484,p=0.376668718971
# allr227,nsub112,nsamp1000,125,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.17337011313,p=0.0675401219558
# allr227,nsub112,nsamp1000,126,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0394399052189,p=0.679701176683
# allr227,nsub112,nsamp1000,126,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0753680624949,p=0.429646474377
# allr227,nsub112,nsamp1000,127,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.181723186587,p=0.0551616285359
# allr227,nsub112,nsamp1000,127,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.427360627591,p=2.60837376843e-06
# allr227,nsub112,nsamp1000,128,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0291605930313,p=0.760206567874
# allr227,nsub112,nsamp1000,128,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0343500621415,p=0.719180072323
# allr227,nsub112,nsamp1000,129,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.125955114804,p=0.185733481536
# allr227,nsub112,nsamp1000,129,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0522156214502,p=0.584535301116
# allr227,nsub112,nsamp1000,130,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0702915566203,p=0.461449471797
# allr227,nsub112,nsamp1000,130,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0371316907457,p=0.697505098082
# allr227,nsub112,nsamp1000,131,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0265908875381,p=0.780779222773
# allr227,nsub112,nsamp1000,131,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.248142643474,p=0.00833895213251
# allr227,nsub112,nsamp1000,132,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.195005199232,p=0.0393590211357
# allr227,nsub112,nsamp1000,132,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.142119253956,p=0.134973404792
# allr227,nsub112,nsamp1000,133,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0419417025697,p=0.66060137118
# allr227,nsub112,nsamp1000,133,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.173009283928,p=0.0681218957224
# allr227,nsub112,nsamp1000,134,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.010921442655,p=0.909009148253
# allr227,nsub112,nsamp1000,134,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.163394308852,p=0.0851796131991
# allr227,nsub112,nsamp1000,135,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0185068378963,p=0.846428552407
# allr227,nsub112,nsamp1000,135,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.190350811553,p=0.0443989843422
# allr227,nsub112,nsamp1000,136,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.233414982775,p=0.013255354116
# allr227,nsub112,nsamp1000,136,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0383021570923,p=0.688455685256
# allr227,nsub112,nsamp1000,137,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.019366111668,p=0.839391862316
# allr227,nsub112,nsamp1000,137,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0906014834371,p=0.342094456081
# allr227,nsub112,nsamp1000,138,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.051461171944,p=0.58998250379
# allr227,nsub112,nsamp1000,138,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0825264139927,p=0.387007835748
# allr227,nsub112,nsamp1000,139,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.123466853844,p=0.194644842037
# allr227,nsub112,nsamp1000,139,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0663683495023,p=0.486889787125
# allr227,nsub112,nsamp1000,140,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.176526232487,p=0.0626214628754
# allr227,nsub112,nsamp1000,140,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.056134097878,p=0.556621732212
# allr227,nsub112,nsamp1000,141,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0354003407923,p=0.71096879708
# allr227,nsub112,nsamp1000,141,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0211861975923,p=0.824529375048
# allr227,nsub112,nsamp1000,142,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.103558404284,p=0.277218624318
# allr227,nsub112,nsamp1000,142,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.266593503749,p=0.00449270668062
# allr227,nsub112,nsamp1000,143,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.274688405275,p=0.00337854678525
# allr227,nsub112,nsamp1000,143,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.144974771748,p=0.127227679516
# allr227,nsub112,nsamp1000,144,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.246887025724,p=0.00868400366668
# allr227,nsub112,nsamp1000,144,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.105770041561,p=0.267031742712
# allr227,nsub112,nsamp1000,145,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.223938163007,p=0.0176165995393
# allr227,nsub112,nsamp1000,145,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.142113827824,p=0.134988458046
# allr227,nsub112,nsamp1000,146,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.396719345702,p=1.48795395961e-05
# allr227,nsub112,nsamp1000,146,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0212276925499,p=0.824191236094
# allr227,nsub112,nsamp1000,147,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.138095977836,p=0.146489962776
# allr227,nsub112,nsamp1000,147,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.140348155626,p=0.13995509412
# allr227,nsub112,nsamp1000,148,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.000137334885236,p=0.998853352033
# allr227,nsub112,nsamp1000,148,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0154075667376,p=0.871905433946
# allr227,nsub112,nsamp1000,149,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.144675950814,p=0.12802189725
# allr227,nsub112,nsamp1000,149,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.250680064135,p=0.00767837356596
# allr227,nsub112,nsamp1000,150,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.224653756192,p=0.0172486622424
# allr227,nsub112,nsamp1000,150,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.147739982435,p=0.120056537202
# allr227,nsub112,nsamp1000,151,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.331388070044,p=0.000358153905881
# allr227,nsub112,nsamp1000,151,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.026633396491,p=0.780437624926
# allr227,nsub112,nsamp1000,152,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.131642440558,p=0.166489342463
# allr227,nsub112,nsamp1000,152,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.161937584807,p=0.0880380910382
# allr227,nsub112,nsamp1000,153,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0492118129139,p=0.606358358056
# allr227,nsub112,nsamp1000,153,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.108838521841,p=0.253323544895
# allr227,nsub112,nsamp1000,154,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00920831121229,p=0.923234354027
# allr227,nsub112,nsamp1000,154,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0149296692757,p=0.87584625827
# allr227,nsub112,nsamp1000,155,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.075477939822,p=0.428972307539
# allr227,nsub112,nsamp1000,155,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.000805878547711,p=0.993271567452
# allr227,nsub112,nsamp1000,156,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0920652647756,p=0.334319930756
# allr227,nsub112,nsamp1000,156,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.114283963095,p=0.230203412708
# allr227,nsub112,nsamp1000,157,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.163067801605,p=0.0858137834739
# allr227,nsub112,nsamp1000,157,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.132681600555,p=0.163139037362
# allr227,nsub112,nsamp1000,158,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.131639136143,p=0.166500076829
# allr227,nsub112,nsamp1000,158,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0287673787284,p=0.763344156958
# allr227,nsub112,nsamp1000,159,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.289688977991,p=0.0019476470536
# allr227,nsub112,nsamp1000,159,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.2986349288,p=0.00138234399425
# allr227,nsub112,nsamp1000,160,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0572401444517,p=0.548860354159
# allr227,nsub112,nsamp1000,160,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.148093648448,p=0.119162339947
# allr227,nsub112,nsamp1000,161,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0384010536547,p=0.687693060245
# allr227,nsub112,nsamp1000,161,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.114820354934,p=0.228008817921
# allr227,nsub112,nsamp1000,162,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.21210195698,p=0.0247614985435
# allr227,nsub112,nsamp1000,162,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0687415655234,p=0.471411987719
# allr227,nsub112,nsamp1000,163,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.262974592557,p=0.00508934339217
# allr227,nsub112,nsamp1000,163,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.243716649766,p=0.00961183459159
# allr227,nsub112,nsamp1000,164,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.253603659896,p=0.00697496730857
# allr227,nsub112,nsamp1000,164,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.10894246258,p=0.252867821838
# allr227,nsub112,nsamp1000,165,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.23395565551,p=0.0130377784909
# allr227,nsub112,nsamp1000,165,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.150513951469,p=0.113180430527
# allr227,nsub112,nsamp1000,166,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0599757580195,p=0.529893233611
# allr227,nsub112,nsamp1000,166,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0390339672527,p=0.68281989313
# allr227,nsub112,nsamp1000,167,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.335755493115,p=0.00029564282126
# allr227,nsub112,nsamp1000,167,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.24995584548,p=0.00786202525606
# allr227,nsub112,nsamp1000,168,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0987696146388,p=0.300160686433
# allr227,nsub112,nsamp1000,168,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.135401794317,p=0.154606714829
# allr227,nsub112,nsamp1000,169,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0749039832252,p=0.432500582197
# allr227,nsub112,nsamp1000,169,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.07279489016,p=0.445607206995
# allr227,nsub112,nsamp1000,170,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.20425649945,p=0.0307551461506
# allr227,nsub112,nsamp1000,170,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.181336066591,p=0.0556908836691
# allr227,nsub112,nsamp1000,171,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0937121516613,p=0.325708320101
# allr227,nsub112,nsamp1000,171,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00449940616868,p=0.9624468521
# allr227,nsub112,nsamp1000,172,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.329694836591,p=0.000385510064823
# allr227,nsub112,nsamp1000,172,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.285845499992,p=0.00224925772055
# allr227,nsub112,nsamp1000,173,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.102028752413,p=0.284415087314
# allr227,nsub112,nsamp1000,173,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0128542492254,p=0.892994547801
# allr227,nsub112,nsamp1000,174,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.103109895073,p=0.279315902713
# allr227,nsub112,nsamp1000,174,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0691608194461,p=0.468705762972
# allr227,nsub112,nsamp1000,175,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.370594042179,p=5.76594742143e-05
# allr227,nsub112,nsamp1000,175,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0481066976678,p=0.614476594816
# allr227,nsub112,nsamp1000,176,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0731691452349,p=0.443265300846
# allr227,nsub112,nsamp1000,176,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.417879379604,p=4.55351685381e-06
# allr227,nsub112,nsamp1000,177,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.072665073934,p=0.446421155127
# allr227,nsub112,nsamp1000,177,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0867381616178,p=0.363155996061
# allr227,nsub112,nsamp1000,178,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0913934988794,p=0.337873800484
# allr227,nsub112,nsamp1000,178,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0997431516701,p=0.295398436481
# allr227,nsub112,nsamp1000,179,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0599186508151,p=0.530285797321
# allr227,nsub112,nsamp1000,179,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.268682756156,p=0.00417746670665
# allr227,nsub112,nsamp1000,180,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.215873136399,p=0.022255371034
# allr227,nsub112,nsamp1000,180,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.108303850027,p=0.255676699943
# allr227,nsub112,nsamp1000,181,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.149095046867,p=0.116658352866
# allr227,nsub112,nsamp1000,181,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.170742855975,p=0.0718696701071
# allr227,nsub112,nsamp1000,182,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0457663168618,p=0.631822833713
# allr227,nsub112,nsamp1000,182,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0548680401958,p=0.565570201825
# allr227,nsub112,nsamp1000,183,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.154080098152,p=0.104794965127
# allr227,nsub112,nsamp1000,183,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.143870358931,p=0.130181972322
# allr227,nsub112,nsamp1000,184,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.18778592549,p=0.0473986589776
# allr227,nsub112,nsamp1000,184,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0806842974894,p=0.397729588969
# allr227,nsub112,nsamp1000,185,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.038390663942,p=0.687773164141
# allr227,nsub112,nsamp1000,185,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.120288602427,p=0.206471924661
# allr227,nsub112,nsamp1000,186,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0325309085706,p=0.733477993585
# allr227,nsub112,nsamp1000,186,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.325551416258,p=0.000460772598839
# allr227,nsub112,nsamp1000,187,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.278306431242,p=0.00296628053578
# allr227,nsub112,nsamp1000,187,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0672485228278,p=0.481118030065
# allr227,nsub112,nsamp1000,188,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0359406943635,p=0.706756994086
# allr227,nsub112,nsamp1000,188,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.162826043355,p=0.0862857672133
# allr227,nsub112,nsamp1000,189,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.179379180233,p=0.058430486057
# allr227,nsub112,nsamp1000,189,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.346134804298,p=0.000185272226048
# allr227,nsub112,nsamp1000,190,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0844170718946,p=0.37618635355
# allr227,nsub112,nsamp1000,190,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.276212179514,p=0.00319902345849
# allr227,nsub112,nsamp1000,191,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.104475610288,p=0.272962687732
# allr227,nsub112,nsamp1000,191,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0524027474282,p=0.583187812265
# allr227,nsub112,nsamp1000,192,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0419374748005,p=0.660633468893
# allr227,nsub112,nsamp1000,192,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.264045034079,p=0.00490590489491
# allr227,nsub112,nsamp1000,193,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0422184807091,p=0.658501381524
# allr227,nsub112,nsamp1000,193,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.152576471948,p=0.108269270565
# allr227,nsub112,nsamp1000,194,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0956600940445,p=0.315707862946
# allr227,nsub112,nsamp1000,194,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0284210894135,p=0.766110496182
# allr227,nsub112,nsamp1000,195,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0876934787236,p=0.357874883152
# allr227,nsub112,nsamp1000,195,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.024455163231,p=0.797994108423
# allr227,nsub112,nsamp1000,196,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0412777552694,p=0.665649648335
# allr227,nsub112,nsamp1000,196,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0712062869519,p=0.455624946351
# allr227,nsub112,nsamp1000,197,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.171666046532,p=0.0703234503371
# allr227,nsub112,nsamp1000,197,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.108411755244,p=0.255200593519
# allr227,nsub112,nsamp1000,198,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0499284889982,p=0.601119041641
# allr227,nsub112,nsamp1000,198,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00490667321509,p=0.95905052427
# allr227,nsub112,nsamp1000,199,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.189398065367,p=0.0454942499708
# allr227,nsub112,nsamp1000,199,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.205036075571,p=0.0301092171112
# allr227,nsub112,nsamp1000,200,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0816355105075,p=0.39217131951
# allr227,nsub112,nsamp1000,200,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0381465047023,p=0.689656606478
# allr227,nsub112,nsamp1000,201,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.152564332161,p=0.108297682405
# allr227,nsub112,nsamp1000,201,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0237719002081,p=0.803522465426
# allr227,nsub112,nsamp1000,202,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.354201729165,p=0.000127388998373
# allr227,nsub112,nsamp1000,202,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.264670038537,p=0.00480154837935
# allr227,nsub112,nsamp1000,203,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.125495406488,p=0.187357049609
# allr227,nsub112,nsamp1000,203,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0342975436534,p=0.719591521381
# allr227,nsub112,nsamp1000,204,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0214554030231,p=0.822336216853
# allr227,nsub112,nsamp1000,204,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0649035010237,p=0.496576780632
# allr227,nsub112,nsamp1000,205,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0539154880891,p=0.572347435578
# allr227,nsub112,nsamp1000,205,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.101173466049,p=0.288492774921
# allr227,nsub112,nsamp1000,206,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0295700289473,p=0.75694367196
# allr227,nsub112,nsamp1000,206,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.394680540943,p=1.66078370248e-05
# allr227,nsub112,nsamp1000,207,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0151131942433,p=0.874332515394
# allr227,nsub112,nsamp1000,207,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.124349891292,p=0.19144761789
# allr227,nsub112,nsamp1000,208,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.195135880546,p=0.0392247333218
# allr227,nsub112,nsamp1000,208,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.105621079356,p=0.267709785222
# allr227,nsub112,nsamp1000,209,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.147564306421,p=0.120502632645
# allr227,nsub112,nsamp1000,209,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0398360839424,p=0.676662640859
# allr227,nsub112,nsamp1000,210,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.160744437143,p=0.0904357529396
# allr227,nsub112,nsamp1000,210,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.29677604112,p=0.00148574482081
# allr227,nsub112,nsamp1000,211,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.110044158527,p=0.24807211048
# allr227,nsub112,nsamp1000,211,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.106066442707,p=0.265686058644
# allr227,nsub112,nsamp1000,212,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0137344885454,p=0.885715016768
# allr227,nsub112,nsamp1000,212,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.272815070415,p=0.00361162163744
# ...
# allr227,nsub112,nsamp1000,430,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.115224807412,p=0.226363790915
# allr227,nsub112,nsamp1000,431,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.15476224783,p=0.103247847826
# allr227,nsub112,nsamp1000,431,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.190803780469,p=0.0438860050113
# allr227,nsub112,nsamp1000,432,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.169334419733,p=0.074281415264
# allr227,nsub112,nsamp1000,432,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.138467376613,p=0.145396751588
# allr227,nsub112,nsamp1000,433,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.035811513409,p=0.707763099722
# allr227,nsub112,nsamp1000,433,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.34133690738,p=0.000230413411852
# allr227,nsub112,nsamp1000,434,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.277912401196,p=0.00300887072149
# allr227,nsub112,nsamp1000,434,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.318911552118,p=0.000610014966939
# allr227,nsub112,nsamp1000,435,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.27184372408,p=0.00373806486416
# allr227,nsub112,nsamp1000,435,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.332497039426,p=0.000341219730449
# allr227,nsub112,nsamp1000,436,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0834849660624,p=0.381498197388
# allr227,nsub112,nsamp1000,436,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.235206868068,p=0.0125461796364
# allr227,nsub112,nsamp1000,437,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00897797816592,p=0.925148902323
# allr227,nsub112,nsamp1000,437,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0716662786145,p=0.452711450885
# allr227,nsub112,nsamp1000,438,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.265555654197,p=0.00465707028999
# allr227,nsub112,nsamp1000,438,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.193654705178,p=0.0407694690348
# allr227,nsub112,nsamp1000,439,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.138999693616,p=0.143840637889
# allr227,nsub112,nsamp1000,439,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.115280544494,p=0.226137748297
# allr227,nsub112,nsamp1000,440,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0672021145327,p=0.481421433108
# allr227,nsub112,nsamp1000,440,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.240264858131,p=0.0107201083218
# allr227,nsub112,nsamp1000,441,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.185448525952,p=0.0502768328567
# allr227,nsub112,nsamp1000,441,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.139939058523,p=0.141125380462
# allr227,nsub112,nsamp1000,442,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.136961011245,p=0.149869173693
# allr227,nsub112,nsamp1000,442,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.162902097328,p=0.0861370648873
# allr227,nsub112,nsamp1000,443,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0564531234951,p=0.554377651795
# allr227,nsub112,nsamp1000,443,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0889734029671,p=0.350874448053
# allr227,nsub112,nsamp1000,444,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.18457930981,p=0.0513833499325
# allr227,nsub112,nsamp1000,444,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00417940063245,p=0.965115953441
# allr227,nsub112,nsamp1000,445,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.173969433552,p=0.0665827376139
# allr227,nsub112,nsamp1000,445,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.112463611827,p=0.237761489032
# allr227,nsub112,nsamp1000,446,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.103579579385,p=0.277119869494
# allr227,nsub112,nsamp1000,446,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.114113848225,p=0.230902504896
# allr227,nsub112,nsamp1000,447,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0118897137948,p=0.900981403157
# allr227,nsub112,nsamp1000,447,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.338368799813,p=0.000263227712855
# allr227,nsub112,nsamp1000,448,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0231927433875,p=0.808216102884
# allr227,nsub112,nsamp1000,448,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0805154730006,p=0.398720960011
# allr227,nsub112,nsamp1000,449,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.212892321056,p=0.0242171760299
# allr227,nsub112,nsamp1000,449,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.02381840167,p=0.803145905983
# allr227,nsub112,nsamp1000,450,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.238308446241,p=0.0113967589636
# allr227,nsub112,nsamp1000,450,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.24594276727,p=0.00895172171794
# allr227,nsub112,nsamp1000,451,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0916146236576,p=0.336701341986
# allr227,nsub112,nsamp1000,451,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.156155367882,p=0.100143926646
# allr227,nsub112,nsamp1000,452,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.158709773571,p=0.0946436924098
# allr227,nsub112,nsamp1000,452,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.198851488658,p=0.0355641052193
# allr227,nsub112,nsamp1000,453,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.186495032353,p=0.0489708317315
# allr227,nsub112,nsamp1000,453,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.137465015699,p=0.148361399694
# allr227,nsub112,nsamp1000,454,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.295262820577,p=0.00157505369853
# allr227,nsub112,nsamp1000,454,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.10343469903,p=0.277796024014
# allr227,nsub112,nsamp1000,455,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.034562541389,p=0.717516252377
# allr227,nsub112,nsamp1000,455,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.137645187886,p=0.147825180443
# allr227,nsub112,nsamp1000,456,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.124780075711,p=0.189903922146
# allr227,nsub112,nsamp1000,456,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.059361194289,p=0.534125474887
# allr227,nsub112,nsamp1000,457,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.267773132077,p=0.00431219953609
# allr227,nsub112,nsamp1000,457,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.144033345438,p=0.129742712238
# allr227,nsub112,nsamp1000,458,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0288865431745,p=0.762392896217
# allr227,nsub112,nsamp1000,458,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.106624235366,p=0.263166144068
# allr227,nsub112,nsamp1000,459,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.134609218519,p=0.157057482895
# allr227,nsub112,nsamp1000,459,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0561293856478,p=0.556654911543
# allr227,nsub112,nsamp1000,460,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.266269083349,p=0.00454351915198
# allr227,nsub112,nsamp1000,460,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0816201558052,p=0.392260671745
# allr227,nsub112,nsamp1000,461,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.307956207837,p=0.000955878445403
# allr227,nsub112,nsamp1000,461,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.000775639525849,p=0.993524033195
# allr227,nsub112,nsamp1000,462,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.060817745887,p=0.524122236331
# allr227,nsub112,nsamp1000,462,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00299019816284,p=0.975037995183
# allr227,nsub112,nsamp1000,463,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0648201900641,p=0.497130742477
# allr227,nsub112,nsamp1000,463,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.260402287959,p=0.00555538301938
# allr227,nsub112,nsamp1000,464,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.149566428742,p=0.115493867467
# allr227,nsub112,nsamp1000,464,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.103990124279,p=0.275209873654
# allr227,nsub112,nsamp1000,465,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.215401437114,p=0.0225564274935
# allr227,nsub112,nsamp1000,465,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.144788721604,p=0.127721725221
# allr227,nsub112,nsamp1000,466,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.337682413042,p=0.000271407362222
# allr227,nsub112,nsamp1000,466,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.158309152424,p=0.0954901792338
# allr227,nsub112,nsamp1000,467,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0660156860503,p=0.489212696045
# allr227,nsub112,nsamp1000,467,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0344244603083,p=0.718597347247
# allr227,nsub112,nsamp1000,468,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0100241059084,p=0.916456998912
# allr227,nsub112,nsamp1000,468,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00830999287512,p=0.930703633715
# allr227,nsub112,nsamp1000,469,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0826254881477,p=0.38643616165
# allr227,nsub112,nsamp1000,469,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0125074296081,p=0.895865205124
# allr227,nsub112,nsamp1000,470,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.07984051994,p=0.402699055382
# allr227,nsub112,nsamp1000,470,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0220189547791,p=0.817749532607
# allr227,nsub112,nsamp1000,471,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.101988862861,p=0.284604406335
# allr227,nsub112,nsamp1000,471,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0231368891559,p=0.808669123106
# allr227,nsub112,nsamp1000,472,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0993945802084,p=0.297097774808
# allr227,nsub112,nsamp1000,472,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0279933337469,p=0.769531692304
# allr227,nsub112,nsamp1000,473,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.209301359936,p=0.0267751887018
# allr227,nsub112,nsamp1000,473,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.259511387748,p=0.0057254329013
# allr227,nsub112,nsamp1000,474,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0952107999969,p=0.317996638575
# allr227,nsub112,nsamp1000,474,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.271924186333,p=0.00372744207558
# allr227,nsub112,nsamp1000,475,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.245209503161,p=0.00916460616164
# allr227,nsub112,nsamp1000,475,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.325095566968,p=0.000469830343729
# allr227,nsub112,nsamp1000,476,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.13011821418,p=0.171495438401
# allr227,nsub112,nsamp1000,476,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0825511709656,p=0.386864936298
# allr227,nsub112,nsamp1000,477,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.207106377141,p=0.028449407454
# allr227,nsub112,nsamp1000,477,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.085046773971,p=0.372623449711
# allr227,nsub112,nsamp1000,478,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.082152410802,p=0.389170476938
# allr227,nsub112,nsamp1000,478,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.149119832188,p=0.116596898386
# allr227,nsub112,nsamp1000,479,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.171029447675,p=0.0713867551734
# allr227,nsub112,nsamp1000,479,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.040777765281,p=0.669461192701
# allr227,nsub112,nsamp1000,480,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.133239936298,p=0.161359771365
# allr227,nsub112,nsamp1000,480,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0105213619394,p=0.912328863086
# allr227,nsub112,nsamp1000,481,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.325513287395,p=0.000461524017271
# allr227,nsub112,nsamp1000,481,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.351931628095,p=0.000141694648565
# allr227,nsub112,nsamp1000,482,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.150907067982,p=0.112231247606
# allr227,nsub112,nsamp1000,482,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0658264852439,p=0.490461337967
# allr227,nsub112,nsamp1000,483,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.013870079556,p=0.884594515988
# allr227,nsub112,nsamp1000,483,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0840817533819,p=0.378092044803
# allr227,nsub112,nsamp1000,484,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.192859717402,p=0.0416193311145
# allr227,nsub112,nsamp1000,484,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0360577785174,p=0.705845538739
# allr227,nsub112,nsamp1000,485,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.354562215191,p=0.000125244874548
# allr227,nsub112,nsamp1000,485,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.645267571893,p=1.59513529756e-14
# allr227,nsub112,nsamp1000,486,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.116532475736,p=0.221102331246
# allr227,nsub112,nsamp1000,486,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.107627422108,p=0.258675147333
# allr227,nsub112,nsamp1000,487,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.428932761743,p=2.37428728528e-06
# allr227,nsub112,nsamp1000,487,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.314632738637,p=0.000728460192358
# allr227,nsub112,nsamp1000,488,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0266966134799,p=0.779929696612
# allr227,nsub112,nsamp1000,488,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.118750069017,p=0.212378498264
# allr227,nsub112,nsamp1000,489,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0182574582845,p=0.848473039608
# allr227,nsub112,nsamp1000,489,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0843362753362,p=0.376645003185
# allr227,nsub112,nsamp1000,490,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0419982205545,p=0.660172339245
# allr227,nsub112,nsamp1000,490,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.288369064727,p=0.00204682467042
# allr227,nsub112,nsamp1000,491,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.439452426873,p=1.25011505059e-06
# allr227,nsub112,nsamp1000,491,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.104697103225,p=0.271941579171
# allr227,nsub112,nsamp1000,492,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.340170518075,p=0.000242828609519
# allr227,nsub112,nsamp1000,492,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0211891754401,p=0.824505107743
# allr227,nsub112,nsamp1000,493,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0943393533058,p=0.322466417047
# allr227,nsub112,nsamp1000,493,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.176097897527,p=0.063271349542
# allr227,nsub112,nsamp1000,494,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0502652633607,p=0.598664009989
# allr227,nsub112,nsamp1000,494,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00177059492521,p=0.985217629158
# allr227,nsub112,nsamp1000,495,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0954435514031,p=0.316809630422
# allr227,nsub112,nsamp1000,495,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0788537887566,p=0.408556771873
# allr227,nsub112,nsamp1000,496,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0201138189993,p=0.833279068031
# allr227,nsub112,nsamp1000,496,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0231636099663,p=0.808452389145
# allr227,nsub112,nsamp1000,497,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0649340215477,p=0.496373920947
# allr227,nsub112,nsamp1000,497,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.10191529993,p=0.284953762409
# allr227,nsub112,nsamp1000,498,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0512517144149,p=0.591498889081
# allr227,nsub112,nsamp1000,498,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00142950528901,p=0.988065089215
# allr227,nsub112,nsamp1000,499,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.234322816361,p=0.0128918089888
# allr227,nsub112,nsamp1000,499,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.285053987781,p=0.00231637955164
# allr227,nsub112,nsamp1000,500,Ciric9,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.130335957572,p=0.17077356622
# allr227,nsub112,nsamp1000,500,Ciric9,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0819262090152,p=0.390481982097
