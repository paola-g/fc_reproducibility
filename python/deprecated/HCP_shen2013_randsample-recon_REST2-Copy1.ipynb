# %% [markdown]
# This notebook runs a defined pipeline on HCP subjects, on the Cedars-Sinai cluster.
# After it is done preprocessing all subjects, it runs the leave-one-out IQ prediction a la Finn.

# %% [markdown]
# # Load libraries & helper functions

# %%
from helpers import *
# %matplotlib inline

# %% [markdown]
# # Declare parameters

# %%
config.DATADIR                 = '/scratch/duboisjx/data/HCP/MRI'
# fMRI runs
session                        = 'REST2'
fmriRuns                       = ['rfMRI_'+session+'_LR','rfMRI_'+session+'_RL']
# use volume or surface data
config.fmriFileTemplate        = '#fMRIrun#.nii.gz'
#config.fmriFileTemplate        = '#fMRIrun#_Atlas.dtseries.nii'
#config.fmriFileTemplate        = '#fMRIrun#_Atlas_MSMAll.dtseries.nii'
config.overwrite               = False
config.pipelineName            = 'Ciric6'
config.Operations              = config.operationDict[config.pipelineName]
config.melodicFolder           = op.join('#fMRIrun#_hp2000.ica','filtered_func_data.ica') #the code #fMRIrun# will be replaced
config.movementRelativeRMSFile = 'Movement_RelativeRMS.txt'
config.movementRegressorsFile  = 'Movement_Regressors_dt.txt'
# parcellation for FC matrix
config.parcellationName        = 'shen2013'
config.parcellationFile        = '/scratch/duboisjx/data/parcellations/shenetal_neuroimage2013_new/shen_2mm_268_parcellation.nii.gz'
config.nParcels                = 268
config.maskParcelswithAll      = True
config.maskParcelswithGM       = False
# subject selection parameters
config.behavFile               = '/scratch/duboisjx/data/HCP/neuropsych/unrestricted_luckydjuju_6_7_2017_0_44_41.csv'
config.release                 = 'all'
config.outScore                = 'PMAT24_A_CR'
# submit jobs with sge
config.queue        = True

# do not alter the following lines
if config.maskParcelswithGM:
    config.parcellationName = config.parcellationName + '_GM'
tmp = config.fmriFileTemplate.split('.')
if tmp[1]=='nii':
    config.isCifti = False
elif tmp[1]=='dtseries':
    config.isCifti = True
else:
    print 'unknown file extension'

if config.pipelineName is 'SiegelB':
    config.useFIX              = True
else:
    config.useFIX              = False
config.preWhitening            = False

# whether to use memmapping (which involves unzipping)
# deprecated
config.useMemMap               = False

# %% [markdown]
# # Subject selection

# %%
df = pd.read_csv(config.behavFile)
# select subjects according to release
if config.release == 'Q2':
    ind = (df['Release'] == 'Q2') | (df['Release'] == 'Q1')
elif config.release == 'S500':
    ind = (df['Release'] == 'Q3') | (df['Release'] == 'S500')
elif config.release == 'Q2+S500':
    ind = (df['Release'] == 'Q2') | (df['Release'] == 'Q1') | (df['Release'] == 'Q3') | (df['Release'] == 'S500')
elif config.release == 'S900':
    ind = (df['Release'] == 'S900')
elif config.release == 'S1200':
    ind = (df['Release'] == 'S1200')
elif config.release == 'all':
    ind = ((df['Release'] == 'Q1') | (df['Release'] == 'Q2') | (df['Release'] == 'Q3') 
           | (df['Release'] == 'S500') | (df['Release'] == 'S900') | (df['Release'] == 'S1200'))
else:
    sys.exit("Invalid release code")
# select subjects that have completed all fMRI
ind = ind & ((df['fMRI_WM_PctCompl']==100) & (df['fMRI_Mot_PctCompl']==100) 
             & (df['fMRI_Lang_PctCompl']==100) & (df['fMRI_Emo_PctCompl']==100)         
             & (df['3T_RS-fMRI_PctCompl']==100) & (df['PMAT_Compl']==True))
df = df[ind]  
# check if either of the two subjects recommended for exclusion by HCP are still present
df = df[~df['Subject'].isin(['209733','528446'])]
df.index     = range(df.shape[0])
tmpAgeRanges = sorted(df['Age'].unique())
# list of all selected subjects
subjects     = [str(subject) for subject in df['Subject']]
# pull their IQ, Age, Gender
age          = [str(a) for a in df['Age']]
gender       = [str(g) for g in df['Gender']]
score        = np.asarray([s for s in df[config.outScore]])

print 'Selected', str(df.shape[0]), 'from the release',config.release
print 'Number of males is:', df[df['Gender']=='M'].shape[0]
try:
    print 'Age range is', tmpAgeRanges[0].split('-')[0], '-', tmpAgeRanges[-1].split('-')[1]
except:
    print 'Age range is', tmpAgeRanges[0].split('-')[0], '-', tmpAgeRanges[-1]
# Exclusion of high-motion subjects
# exclude subjects with >0.14 frame-to-frame head motion estimate averged across both rest runs (arbitrary threshold as in Finn et al 2015)
RelRMSMean = np.zeros([len(subjects), len(fmriRuns)],dtype=np.float32)
compSub    = np.zeros((len(subjects)),dtype=np.bool_)
keepSub    = np.zeros((len(subjects)),dtype=np.bool_)
iSub=0
for config.subject in subjects:
    i=0
    for config.fmriRun in fmriRuns:
        RelRMSMeanFile = op.join(buildpath(), 'Movement_RelativeRMS_mean.txt')
        #print RelRMSMeanFile
        if op.isfile(RelRMSMeanFile):
            with open(RelRMSMeanFile,'r') as tmp:
                RelRMSMean[iSub,i] = float(tmp.read())
        else:
            print RelRMSMeanFile+' File missing'
            break
        i=i+1
    if i==len(fmriRuns): # all RelRMSMeanFile exist
        compSub[iSub]=True
        if np.mean(RelRMSMean[iSub,:]) > 0.14:
            print config.subject, ': too much motion, exclude'
        else:
            keepSub[iSub]=True
    iSub=iSub+1

#### motion vs. score correlation
plt.scatter(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1),c='r')
plt.scatter(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1),c='b')
# fit a curve to the data using a least squares 1st order polynomial fit
z1 = np.polyfit(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1),1)
z2 = np.polyfit(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1),1)
p1 = np.poly1d(z1)
p2 = np.poly1d(z2)                
fit1 = p1(score[keepSub])
fit2 = p2(score[compSub])
# get the coordinates for the fit curve
c1_x = [np.min(score[keepSub]),np.max(score[keepSub])]
c1_y = p1(c1_x)
c2_x = [np.min(score[compSub]),np.max(score[compSub])]
c2_y = p2(c2_x)
# plot line of best fit
plt.plot(c2_x,c2_y,'r-',label='before exclusion')
plt.plot(c1_x,c1_y,'b-',label='after exclusion')
plt.xlabel('Score [{}]'.format(config.outScore))
plt.ylabel('RelRMSMean')
plt.legend(loc=0)
plt.show()
rho1,p1 = stats.pearsonr(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1))
rho2,p2 = stats.pearsonr(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1))            
print 'With all subjects: corr(IQ,motion) = {:.3f} (p = {:.3f})'.format(rho2,p2)
print 'After discarding high movers: corr(IQ,motion) = {:.3f} (p = {:.3f})'.format(rho1,p1)
    
subjects   = [subject for (subject, keep) in zip(subjects, keepSub) if keep]
age        = [a for (a, keep) in zip(age, keepSub) if keep]
gender     = [g for (g, keep) in zip(gender, keepSub) if keep]
score      = score[keepSub]
RelRMSMean = RelRMSMean[keepSub,:]
print 'Keeping {} subjects [{} M]'.format(len(subjects),sum([g=='M' for g in gender]))
# Out:
# Selected 957 from the release all
# Number of males is: 452
# Age range is 22 - Age range is 22 - 36+
# 102008 : too much motion, exclude
# 103515 : too much motion, exclude
# 104820 : too much motion, exclude
# 107725 : too much motion, exclude
# 108121 : too much motion, exclude
# 114924 : too much motion, exclude
# 116524 : too much motion, exclude
# 123420 : too much motion, exclude
# 123723 : too much motion, exclude
# 124220 : too much motion, exclude
# 124624 : too much motion, exclude
# 130518 : too much motion, exclude
# 136732 : too much motion, exclude
# 139435 : too much motion, exclude
# 140824 : too much motion, exclude
# 141119 : too much motion, exclude
# 147030 : too much motion, exclude
# 151324 : too much motion, exclude
# 151526 : too much motion, exclude
# 151728 : too much motion, exclude
# 153833 : too much motion, exclude
# 154330 : too much motion, exclude
# 156233 : too much motion, exclude
# 156637 : too much motion, exclude
# 160830 : too much motion, exclude
# 161327 : too much motion, exclude
# 161832 : too much motion, exclude
# 163331 : too much motion, exclude
# 163836 : too much motion, exclude
# 166640 : too much motion, exclude
# 168240 : too much motion, exclude
# /scratch/duboisjx/data/HCP/MRI/169040/MNINonLinear/Results/rfMRI_REST2_LR/Movement_RelativeRMS_mean.txt File missing
# 171532 : too much motion, exclude
# 175035 : too much motion, exclude
# 175439 : too much motion, exclude
# 176239 : too much motion, exclude
# 181636 : too much motion, exclude
# 182436 : too much motion, exclude
# 188751 : too much motion, exclude
# 191437 : too much motion, exclude
# 198249 : too much motion, exclude
# 199150 : too much motion, exclude
# 205220 : too much motion, exclude
# 207123 : too much motion, exclude
# 209127 : too much motion, exclude
# 209834 : too much motion, exclude
# 210415 : too much motion, exclude
# 223929 : too much motion, exclude
# 224022 : too much motion, exclude
# 227432 : too much motion, exclude
# 250427 : too much motion, exclude
# 295146 : too much motion, exclude
# 298051 : too much motion, exclude
# 308331 : too much motion, exclude
# 311320 : too much motion, exclude
# 346137 : too much motion, exclude
# 352132 : too much motion, exclude
# 366446 : too much motion, exclude
# 382242 : too much motion, exclude
# 390645 : too much motion, exclude
# 392447 : too much motion, exclude
# 453441 : too much motion, exclude
# 453542 : too much motion, exclude
# 465852 : too much motion, exclude
# 468050 : too much motion, exclude
# 555348 : too much motion, exclude
# 562345 : too much motion, exclude
# 581349 : too much motion, exclude
# 609143 : too much motion, exclude
# 680250 : too much motion, exclude
# 686969 : too much motion, exclude
# 735148 : too much motion, exclude
# 748662 : too much motion, exclude
# 779370 : too much motion, exclude
# 788876 : too much motion, exclude
# 810843 : too much motion, exclude
# 856968 : too much motion, exclude
# 919966 : too much motion, exclude
# 922854 : too much motion, exclude
# 937160 : too much motion, exclude
# 947668 : too much motion, exclude
# With all subjects: corr(IQ,motion) = -0.175 (p = 0.000)
# After discarding high movers: corr(IQ,motion) = -0.149 (p = 0.000)
# Keeping 876 subjects [414 M]

# %% [markdown]
# # Do work

# %% [markdown]
# ### preprocess everybody

# %%
config.scriptlist = []
keepSub = np.zeros((len(subjects)),dtype=np.bool_)
iSub    = 0
for config.subject in subjects:
    iRun = 0
    for config.fmriRun in fmriRuns:
        keepSub[iSub] = runPipelinePar(launchSubproc=False)
        if not keepSub[iSub]:
            break
        iRun=iRun+1
    iSub = iSub + 1
print 'Keeping {}/{} subjects'.format(np.sum(keepSub),len(subjects))
subjects   = [subject for (subject, keep) in zip(subjects, keepSub) if keep]
age        = [a for (a, keep) in zip(age, keepSub) if keep]
gender     = [g for (g, keep) in zip(gender, keepSub) if keep]
score      = score[keepSub]
RelRMSMean = RelRMSMean[keepSub,:]

# launch array job (if there is something to do)
if len(config.scriptlist)>0:
    print config.scriptlist
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    JobID = fnSubmitJobArrayFromJobList()
    print 'Running array job {} ({} sub jobs)'.format(JobID.split('.')[0],JobID.split('.')[1].split('-')[1].split(':')[0])
    config.joblist.append(JobID.split('.')[0])
    checkProgress(pause=60,verbose=False)
# Out:
# Keeping 876/876 subjects

# %% [markdown]
# ### run prediction in Q2 (sanity check)

# %%
#----------------------
# prepare
#----------------------
config.queue        = True
config.sgeopts      = '-l mem_free=25G -pe smp 6' 
config.overwrite    = False
config.fmriFile_dn  = ''
newdf = df[df['Subject'].isin([int(s) for s in subjects])]  
idx_smpl      = np.where(np.ravel(newdf['Release'].isin(['Q1','Q2'])))[0]
# define nSubPerSample
nSubPerSample = idx_smpl.shape[0]
outDir = op.join(config.DATADIR,'Results','samples_nsub{}_{}'.format(nSubPerSample,0))
if not op.isdir(outDir):
    mkdir(outDir)
smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
smpl_score    = score[idx_smpl]
smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
motFile = op.join(outDir,'RMS_{}.txt'.format(session))
np.savetxt(motFile, smpl_motscore)
fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
    session,config.pipelineName, config.parcellationName, config.release))
overwrite = False
if not op.isfile(fcMatFile) or overwrite:
    fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
    iSub= 0
    for config.subject in smpl_subjects:
        iRun = 0
        for config.fmriRun in fmriRuns:
            # set the global variable config
            runPipelinePar(launchSubproc=False)
            #print 'Found denoised data: {}'.format(config.fmriFile_dn)
            tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
            rstring = get_rcode(config.fmriFile_dn)
            fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
            fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
            iRun = iRun+1
        iSub = iSub + 1
    fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
    results = {}
    results['fcMats']        = fcMats_dn
    results['subjects']      = smpl_subjects
    results[config.outScore] = np.asarray(smpl_score)
    sio.savemat(fcMatFile, results)
fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
#----------------------
# predict!
#----------------------
idcode           = session
predict          = 'IQ'
config.queue     = True
launchSubproc    = False
config.sgeopts   = '-l mem_free=2G' 
config.overwrite = False
newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
# run the IQ prediction for each subject
for model in ['IQ']:
    for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
        for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
            resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                config.release))
            if not op.isfile(resFile) or config.overwrite:
                runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                 regression=regression, outDir=outDir)
                checkProgress(pause=10,verbose=False)
                # merge cross-validation folds, save results
                n_subs          = fcMats_dn.shape[-1]
                predictions_pos = np.zeros([n_subs,1])
                predictions_neg = np.zeros([n_subs,1])
                iSub = 0
                for subject in smpl_subjects:
                    subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                        model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                        config.release))
                    while not op.isfile(subResFile):
                        sleep(.1)
                    results = sio.loadmat(subResFile) 
                    if regression=='Finn':
                        predictions_neg[iSub] = results['pred_neg']
                        predictions_pos[iSub] = results['pred_pos']
                    else:
                        predictions_pos[iSub] = results['pred']
                    iSub = iSub + 1
                if predict=='IQ':
                    rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                elif predict=='motion':
                    rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                if regression=='Finn':
                    results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                else:
                    results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                if regression=='Finn':
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                    results['rho_neg'] = rho
                    results['p_neg'] = p
                # save result
                sio.savemat(resFile,results)

            while not op.isfile(resFile):
                sleep(.1)
            results = sio.loadmat(resFile)

            if regression=='Finn':
                print ('{},nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                    config.release,nSubPerSample,0,0,config.pipelineName,config.parcellationName,
                    config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                      )
                print ('{},nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                    config.release,nSubPerSample,0,0,config.pipelineName,config.parcellationName,
                    config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                      )
            else:
                print ('{},nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                    config.release,nSubPerSample,0,0,config.pipelineName,config.parcellationName,
                    config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                      )
# Out:
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:38: RuntimeWarning: divide by zero encountered in arctanh
# all,nsub112,nsamp0,0,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.50093211575,p=1.85444224171e-08
# all,nsub112,nsamp0,0,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.388616258284,p=2.29307674052e-05

# %% [markdown]
# ### run prediction in random samples (from all subjects)

# %%
# Generate random samples from all subjects
nRep = 1000
sampleFile = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_{}.txt'.format(nSubPerSample,nRep,session))
if not op.isfile(sampleFile) or config.overwrite:
    samples = np.vstack([random.sample(range(len(subjects)),nSubPerSample) for i in range(nRep)])
    np.savetxt(sampleFile, samples)
else:
    samples = np.loadtxt(sampleFile,dtype=np.int16)

#do work
outDir_ = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}'.format(nSubPerSample,nRep))
if not op.isdir(outDir_):
    mkdir(outDir_)
for iSample in range(500):#nRep):
    outDir = op.join(outDir_,'{}'.format(iSample+1))
    if not op.isdir(outDir):
        mkdir(outDir)
    #----------------------
    # prepare
    #----------------------
    config.queue        = True
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    config.overwrite    = False
    config.fmriFile_dn  = ''
    idx_smpl      = samples[iSample,:]
    # reorder indices!
    idx_smpl      = np.sort(idx_smpl)
    smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
    smpl_score    = score[idx_smpl]
    smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
    motFile = op.join(outDir,'RMS_{}.txt'.format(session))
    np.savetxt(motFile, smpl_motscore)
    fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
        session,config.pipelineName, config.parcellationName, config.release))
    overwrite = False
    if not op.isfile(fcMatFile) or overwrite:
        fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
        iSub= 0
        for config.subject in smpl_subjects:
            iRun = 0
            for config.fmriRun in fmriRuns:
                # set the global variable config
                runPipelinePar(launchSubproc=False)
                #print 'Found denoised data: {}'.format(config.fmriFile_dn)
                tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
                rstring = get_rcode(config.fmriFile_dn)
                fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
                fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
                iRun = iRun+1
            iSub = iSub + 1
        fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
        results = {}
        results['fcMats']        = fcMats_dn
        results['subjects']      = smpl_subjects
        results[config.outScore] = np.asarray(smpl_score)
        sio.savemat(fcMatFile, results)
    fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
    #----------------------
    # predict!
    #----------------------
    idcode           = session
    predict          = 'IQ'
    config.queue     = True
    launchSubproc    = False
    config.sgeopts   = '-l mem_free=2G' 
    config.overwrite = False
    newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
    # run the IQ prediction for each subject
    for model in ['IQ']:
        for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
            for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
                resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                    model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                    config.release))
                if not op.isfile(resFile) or config.overwrite:
                    runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                     regression=regression, outDir=outDir)
                    checkProgress(pause=10,verbose=False)
                    # merge cross-validation folds, save results
                    n_subs          = fcMats_dn.shape[-1]
                    predictions_pos = np.zeros([n_subs,1])
                    predictions_neg = np.zeros([n_subs,1])
                    iSub = 0
                    for subject in smpl_subjects:
                        subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                            model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                            config.release))
                        while not op.isfile(subResFile):
                            sleep(.1)
                        results = sio.loadmat(subResFile) 
                        if regression=='Finn':
                            predictions_neg[iSub] = results['pred_neg']
                            predictions_pos[iSub] = results['pred_pos']
                        else:
                            predictions_pos[iSub] = results['pred']
                        iSub = iSub + 1
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                    if regression=='Finn':
                        results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                    else:
                        results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                    if regression=='Finn':
                        if predict=='IQ':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                        elif predict=='motion':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                        results['rho_neg'] = rho
                        results['p_neg'] = p
                    # save result
                    sio.savemat(resFile,results)

                while not op.isfile(resFile):
                    sleep(.1)
                results = sio.loadmat(resFile)

                if regression=='Finn':
                    print ('{},nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                          )
                    print ('{},nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                          )
                else:
                    print ('{},nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                          )
# Out:
# all,nsub112,nsamp1000,1,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0910642871682,p=0.339624148771
# all,nsub112,nsamp1000,1,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.221480589495,p=0.0189323467111
# all,nsub112,nsamp1000,2,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.224131750608,p=0.0175163989948
# all,nsub112,nsamp1000,2,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0219481131233,p=0.818325770221
# all,nsub112,nsamp1000,3,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0056031899497,p=0.953243784309
# all,nsub112,nsamp1000,3,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0996051561165,p=0.296070416257
# all,nsub112,nsamp1000,4,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.121995107536,p=0.200059162677
# all,nsub112,nsamp1000,4,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0364489241777,p=0.702803642425
# all,nsub112,nsamp1000,5,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0173424074789,p=0.855983410566
# all,nsub112,nsamp1000,5,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.132821471169,p=0.162691943556
# all,nsub112,nsamp1000,6,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.27076211292,p=0.0038835192646
# all,nsub112,nsamp1000,6,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.159547741769,p=0.092892301286
# all,nsub112,nsamp1000,7,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.141803034215,p=0.135852803525
# all,nsub112,nsamp1000,7,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.121051624868,p=0.203586650679
# all,nsub112,nsamp1000,8,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00303203619399,p=0.974688848448
# all,nsub112,nsamp1000,8,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.140354251368,p=0.139937712152
# all,nsub112,nsamp1000,9,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0370865814824,p=0.697854719094
# all,nsub112,nsamp1000,9,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0921734877875,p=0.333749625434
# all,nsub112,nsamp1000,10,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.251399121897,p=0.00749979260947
# all,nsub112,nsamp1000,10,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.131971736902,p=0.165422197732
# all,nsub112,nsamp1000,11,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0576213915908,p=0.54619732022
# all,nsub112,nsamp1000,11,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.15139344998,p=0.111065456541
# all,nsub112,nsamp1000,12,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0273146598639,p=0.774968802586
# all,nsub112,nsamp1000,12,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.205378333206,p=0.029829288034
# all,nsub112,nsamp1000,13,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0337586186482,p=0.723818268721
# all,nsub112,nsamp1000,13,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0968809821643,p=0.309542493127
# all,nsub112,nsamp1000,14,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.293804172505,p=0.00166572805125
# all,nsub112,nsamp1000,14,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.124977163122,p=0.189199712482
# all,nsub112,nsamp1000,15,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.12143078756,p=0.202163710034
# all,nsub112,nsamp1000,15,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.202365852368,p=0.0323705694169
# all,nsub112,nsamp1000,16,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.137467486565,p=0.148354036134
# all,nsub112,nsamp1000,16,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0505828888277,p=0.596352689808
# all,nsub112,nsamp1000,17,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.161872490668,p=0.0881675821587
# all,nsub112,nsamp1000,17,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0688245374555,p=0.470875742048
# all,nsub112,nsamp1000,18,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00578497015112,p=0.951728704474
# all,nsub112,nsamp1000,18,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.19661962622,p=0.0377267672838
# all,nsub112,nsamp1000,19,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0210223700566,p=0.825864705168
# all,nsub112,nsamp1000,19,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.229872964226,p=0.0147605921
# all,nsub112,nsamp1000,20,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.253783135612,p=0.00693370807916
# all,nsub112,nsamp1000,20,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0784232916269,p=0.411128009455
# all,nsub112,nsamp1000,21,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0858836570879,p=0.367920336727
# all,nsub112,nsamp1000,21,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.264739958814,p=0.00478999794216
# all,nsub112,nsamp1000,22,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.112516498696,p=0.23753949414
# all,nsub112,nsamp1000,22,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.239380571599,p=0.0110214595926
# all,nsub112,nsamp1000,23,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0482957846379,p=0.613084206607
# all,nsub112,nsamp1000,23,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0824497596212,p=0.387450492945
# all,nsub112,nsamp1000,24,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0310796089535,p=0.744950741059
# all,nsub112,nsamp1000,24,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0748354287281,p=0.432923111177
# all,nsub112,nsamp1000,25,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0382329236256,p=0.688989754059
# all,nsub112,nsamp1000,25,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00423909059688,p=0.964618061405
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:51: RuntimeWarning: divide by zero encountered in arctanh
# all,nsub112,nsamp1000,26,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.301386829214,p=0.00124125170071
# all,nsub112,nsamp1000,26,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00438982434804,p=0.963360806621
# all,nsub112,nsamp1000,27,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.185435962393,p=0.0502926849033
# all,nsub112,nsamp1000,27,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00877253994206,p=0.926856883854
# all,nsub112,nsamp1000,28,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0
Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0350527882394,p=0.713682422329
# all,nsub112,nsamp1000,120,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.402121526461,p=1.10817745542e-05
# all,nsub112,nsamp1000,120,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.120010692042,p=0.207530048813
# all,nsub112,nsamp1000,121,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.141318004384,p=0.137210129162
# all,nsub112,nsamp1000,121,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0014314197549,p=0.988049106555
# all,nsub112,nsamp1000,122,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.188160538787,p=0.0469503355506
# all,nsub112,nsamp1000,122,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.361933186515,p=8.81206405839e-05
# all,nsub112,nsamp1000,123,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.241225195957,p=0.0104010470041
# all,nsub112,nsamp1000,123,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.280265511944,p=0.00276247328569
# all,nsub112,nsamp1000,124,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.220535193487,p=0.0194606141866
# all,nsub112,nsamp1000,124,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.199756216836,p=0.0347176394645
# all,nsub112,nsamp1000,125,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00117400181164,p=0.990198165226
# all,nsub112,nsamp1000,125,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.115038604182,p=0.227120093739
# all,nsub112,nsamp1000,126,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.112143655569,p=0.239107600936
# all,nsub112,nsamp1000,126,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0689519113469,p=0.47005317403
# all,nsub112,nsamp1000,127,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.20644792547,p=0.0289686622163
# all,nsub112,nsamp1000,127,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.213792556958,p=0.0236096787327
# all,nsub112,nsamp1000,128,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.078309762774,p=0.411807660663
# all,nsub112,nsamp1000,128,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0561855450344,p=0.556259549
# all,nsub112,nsamp1000,129,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.294338090441,p=0.00163200240034
# all,nsub112,nsamp1000,129,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.05783746925,p=0.544690814406
# all,nsub112,nsamp1000,130,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.128833165269,p=0.175801620946
# all,nsub112,nsamp1000,130,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0630801505394,p=0.508774657348
# all,nsub112,nsamp1000,131,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0212746403032,p=0.823808701567
# all,nsub112,nsamp1000,131,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0625495767129,p=0.512352963639
# all,nsub112,nsamp1000,132,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.17542401502,p=0.0643049090399
# all,nsub112,nsamp1000,132,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0547939523323,p=0.566095957
# all,nsub112,nsamp1000,133,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.17945600503,p=0.0583208886659
# all,nsub112,nsamp1000,133,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.183273935252,p=0.0530828050396
# all,nsub112,nsamp1000,134,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.127213320043,p=0.181342345848
# all,nsub112,nsamp1000,134,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.000888637573824,p=0.992580615405
# all,nsub112,nsamp1000,135,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.248408940688,p=0.00826734645669
# all,nsub112,nsamp1000,135,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.171526110453,p=0.0705560784346
# all,nsub112,nsamp1000,136,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0517156820532,p=0.588142337629
# all,nsub112,nsamp1000,136,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0730940823346,p=0.443734451019
# all,nsub112,nsamp1000,137,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.134180833936,p=0.158394148082
# all,nsub112,nsamp1000,137,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.108994497122,p=0.252639890681
# all,nsub112,nsamp1000,138,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0174983025425,p=0.854702957389
# all,nsub112,nsamp1000,138,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0309959403654,p=0.745613886346
# all,nsub112,nsamp1000,139,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.183205675756,p=0.0531729307281
# all,nsub112,nsamp1000,139,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.126080187405,p=0.185293538919
# all,nsub112,nsamp1000,140,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0117861045899,p=0.901839944111
# all,nsub112,nsamp1000,140,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.13571535306,p=0.153645092511
# all,nsub112,nsamp1000,141,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.141775722598,p=0.135928960646
# all,nsub112,nsamp1000,141,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0691191438283,p=0.468974393038
# all,nsub112,nsamp1000,142,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.200640512371,p=0.0339067540871
# all,nsub112,nsamp1000,142,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0
Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0313969928636,p=0.742436899871
# all,nsub112,nsamp1000,488,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.218270529707,p=0.0207779725383
# all,nsub112,nsamp1000,488,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.12049874275,p=0.205674399466
# all,nsub112,nsamp1000,489,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.277394947478,p=0.00306563702689
# all,nsub112,nsamp1000,489,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.170031810254,p=0.0730792050888
# all,nsub112,nsamp1000,490,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.155750452541,p=0.101038430896
# all,nsub112,nsamp1000,490,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.123807836053,p=0.193405695321
# all,nsub112,nsamp1000,491,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.281344968955,p=0.00265564810421
# all,nsub112,nsamp1000,491,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.135029057382,p=0.155755682632
# all,nsub112,nsamp1000,492,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.356629494631,p=0.000113583015052
# all,nsub112,nsamp1000,492,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.336368973538,p=0.000287718177338
# all,nsub112,nsamp1000,493,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.307519068422,p=0.000972822059202
# all,nsub112,nsamp1000,493,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.26655271717,p=0.00449906686432
# all,nsub112,nsamp1000,494,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.20812459219,p=0.0276620205998
# all,nsub112,nsamp1000,494,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.180038026819,p=0.0574960433402
# all,nsub112,nsamp1000,495,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.041278205066,p=0.665646223241
# all,nsub112,nsamp1000,495,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0834728311049,p=0.38156764953
# all,nsub112,nsamp1000,496,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0210461159219,p=0.825671125812
# all,nsub112,nsamp1000,496,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.274990380064,p=0.00334226704226
# all,nsub112,nsamp1000,497,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.122001438124,p=0.200035643527
# all,nsub112,nsamp1000,497,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.276313623565,p=0.00318738195507
# all,nsub112,nsamp1000,498,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0609436792406,p=0.523261827059
# all,nsub112,nsamp1000,498,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.10665728551,p=0.263017347223
# all,nsub112,nsamp1000,499,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.138182093623,p=0.146235930563
# all,nsub112,nsamp1000,499,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0890285123683,p=0.350574967305
# all,nsub112,nsamp1000,500,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.236205980357,p=0.0121653311462
# all,nsub112,nsamp1000,500,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.334670641763,p=0.000310151785099

# %% [markdown]
# ### The recon algorithm changed after Q3
# This could be important, and explain why the random sampling typically gives worse performance
# https://wiki.humanconnectome.org/display/PublicData/Ramifications+of+Image+Reconstruction+Version+Differences

# %% [markdown]
# ### r177 recon

# %%
# Generate random samples from r177 subjects
newdf       = df[df['Subject'].isin([int(s) for s in subjects])]  
idx_smpl  = np.where(np.ravel(newdf['fMRI_3T_ReconVrs'].isin(['r177'])))[0]
print "{} subjects with r177 recon".format(idx_smpl.shape[0])
nRep = 1000
sampleFile = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_{}_r177.txt'.format(nSubPerSample,nRep,session))
if not op.isfile(sampleFile) or config.overwrite:
    samples = np.vstack([random.sample(idx_smpl,nSubPerSample) for i in range(nRep)])
    np.savetxt(sampleFile, samples)
else:
    samples = np.loadtxt(sampleFile,dtype=np.int16)
    
# do work
outDir_ = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_r177'.format(nSubPerSample,nRep))
if not op.isdir(outDir_):
    mkdir(outDir_)
for iSample in range(100):#nRep):
    outDir = op.join(outDir_,'{}'.format(iSample+1))
    if not op.isdir(outDir):
        mkdir(outDir)
    #----------------------
    # prepare
    #----------------------
    config.queue        = True
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    config.overwrite    = False
    config.fmriFile_dn  = ''
    idx_smpl      = samples[iSample,:]
    # reorder indices!
    idx_smpl      = np.sort(idx_smpl)
    smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
    smpl_score    = score[idx_smpl]
    smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
    motFile = op.join(outDir,'RMS_{}.txt'.format(session))
    np.savetxt(motFile, smpl_motscore)
    fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
        session,config.pipelineName, config.parcellationName, config.release))
    overwrite = False
    if not op.isfile(fcMatFile) or overwrite:
        fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
        iSub= 0
        for config.subject in smpl_subjects:
            iRun = 0
            for config.fmriRun in fmriRuns:
                # set the global variable config
                runPipelinePar(launchSubproc=False)
                #print 'Found denoised data: {}'.format(config.fmriFile_dn)
                tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
                rstring = get_rcode(config.fmriFile_dn)
                fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
                fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
                iRun = iRun+1
            iSub = iSub + 1
        fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
        results = {}
        results['fcMats']        = fcMats_dn
        results['subjects']      = smpl_subjects
        results[config.outScore] = np.asarray(smpl_score)
        sio.savemat(fcMatFile, results)
    fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
    #----------------------
    # predict!
    #----------------------
    idcode           = session
    predict          = 'IQ'
    config.queue     = True
    launchSubproc    = False
    config.sgeopts   = '-l mem_free=2G' 
    config.overwrite = False
    newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
    # run the IQ prediction for each subject
    for model in ['IQ']:
        for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
            for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
                resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                    model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                    config.release))
                if not op.isfile(resFile) or config.overwrite:
                    runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                     regression=regression, outDir=outDir)
                    checkProgress(pause=10,verbose=False)
                    # merge cross-validation folds, save results
                    n_subs          = fcMats_dn.shape[-1]
                    predictions_pos = np.zeros([n_subs,1])
                    predictions_neg = np.zeros([n_subs,1])
                    iSub = 0
                    for subject in smpl_subjects:
                        subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                            model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                            config.release))
                        while not op.isfile(subResFile):
                            sleep(.1)
                        results = sio.loadmat(subResFile) 
                        if regression=='Finn':
                            predictions_neg[iSub] = results['pred_neg']
                            predictions_pos[iSub] = results['pred_pos']
                        else:
                            predictions_pos[iSub] = results['pred']
                        iSub = iSub + 1
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                    if regression=='Finn':
                        results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                    else:
                        results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                    if regression=='Finn':
                        if predict=='IQ':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                        elif predict=='motion':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                        results['rho_neg'] = rho
                        results['p_neg'] = p
                    # save result
                    sio.savemat(resFile,results)

                while not op.isfile(resFile):
                    sleep(.1)
                results = sio.loadmat(resFile)

                if regression=='Finn':
                    print ('{}r177,nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                          )
                    print ('{}r177,nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                          )
                else:
                    print ('{}r177,nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                          )
# Out:
# 159 subjects with r177 recon
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:54: RuntimeWarning: divide by zero encountered in arctanh
# allr177,nsub112,nsamp1000,1,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.228454393032,p=0.0154038760955
# allr177,nsub112,nsamp1000,1,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.125953491377,p=0.185739196939
# allr177,nsub112,nsamp1000,2,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.308546213302,p=0.000933437099495
# allr177,nsub112,nsamp1000,2,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.359584791725,p=9.86567442124e-05
# allr177,nsub112,nsamp1000,3,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.219806844924,p=0.0198762161382
# allr177,nsub112,nsamp1000,3,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.212310396223,p=0.0246169416905
# allr177,nsub112,nsamp1000,4,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.270491069238,p=0.00392075453996
# allr177,nsub112,nsamp1000,4,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.101373127882,p=0.287537401427
# allr177,nsub112,nsamp1000,5,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.302910778808,p=0.00116888577334
# allr177,nsub112,nsamp1000,5,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.320628792498,p=0.000567663690991
# allr177,nsub112,nsamp1000,6,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.156344319692,p=0.0997286471988
# allr177,nsub112,nsamp1000,6,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.264192966463,p=0.00488102362231
# allr177,nsub112,nsamp1000,7,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.174745487542,p=0.0653594397014
# allr177,nsub112,nsamp1000,7,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.112633953979,p=0.237046987177
# allr177,nsub112,nsamp1000,8,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.272795318843,p=0.00361415406612
# allr177,nsub112,nsamp1000,8,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.2350362203,p=0.0126122588843
# allr177,nsub112,nsamp1000,9,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.411856139264,p=6.43133100627e-06
# allr177,nsub112,nsamp1000,9,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.209828703934,p=0.0263856994711
# allr177,nsub112,nsamp1000,10,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.168219710953,p=0.076236082321
# allr177,nsub112,nsamp1000,10,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.318138689144,p=0.000630005858752
# allr177,nsub112,nsamp1000,11,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.33758688885,p=0.000272564164757
# allr177,nsub112,nsamp1000,11,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.342843288184,p=0.000215248257807
# allr177,nsub112,nsamp1000,12,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.263751898215,p=0.00495554294401
# allr177,nsub112,nsamp1000,12,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.293099588256,p=0.00171120182692
# allr177,nsub112,nsamp1000,13,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.17315347651,p=0.0678889248221
# allr177,nsub112,nsamp1000,13,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.36132169357,p=9.07582392443e-05
# allr177,nsub112,nsamp1000,14,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.394998047774,p=1.63268210067e-05
# allr177,nsub112,nsamp1000,14,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.32459506463,p=0.000479963823738
# allr177,nsub112,nsamp1000,15,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.268977402626,p=0.00413463866605
# allr177,nsub112,nsamp1000,15,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.31718429795,p=0.000655521064797
# allr177,nsub112,nsamp1000,16,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.154480097893,p=0.103885578512
# allr177,nsub112,nsamp1000,16,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.183905458818,p=0.0522549346016
# allr177,nsub112,nsamp1000,17,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.2312954743,p=0.0141390984571
# allr177,nsub112,nsamp1000,17,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0159007479026,p=0.867841863911
# allr177,nsub112,nsamp1000,18,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.189034005204,p=0.0459186567694
# allr177,nsub112,nsamp1000,18,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.244062133389,p=0.00950666228158
# allr177,nsub112,nsamp1000,19,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.281437216506,p=0.00264669411828
# allr177,nsub112,nsamp1000,19,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.280462644756,p=0.00274268036138
# allr177,nsub112,nsamp1000,20,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.169896371594,p=0.0733114469198
# allr177,nsub112,nsamp1000,20,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.301994078529,p=0.0012119406233
# allr177,nsub112,nsamp1000,21,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.239512945863,p=0.010975881304
# allr177,nsub112,nsamp1000,21,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.238498349256,p=0.0113294788348
# allr177,nsub112,nsamp1000,22,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00712359012875,p=0.940577385802
# allr177,nsub112,nsamp1000,22,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.10042855247,p=0.292075763171
# allr177,nsub112,nsamp1000,23,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.12267847828,p=0.197531812921
# allr177,nsub112,nsamp1000,23,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.108753117661,p=0.25369841727
# allr177,nsub112,nsamp1000,24,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.409834449083,p=7.21086207875e-06
# allr177,nsub112,nsamp1000,24,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.348290134163,p=0.000167792614666
# allr177,nsub112,nsamp1000,25,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.224485073359,p=0.0173347898992
# allr177,nsub112,nsamp1000,25,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.253471390846,p=0.00700551336197
# allr177,nsub112,nsamp1000,26,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0775611363062,p=0.416305816535
# allr177,nsub112,nsamp1000,26,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.181798951319,p=0.0550585313841
# allr177,nsub112,nsamp1000,27,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.361961547373,p=8.80000599459e-05
# allr177,nsub112,nsamp1000,27,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.245721449787,p=0.00901551189957
# allr177,nsub112,nsamp1000,28,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.181900284492,p=0.0549208895845
# allr177,nsub112,nsamp1000,28,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.111009702587,p=0.243920997433
# allr177,nsub112,nsamp1000,29,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.163845878476,p=0.0843087012811
# allr177,nsub112,nsamp1000,29,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0628457769438,p=0.510353729741
# allr177,nsub112,nsamp1000,30,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.272780685363,p=0.00361603131065
# allr177,nsub112,nsamp1000,30,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.307368645589,p=0.000978715616567
# allr177,nsub112,nsamp1000,31,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.37028552089,p=5.85494713281e-05
# allr177,nsub112,nsamp1000,31,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.389912047076,p=2.14147018298e-05
# allr177,nsub112,nsamp1000,32,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.301561494966,p=0.00123275537506
# allr177,nsub112,nsamp1000,32,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.184373855576,p=0.0516478112352
# allr177,nsub112,nsamp1000,33,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.379953681434,p=3.59613087965e-05
# allr177,nsub112,nsamp1000,33,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.210539299905,p=0.0258685070224
# allr177,nsub112,nsamp1000,34,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.204921529539,p=0.0302033990798
# allr177,nsub112,nsamp1000,34,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.250566979489,p=0.00770679802951
# allr177,nsub112,nsamp1000,35,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.312955180556,p=0.000780389022354
# allr177,nsub112,nsamp1000,35,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0616505437967,p=0.518445650814
# allr177,nsub112,nsamp1000,36,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.297653546572,p=0.00143608813693
# allr177,nsub112,nsamp1000,36,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.247967267791,p=0.00838640789014
# allr177,nsub112,nsamp1000,37,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.244015960644,p=0.00952065935989
# allr177,nsub112,nsamp1000,37,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.216283015166,p=0.021996575485
# allr177,nsub112,nsamp1000,38,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.199107706295,p=0.0353226431666
# allr177,nsub112,nsamp1000,38,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.276466520849,p=0.00316990772736
# allr177,nsub112,nsamp1000,39,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.178710126663,p=0.0593921008692
# allr177,nsub112,nsamp1000,39,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.189305060655,p=0.0456023598661
# allr177,nsub112,nsamp1000,40,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.240428658247,p=0.0106650879509
# allr177,nsub112,nsamp1000,40,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0395402713951,p=0.678930919546
# allr177,nsub112,nsamp1000,41,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.322044909225,p=0.000534789170176
# allr177,nsub112,nsamp1000,41,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.298883488974,p=0.00136902547429
# allr177,nsub112,nsamp1000,42,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.224674946479,p=0.0172378689242
# allr177,nsub112,nsamp1000,42,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.257676479252,p=0.00609032617236
# allr177,nsub112,nsamp1000,43,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.202691548356,p=0.0320872800796
# allr177,nsub112,nsamp1000,43,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0711854236341,p=0.455757336688
# allr177,nsub112,nsamp1000,44,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.315413729377,p=0.000705381573884
# allr177,nsub112,nsamp1000,44,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.323814733176,p=0.000496164610791
# allr177,nsub112,nsamp1000,45,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.086506715029,p=0.364442664168
# allr177,nsub112,nsamp1000,45,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.25890382201,p=0.00584404141503
# allr177,nsub112,nsamp1000,46,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.370225289419,p=5.8724712236e-05
# allr177,nsub112,nsamp1000,46,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.198222321751,p=0.0361629368528
# allr177,nsub112,nsamp1000,47,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.161345371622,p=0.0892217621051
# allr177,nsub112,nsamp1000,47,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.251927998396,p=0.00737079835307
# allr177,nsub112,nsamp1000,48,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0666086167843,p=0.485310577178
# allr177,nsub112,nsamp1000,48,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.178170808329,p=0.0601766445275
# allr177,nsub112,nsamp1000,49,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.215609785053,p=0.022423024159
# allr177,nsub112,nsamp1000,49,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.342651825866,p=0.000217123118818
# allr177,nsub112,nsamp1000,50,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.22446845869,p=0.0173432932611
# allr177,nsub112,nsamp1000,50,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.357217556494,p=0.00011045509748
# allr177,nsub112,nsamp1000,51,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.256938617642,p=0.00624278778116
# allr177,nsub112,nsamp1000,51,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.259186296589,p=0.00578862789778
# allr177,nsub112,nsamp1000,52,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.222970165296,p=0.0181251003524
# allr177,nsub112,nsamp1000,52,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.269663229774,p=0.00403646895657
# allr177,nsub112,nsamp1000,53,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.157816422183,p=0.0965394734252
# allr177,nsub112,nsamp1000,53,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.247334788837,p=0.00855953826557
# allr177,nsub112,nsamp1000,54,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.265767833765,p=0.00462303737151
# allr177,nsub112,nsamp1000,54,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.301413820626,p=0.00123993527407
# allr177,nsub112,nsamp1000,55,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.267588140819,p=0.00434007109873
# allr177,nsub112,nsamp1000,55,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.357842491072,p=0.00010721901331
# allr177,nsub112,nsamp1000,56,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.379124788255,p=3.75186612847e-05
# allr177,nsub112,nsamp1000,56,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.275054827594,p=0.00333456966733
# allr177,nsub112,nsamp1000,57,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.343688728937,p=0.000207147316363
# allr177,nsub112,nsamp1000,57,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.319154844237,p=0.000603843494162
# allr177,nsub112,nsamp1000,58,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.122374753389,p=0.198652236522
# allr177,nsub112,nsamp1000,58,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.281986738993,p=0.00259391651006
# allr177,nsub112,nsamp1000,59,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.331336710884,p=0.000358956636793
# allr177,nsub112,nsamp1000,59,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.363959732212,p=7.98811457854e-05
# allr177,nsub112,nsamp1000,60,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.242982263109,p=0.00983880153437
# allr177,nsub112,nsamp1000,60,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.302527011732,p=0.00118673769853
# allr177,nsub112,nsamp1000,61,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.364355452819,p=7.8358491639e-05
# allr177,nsub112,nsamp1000,61,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.272348936739,p=0.00367181290868
# allr177,nsub112,nsamp1000,62,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.221810539031,p=0.0187509122516
# allr177,nsub112,nsamp1000,62,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.160808821926,p=0.090305061003
# allr177,nsub112,nsamp1000,63,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.342410747292,p=0.000219505345222
# allr177,nsub112,nsamp1000,63,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.359425695407,p=9.94113488925e-05
# allr177,nsub112,nsamp1000,64,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.242341587029,p=0.0100406395601
# allr177,nsub112,nsamp1000,64,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.285402520206,p=0.00228660348154
# allr177,nsub112,nsamp1000,65,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.374953840743,p=4.63599841924e-05
# allr177,nsub112,nsamp1000,65,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.284275250833,p=0.00238417839368
# allr177,nsub112,nsamp1000,66,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.288356263625,p=0.00204780851602
# allr177,nsub112,nsamp1000,66,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.3191098703,p=0.000604979990545
# allr177,nsub112,nsamp1000,67,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.399340514545,p=1.29053875266e-05
# allr177,nsub112,nsamp1000,67,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.276248590484,p=0.00319484062371
# allr177,nsub112,nsamp1000,68,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.376647555146,p=4.25576327654e-05
# allr177,nsub112,nsamp1000,68,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.260325987668,p=0.00556976873712
# allr177,nsub112,nsamp1000,69,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.170205958952,p=0.0727814585264
# allr177,nsub112,nsamp1000,69,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.256633988777,p=0.00630671406476
# allr177,nsub112,nsamp1000,70,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.306970368801,p=0.000994477877856
# allr177,nsub112,nsamp1000,70,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.21502035404,p=0.0228021923277
# allr177,nsub112,nsamp1000,71,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0142147230462,p=0.881747471043
# allr177,nsub112,nsamp1000,71,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0646809729494,p=0.498057166828
# allr177,nsub112,nsamp1000,72,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.28246298196,p=0.00254894654194
# allr177,nsub112,nsamp1000,72,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.352953311935,p=0.000135080938772
# allr177,nsub112,nsamp1000,73,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.409547461634,p=7.32848641164e-06
# allr177,nsub112,nsamp1000,73,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.423939700609,p=3.19539186172e-06
# allr177,nsub112,nsamp1000,74,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0907500332259,p=0.341300309599
# allr177,nsub112,nsamp1000,74,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.164837638392,p=0.0824209047735
# allr177,nsub112,nsamp1000,75,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.339447991726,p=0.000250826726775
# allr177,nsub112,nsamp1000,75,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.338167789265,p=0.000265599231368
# allr177,nsub112,nsamp1000,76,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.296503047608,p=0.00150150831647
# allr177,nsub112,nsamp1000,76,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.232194036223,p=0.0137583627944
# allr177,nsub112,nsamp1000,77,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.178414847868,p=0.0598205980318
# allr177,nsub112,nsamp1000,77,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0251693695483,p=0.792226051154
# allr177,nsub112,nsamp1000,78,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.286102316363,p=0.00222785986847
# allr177,nsub112,nsamp1000,78,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.26872237734,p=0.00417168460516
# allr177,nsub112,nsamp1000,79,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.232634225043,p=0.0135751284013
# allr177,nsub112,nsamp1000,79,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.193653740048,p=0.0407704919215
# allr177,nsub112,nsamp1000,80,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0684538444463,p=0.473274092805
# allr177,nsub112,nsamp1000,80,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.291487853822,p=0.00181948564599
# allr177,nsub112,nsamp1000,81,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.349545287655,p=0.000158331408402
# allr177,nsub112,nsamp1000,81,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.350142251812,p=0.000154007512119
# allr177,nsub112,nsamp1000,82,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.391183081435,p=2.00194263156e-05
# allr177,nsub112,nsamp1000,82,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.353284920424,p=0.000132996749187
# allr177,nsub112,nsamp1000,83,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0123227567228,p=0.897394310541
# allr177,nsub112,nsamp1000,83,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0758166547381,p=0.426897898824
# allr177,nsub112,nsamp1000,84,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.475499466436,p=1.17052644634e-07
# allr177,nsub112,nsamp1000,84,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.325628323479,p=0.000459260386503
# allr177,nsub112,nsamp1000,85,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.181848237151,p=0.0549915505906
# allr177,nsub112,nsamp1000,85,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.131435027156,p=0.167164118583
# allr177,nsub112,nsamp1000,86,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.310223811624,p=0.000872232900665
# allr177,nsub112,nsamp1000,86,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.368473854859,p=6.40398674189e-05
# allr177,nsub112,nsamp1000,87,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.216326609406,p=0.0219692028137
# allr177,nsub112,nsamp1000,87,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.282724255103,p=0.00252457527557
# allr177,nsub112,nsamp1000,88,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.192152472487,p=0.0423877796824
# allr177,nsub112,nsamp1000,88,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.314987393344,p=0.000717895576099
# allr177,nsub112,nsamp1000,89,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.292417309454,p=0.00175630617451
# allr177,nsub112,nsamp1000,89,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.262586678441,p=0.00515731352437
# allr177,nsub112,nsamp1000,90,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.248962440299,p=0.0081202475399
# allr177,nsub112,nsamp1000,90,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.346481262665,p=0.000182353094851
# allr177,nsub112,nsamp1000,91,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.320962958271,p=0.000559743072951
# allr177,nsub112,nsamp1000,91,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0124286425986,p=0.89651752117
# allr177,nsub112,nsamp1000,92,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0600998887899,p=0.529040442287
# allr177,nsub112,nsamp1000,92,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.306007485603,p=0.00103354722414
# allr177,nsub112,nsamp1000,93,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.235273882964,p=0.0125203125211
# allr177,nsub112,nsamp1000,93,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.293506047158,p=0.0016848334921
# allr177,nsub112,nsamp1000,94,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.321782746396,p=0.000540739979091
# allr177,nsub112,nsamp1000,94,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.398969329926,p=1.31691265166e-05
# allr177,nsub112,nsamp1000,95,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.221069703866,p=0.0191604018381
# allr177,nsub112,nsamp1000,95,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.301913455295,p=0.0012157955511
# allr177,nsub112,nsamp1000,96,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.107250979719,p=0.26035419818
# allr177,nsub112,nsamp1000,96,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.183208236534,p=0.0531695473572
# allr177,nsub112,nsamp1000,97,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.307273261604,p=0.000982469629408
# allr177,nsub112,nsamp1000,97,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.238784467442,p=0.0112287676904
# allr177,nsub112,nsamp1000,98,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.482946382965,p=6.93067221093e-08
# allr177,nsub112,nsamp1000,98,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.33802267639,p=0.00026732353074
# allr177,nsub112,nsamp1000,99,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.271129028802,p=0.00383361808065
# allr177,nsub112,nsamp1000,99,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.306398805177,p=0.00101750335738
# allr177,nsub112,nsamp1000,100,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.301854565232,p=0.00121861838229
# allr177,nsub112,nsamp1000,100,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.35321378805,p=0.00013344128896

# %% [markdown]
# ### r227 recon

# %%
# Generate random samples from r227 subjects
newdf       = df[df['Subject'].isin([int(s) for s in subjects])]  
idx_smpl    = np.where(np.ravel(newdf['fMRI_3T_ReconVrs'].isin(['r227'])))[0]
print "{} subjects with r227 recon".format(idx_smpl.shape[0])
nRep = 1000
sampleFile = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_{}_r227.txt'.format(nSubPerSample,nRep,session))
if not op.isfile(sampleFile) or config.overwrite:
    samples = np.vstack([random.sample(idx_smpl,nSubPerSample) for i in range(nRep)])
    np.savetxt(sampleFile, samples)
else:
    samples = np.loadtxt(sampleFile,dtype=np.int16)
    
# do work    
outDir_ = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_r227'.format(nSubPerSample,nRep))
if not op.isdir(outDir_):
    mkdir(outDir_)
for iSample in range(500):#nRep):
    outDir = op.join(outDir_,'{}'.format(iSample+1))
    if not op.isdir(outDir):
        mkdir(outDir)
    #----------------------
    # prepare
    #----------------------
    config.queue        = True
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    config.overwrite    = False
    config.fmriFile_dn  = ''
    idx_smpl      = samples[iSample,:]
    # reorder indices!
    idx_smpl      = np.sort(idx_smpl)
    smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
    smpl_score    = score[idx_smpl]
    smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
    motFile = op.join(outDir,'RMS_{}.txt'.format(session))
    np.savetxt(motFile, smpl_motscore)
    fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
        session,config.pipelineName, config.parcellationName, config.release))
    overwrite = False
    if not op.isfile(fcMatFile) or overwrite:
        fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
        iSub= 0
        for config.subject in smpl_subjects:
            iRun = 0
            for config.fmriRun in fmriRuns:
                # set the global variable config
                runPipelinePar(launchSubproc=False)
                #print 'Found denoised data: {}'.format(config.fmriFile_dn)
                tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
                rstring = get_rcode(config.fmriFile_dn)
                fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
                fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
                iRun = iRun+1
            iSub = iSub + 1
        fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
        results = {}
        results['fcMats']        = fcMats_dn
        results['subjects']      = smpl_subjects
        results[config.outScore] = np.asarray(smpl_score)
        sio.savemat(fcMatFile, results)
    fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
    #----------------------
    # predict!
    #----------------------
    idcode           = session
    predict          = 'IQ'
    config.queue     = True
    launchSubproc    = False
    config.sgeopts   = '-l mem_free=2G' 
    config.overwrite = False
    newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
    # run the IQ prediction for each subject
    for model in ['IQ']:
        for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
            for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
                resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                    model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                    config.release))
                if not op.isfile(resFile) or config.overwrite:
                    runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                     regression=regression, outDir=outDir)
                    checkProgress(pause=10,verbose=False)
                    # merge cross-validation folds, save results
                    n_subs          = fcMats_dn.shape[-1]
                    predictions_pos = np.zeros([n_subs,1])
                    predictions_neg = np.zeros([n_subs,1])
                    iSub = 0
                    for subject in smpl_subjects:
                        subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                            model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                            config.release))
                        while not op.isfile(subResFile):
                            sleep(.1)
                        results = sio.loadmat(subResFile) 
                        if regression=='Finn':
                            predictions_neg[iSub] = results['pred_neg']
                            predictions_pos[iSub] = results['pred_pos']
                        else:
                            predictions_pos[iSub] = results['pred']
                        iSub = iSub + 1
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                    if regression=='Finn':
                        results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                    else:
                        results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                    if regression=='Finn':
                        if predict=='IQ':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                        elif predict=='motion':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                        results['rho_neg'] = rho
                        results['p_neg'] = p
                    # save result
                    sio.savemat(resFile,results)

                while not op.isfile(resFile):
                    sleep(.1)
                results = sio.loadmat(resFile)

                if regression=='Finn':
                    print ('{}r227,nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                          )
                    print ('{}r227,nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                          )
                else:
                    print ('{}r227,nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                          )
# Out:
# 712 subjects with r227 recon
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:54: RuntimeWarning: divide by zero encountered in arctanh
# allr227,nsub112,nsamp1000,1,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.149541478759,p=0.115555276242
# allr227,nsub112,nsamp1000,1,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.185853957898,p=0.0497674928148
# allr227,nsub112,nsamp1000,2,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0321249508915,p=0.736681367069
# allr227,nsub112,nsamp1000,2,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0692273921341,p=0.468276827236
# allr227,nsub112,nsamp1000,3,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.158619992827,p=0.0948328758464
# allr227,nsub112,nsamp1000,3,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0977969991621,p=0.304968561911
# allr227,nsub112,nsamp1000,4,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.113047517975,p=0.235318520556
# allr227,nsub112,nsamp1000,4,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.226319257311,p=0.0164179564793
# allr227,nsub112,nsamp1000,5,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.353073912912,p=0.000134319464257
# allr227,nsub112,nsamp1000,5,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.120463767416,p=0.20580698459
# allr227,nsub112,nsamp1000,6,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.336696897232,p=0.00028356315854
# allr227,nsub112,nsamp1000,6,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.313340697962,p=0.000768164066042
# allr227,nsub112,nsamp1000,7,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.267241124478,p=0.00439278883935
# allr227,nsub112,nsamp1000,7,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.251190354909,p=0.00755125843718
# allr227,nsub112,nsamp1000,8,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.224446854417,p=0.0173543556893
# allr227,nsub112,nsamp1000,8,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0260664573118,p=0.784996907659
# allr227,nsub112,nsamp1000,9,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.40137417313,p=1.15464242102e-05
# allr227,nsub112,nsamp1000,9,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.104783540989,p=0.271543791482
# allr227,nsub112,nsamp1000,10,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0413825266488,p=0.664852025292
# allr227,nsub112,nsamp1000,10,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.330493679507,p=0.000372372407269
# allr227,nsub112,nsamp1000,11,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.286262884798,p=0.00221457500606
# allr227,nsub112,nsamp1000,11,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.124808094631,p=0.189803692258
# allr227,nsub112,nsamp1000,12,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.295631847189,p=0.00155283575582
# allr227,nsub112,nsamp1000,12,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.33769831895,p=0.000271215182244
# allr227,nsub112,nsamp1000,13,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.225949015748,p=0.0165995641739
# allr227,nsub112,nsamp1000,13,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.130355932995,p=0.170707455429
# allr227,nsub112,nsamp1000,14,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0906623008179,p=0.341769185819
# allr227,nsub112,nsamp1000,14,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0863530517964,p=0.365298465759
# allr227,nsub112,nsamp1000,15,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.171348799411,p=0.0708517319675
# allr227,nsub112,nsamp1000,15,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0992286243182,p=0.297909095548
# allr227,nsub112,nsamp1000,16,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.18319546365,p=0.0531864250074
# allr227,nsub112,nsamp1000,16,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0200680113458,p=0.83365328138
# allr227,nsub112,nsamp1000,17,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0308249934622,p=0.746969364669
# allr227,nsub112,nsamp1000,17,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.317401047341,p=0.000649644578211
# allr227,nsub112,nsamp1000,18,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0701522604772,p=0.462340021843
# allr227,nsub112,nsamp1000,18,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0465794728986,p=0.625772616845
# allr227,nsub112,nsamp1000,19,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.151956861956,p=0.109726845639
# allr227,nsub112,nsamp1000,19,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0518847878548,p=0.586921112808
# allr227,nsub112,nsamp1000,20,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.332822977535,p=0.000336384921944
# allr227,nsub112,nsamp1000,20,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.211038674087,p=0.0255102424852
# allr227,nsub112,nsamp1000,21,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0661909045022,p=0.488057839227
# allr227,nsub112,nsamp1000,21,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.062702803746,p=0.511318239423
# allr227,nsub112,nsamp1000,22,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0656564313789,p=0.491585058973
# allr227,nsub112,nsamp1000,22,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0991610867603,p=0.298239688934
# allr227,nsub112,nsamp1000,23,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.067228735173,p=0.481247383058
# allr227,nsub112,nsamp1000,23,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.1415879403,p=0.136453463035
# allr227,nsub112,nsamp1000,24,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.152711192185,p=0.10795436302
# allr227,nsub112,nsamp1000,24,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.245791844594,p=0.00899517877523
# allr227,nsub112,nsamp1000,25,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.16557624387,p=0.0810370635565
# allr227,nsub112,nsamp1000,25,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.266426570476,p=0.00451878889833
# allr227,nsub112,nsamp1000,26,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.179949916921,p=0.0576202952693
# allr227,nsub112,nsamp1000,26,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0950557398342,p=0.318789022511
# allr227,nsub112,nsamp1000,27,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.207847118351,p=0.027874731875
# allr227,nsub112,nsamp1000,27,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.237127731173,p=0.0118229722232
# allr227,nsub112,nsamp1000,28,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0368706725246,p=0.699529004336
# allr227,nsub112,nsamp1000,28,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.12666990271,p=0.183229456457
# allr227,nsub112,nsamp1000,29,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.40208829799,p=1.11020540238e-05
# allr227,nsub112,nsamp1000,29,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.140074563349,p=0.14073692887
# allr227,nsub112,nsamp1000,30,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.14740614103,p=0.120905356939
# allr227,nsub112,nsamp1000,30,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.370231978559,p=5.87052263149e-05
# allr227,nsub112,nsamp1000,31,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0920825738623,p=0.334228675056
# allr227,nsub112,nsamp1000,31,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.2356352573,p=0.0123816266388
# allr227,nsub112,nsamp1000,32,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.149658138578,p=0.11526836177
# allr227,nsub112,nsamp1000,32,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.100105838023,p=0.293637114672
# allr227,nsub112,nsamp1000,33,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.137712130478,p=0.147626321929
# allr227,nsub112,nsamp1000,33,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.230528350527,p=0.0144713645822
# allr227,nsub112,nsamp1000,34,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.173045818867,p=0.0680628052482
# allr227,nsub112,nsamp1000,34,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.034871479526,p=0.715099468559
# allr227,nsub112,nsamp1000,35,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.134344051165,p=0.157883872005
# allr227,nsub112,nsamp1000,35,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.132963102811,p=0.162240150184
# allr227,nsub112,nsamp1000,36,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.29118107771,p=0.00184078643122
# allr227,nsub112,nsamp1000,36,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.255123072862,p=0.00663244559546
# allr227,nsub112,nsamp1000,37,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.187891311869,p=0.0472721789897
# allr227,nsub112,nsamp1000,37,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.276254760615,p=0.00319413229608
# allr227,nsub112,nsamp1000,38,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.161766107907,p=0.0883795343066
# allr227,nsub112,nsamp1000,38,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.294231943246,p=0.00163865755663
# allr227,nsub112,nsamp1000,39,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.304262861592,p=0.00110792282243
# allr227,nsub112,nsamp1000,39,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.367542634546,p=6.70455235801e-05
# allr227,nsub112,nsamp1000,40,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0522114352244,p=0.584565462337
# allr227,nsub112,nsamp1000,40,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.259978250072,p=0.00563575215074
# allr227,nsub112,nsamp1000,41,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.165318743961,p=0.0815173840725
# allr227,nsub112,nsamp1000,41,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.088417846278,p=0.353902435347
# allr227,nsub112,nsamp1000,42,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.390537207989,p=2.07174016477e-05
# allr227,nsub112,nsamp1000,42,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.247068394593,p=0.0086333973495
# allr227,nsub112,nsamp1000,43,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.122839414802,p=0.196939979452
# allr227,nsub112,nsamp1000,43,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.220424032102,p=0.0195235555056
# allr227,nsub112,nsamp1000,44,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.191100147801,p=0.0435530526439
# allr227,nsub112,nsamp1000,44,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0214044249674,p=0.822751419481
# allr227,nsub112,nsamp1000,45,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.12519179917,p=0.188434961862
# allr227,nsub112,nsamp1000,45,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00136492976321,p=0.988604191961
# allr227,nsub112,nsamp1000,46,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0169156164499,p=0.859490787591
# allr227,nsub112,nsamp1000,46,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.093269510911,p=0.328008794944
# allr227,nsub112,nsamp1000,47,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0211930543576,p=0.824473497622
# allr227,nsub112,nsamp1000,47,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0528008517285,p=0.580325837039
# allr227,nsub112,nsamp1000,48,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.327116352225,p=0.000430885967374
# allr227,nsub112,nsamp1000,48,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.134893199644,p=0.156176051738
# allr227,nsub112,nsamp1000,49,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.232369024136,p=0.0136852654032
# allr227,nsub112,nsamp1000,49,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0186606858974,p=0.84516776884
# allr227,nsub112,nsamp1000,50,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.157636995272,p=0.0969238239642
# allr227,nsub112,nsamp1000,50,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.161570785711,p=0.0887697398478
# allr227,nsub112,nsamp1000,51,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0803768237762,p=0.399536232268
# allr227,nsub112,nsamp1000,51,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.218605568846,p=0.020578374436
# allr227,nsub112,nsamp1000,52,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0826898718263,p=0.386064929953
# allr227,nsub112,nsamp1000,52,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.104614141427,p=0.272323740308
# allr227,nsub112,nsamp1000,53,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.140536060224,p=0.139420038176
# allr227,nsub112,nsamp1000,53,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.249954071012,p=0.0078624799611
# allr227,nsub112,nsamp1000,54,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.119948928318,p=0.207765735835
# allr227,nsub112,nsamp1000,54,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.220437922272,p=0.0195156810973
# allr227,nsub112,nsamp1000,55,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.075725629201,p=0.427454803705
# allr227,nsub112,nsamp1000,55,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0795065753594,p=0.404675931605
# allr227,nsub112,nsamp1000,56,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0859543109319,p=0.367524952459
# allr227,nsub112,nsamp1000,56,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0136242674451,p=0.886626031178
# allr227,nsub112,nsamp1000,57,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.197664620079,p=0.0367008148957
# allr227,nsub112,nsamp1000,57,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.14341680122,p=0.131410333765
# allr227,nsub112,nsamp1000,58,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0653603882183,p=0.493544568598
# allr227,nsub112,nsamp1000,58,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.133964158406,p=0.159073455482
# allr227,nsub112,nsamp1000,59,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.182421387951,p=0.0542175319006
# allr227,nsub112,nsamp1000,59,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0126444406891,p=0.894730989219
# allr227,nsub112,nsamp1000,60,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.164867195496,p=0.0823651663764
# allr227,nsub112,nsamp1000,60,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.054015574485,p=0.571633553787
# allr227,nsub112,nsamp1000,61,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.128605064499,p=0.176574222876
# allr227,nsub112,nsamp1000,61,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.182112529334,p=0.0546335123681
# allr227,nsub112,nsamp1000,62,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.213917217643,p=0.0235265920368
# allr227,nsub112,nsamp1000,62,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.235523820623,p=0.0124242492712
# allr227,nsub112,nsamp1000,63,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.272828085831,p=0.00360995374849
# allr227,nsub112,nsamp1000,63,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0934977789795,p=0.326821153989
# allr227,nsub112,nsamp1000,64,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.174019522311,p=0.0665032250186
# allr227,nsub112,nsamp1000,64,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0786809151439,p=0.409588160388
# allr227,nsub112,nsamp1000,65,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0685419629346,p=0.472703374225
# allr227,nsub112,nsamp1000,65,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0774823392712,p=0.416780929682
# allr227,nsub112,nsamp1000,66,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0411337114004,p=0.666746861499
# allr227,nsub112,nsamp1000,66,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0540403849475,p=0.571456653921
# allr227,nsub112,nsamp1000,67,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0857049662726,p=0.368921469303
# allr227,nsub112,nsamp1000,67,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.02668589844,p=0.780015782021
# allr227,nsub112,nsamp1000,68,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.123062623061,p=0.1961212669
# allr227,nsub112,nsamp1000,68,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0381453199245,p=0.68966575048
# allr227,nsub112,nsamp1000,69,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.207475959556,p=0.0281614352075
# allr227,nsub112,nsamp1000,69,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.166944408842,p=0.0785228751942
# allr227,nsub112,nsamp1000,70,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.146393351599,p=0.123508810205
# allr227,nsub112,nsamp1000,70,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.317974032187,p=0.000634341797938
# allr227,nsub112,nsamp1000,71,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.147936618966,p=0.119558730514
# allr227,nsub112,nsamp1000,71,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.1348897986,p=0.156186586079
# allr227,nsub112,nsamp1000,72,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00299106116983,p=0.975030793169
# allr227,nsub112,nsamp1000,72,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.117218351245,p=0.218377514705
# allr227,nsub112,nsamp1000,73,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.147886910886,p=0.119684421021
# allr227,nsub112,nsamp1000,73,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.20292704429,p=0.0318837543653
# allr227,nsub112,nsamp1000,74,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.285437642239,p=0.00228362217256
# allr227,nsub112,nsamp1000,74,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.367112434765,p=6.84780634128e-05
# allr227,nsub112,nsamp1000,75,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00179367140165,p=0.985024990078
# allr227,nsub112,nsamp1000,75,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.180015882253,p=0.0575272507528
# allr227,nsub112,nsamp1000,76,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.156825123845,p=0.0986780414498
# allr227,nsub112,nsamp1000,76,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.210233579494,p=0.0260899498069
# allr227,nsub112,nsamp1000,77,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.12854842151,p=0.176766465047
# allr227,nsub112,nsamp1000,77,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.216774543306,p=0.0216896355615
# allr227,nsub112,nsamp1000,78,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.212144522451,p=0.0247319197445
# allr227,nsub112,nsamp1000,78,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.288573251475,p=0.00203118933987
# allr227,nsub112,nsamp1000,79,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.263838016698,p=0.00494091383811
# allr227,nsub112,nsamp1000,79,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.246159290969,p=0.00888969831898
# allr227,nsub112,nsamp1000,80,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.13440037087,p=0.157708081554
# allr227,nsub112,nsamp1000,80,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.369316023472,p=6.14304126211e-05
# allr227,nsub112,nsamp1000,81,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.1411959503,p=0.137553308997
# allr227,nsub112,nsamp1000,81,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.131368439704,p=0.167381176129
# allr227,nsub112,nsamp1000,82,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.314590483957,p=0.000729728344596
# allr227,nsub112,nsamp1000,82,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.51217448989,p=7.81967544803e-09
# allr227,nsub112,nsamp1000,83,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0402296077741,p=0.673649597859
# allr227,nsub112,nsamp1000,83,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0568130412103,p=0.551851181869
# allr227,nsub112,nsamp1000,84,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.107890944049,p=0.25750417059
# allr227,nsub112,nsamp1000,84,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0105170747751,p=0.912364444592
# allr227,nsub112,nsamp1000,85,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.262461440134,p=0.00517942984374
# allr227,nsub112,nsamp1000,85,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.025734199974,p=0.787672292835
# allr227,nsub112,nsamp1000,86,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.116446669104,p=0.221444904295
# allr227,nsub112,nsamp1000,86,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0127924070141,p=0.893506321182
# allr227,nsub112,nsamp1000,87,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.311563933872,p=0.000826002164016
# allr227,nsub112,nsamp1000,87,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.217489545813,p=0.0212497123016
# allr227,nsub112,nsamp1000,88,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.282820727204,p=0.00251562973872
# allr227,nsub112,nsamp1000,88,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.225395033001,p=0.0168745476935
# allr227,nsub112,nsamp1000,89,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0912672865127,p=0.338544167936
# allr227,nsub112,nsamp1000,89,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.210090275783,p=0.0261943041841
# allr227,nsub112,nsamp1000,90,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.416768335038,p=4.85540445729e-06
# allr227,nsub112,nsamp1000,90,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.149281047896,p=0.11619778069
# allr227,nsub112,nsamp1000,91,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0340655892899,p=0.721409693938
# allr227,nsub112,nsamp1000,91,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0851720007886,p=0.371917372662
# allr227,nsub112,nsamp1000,92,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.184069843598,p=0.0520411965014
# allr227,nsub112,nsamp1000,92,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.041380111165,p=0.664870410127
# allr227,nsub112,nsamp1000,93,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0729798387042,p=0.444449020949
# allr227,nsub112,nsamp1000,93,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0527354569899,p=0.580795514582
# allr227,nsub112,nsamp1000,94,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0335908144141,p=0.725136049049
# allr227,nsub112,nsamp1000,94,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0752468082977,p=0.43039114964
# allr227,nsub112,nsamp1000,95,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.159603506542,p=0.0927766671442
# allr227,nsub112,nsamp1000,95,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.140655861802,p=0.139079716333
# allr227,nsub112,nsamp1000,96,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0120303972343,p=0.899815835587
# allr227,nsub112,nsamp1000,96,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0452111865612,p=0.635967277683
# allr227,nsub112,nsamp1000,97,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0630815809116,p=0.508765028095
# allr227,nsub112,nsamp1000,97,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.132808546245,p=0.162733219568
# allr227,nsub112,nsamp1000,98,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.302233243558,p=0.00120057057681
# allr227,nsub112,nsamp1000,98,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0655671219794,p=0.492175763631
# allr227,nsub112,nsamp1000,99,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.041461550457,p=0.664250665563
# allr227,nsub112,nsamp1000,99,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0815048588477,p=0.392931997869
# allr227,nsub112,nsamp1000,100,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0370962969343,p=0.697779413778
# allr227,nsub112,nsamp1000,100,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.144547575857,p=0.128364262415
# allr227,nsub112,nsamp1000,101,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.029329658896,p=0.758858726448
# allr227,nsub112,nsamp1000,101,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.100492443627,p=0.291767299667
# allr227,nsub112,nsamp1000,102,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.093420529347,p=0.327222762261
# allr227,nsub112,nsamp1000,102,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0574442774884,p=0.547433686923
# allr227,nsub112,nsamp1000,103,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.084557072408,p=0.37539243221
# allr227,nsub112,nsamp1000,103,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0827412655402,p=0.385768751671
# allr227,nsub112,nsamp1000,104,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.113685624044,p=0.232668888115
# allr227,nsub112,nsamp1000,104,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.238792906822,p=0.0112258090445
# allr227,nsub112,nsamp1000,105,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.239816193247,p=0.0108720911812
# allr227,nsub112,nsamp1000,105,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.209704548074,p=0.0264769620915
# allr227,nsub112,nsamp1000,106,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.141200083214,p=0.137541677802
# allr227,nsub112,nsamp1000,106,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0918792082745,p=0.335301844474
# allr227,nsub112,nsamp1000,107,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.108349184563,p=0.255476597847
# allr227,nsub112,nsamp1000,107,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.106574346965,p=0.263390857848
# allr227,nsub112,nsamp1000,108,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0850816017554,p=0.372426995063
# allr227,nsub112,nsamp1000,108,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0607583577772,p=0.524528239299
# allr227,nsub112,nsamp1000,109,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.190704906158,p=0.0439975552986
# allr227,nsub112,nsamp1000,109,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.128315785249,p=0.177557628867
# allr227,nsub112,nsamp1000,110,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.122790098515,p=0.197121200617
# allr227,nsub112,nsamp1000,110,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0868529055948,p=0.362519147228
# allr227,nsub112,nsamp1000,111,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0224462854051,p=0.814275625725
# allr227,nsub112,nsamp1000,111,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0757296684922,p=0.427430082002
# allr227,nsub112,nsamp1000,112,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.378714781428,p=3.83121277609e-05
# allr227,nsub112,nsamp1000,112,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.236062741668,p=0.0122193037318
# allr227,nsub112,nsamp1000,113,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.280209390746,p=0.00276813156146
# allr227,nsub112,nsamp1000,113,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.196407059994,p=0.0379383789284
# allr227,nsub112,nsamp1000,114,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.249206425108,p=0.00805614286328
# allr227,nsub112,nsamp1000,114,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0517016816576,p=0.588243495645
# allr227,nsub112,nsamp1000,115,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.113518038744,p=0.233362728864
# allr227,nsub112,nsamp1000,115,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.157057624556,p=0.0981731397851
# allr227,nsub112,nsamp1000,116,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.206065253344,p=0.0292741179171
# allr227,nsub112,nsamp1000,116,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.175445995702,p=0.064270980881
# allr227,nsub112,nsamp1000,117,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.194546657227,p=0.0398332668306
# allr227,nsub112,nsamp1000,117,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0627408136719,p=0.511061729556
# allr227,nsub112,nsamp1000,118,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0964520178782,p=0.311699720738
# allr227,nsub112,nsamp1000,118,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0430966466572,p=0.65185613318
# allr227,nsub112,nsamp1000,119,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.284953780774,p=0.00232500509155
# allr227,nsub112,nsamp1000,119,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.118158839077,p=0.214680000137
# allr227,nsub112,nsamp1000,120,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.065332227953,p=0.493731175971
# allr227,nsub112,nsamp1000,120,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.223726216491,p=0.0177268704748
# allr227,nsub112,nsamp1000,121,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0492718768583,p=0.605918483383
# allr227,nsub112,nsamp1000,121,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.166690350338,p=0.0789849479141
# allr227,nsub112,nsamp1000,122,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.027634306293,p=0.772406621799
# allr227,nsub112,nsamp1000,122,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0390896025344,p=0.68239214424
# allr227,nsub112,nsamp1000,123,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.194405683046,p=0.0399800265115
# allr227,nsub112,nsamp1000,123,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.277511804664,p=0.00305273388411
# allr227,nsub112,nsamp1000,124,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.157643581251,p=0.0969096948291
# allr227,nsub112,nsamp1000,124,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.198491535395,p=0.0359056736882
# allr227,nsub112,nsamp1000,125,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.123068662388,p=0.196099149292
# allr227,nsub112,nsamp1000,125,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.126994096745,p=0.182101917291
# allr227,nsub112,nsamp1000,126,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0694794142388,p=0.466654962509
# allr227,nsub112,nsamp1000,126,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0667742610339,p=0.484223438591
# allr227,nsub112,nsamp1000,127,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0123761306312,p=0.896952331686
# allr227,nsub112,nsamp1000,127,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.125923874704,p=0.185843487316
# allr227,nsub112,nsamp1000,128,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.156591063617,p=0.0991883928898
# allr227,nsub112,nsamp1000,128,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.132463837099,p=0.163836931928
# allr227,nsub112,nsamp1000,129,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.167683380569,p=0.0771911825697
# allr227,nsub112,nsamp1000,129,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.102115963742,p=0.284001468167
# allr227,nsub112,nsamp1000,130,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.213520357118,p=0.0237919738511
# allr227,nsub112,nsamp1000,130,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.207209046779,p=0.0283691591723
# allr227,nsub112,nsamp1000,131,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.142648345619,p=0.133511727123
# allr227,nsub112,nsamp1000,131,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.120424584918,p=0.205955591035
# allr227,nsub112,nsamp1000,132,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.261249167475,p=0.0053979180344
# allr227,nsub112,nsamp1000,132,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.261983611299,p=0.0052645899435
# allr227,nsub112,nsamp1000,133,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00785902968336,p=0.934455585382
# allr227,nsub112,nsamp1000,133,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0345776382714,p=0.717398086322
# allr227,nsub112,nsamp1000,134,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0129680369632,p=0.892053015722
# allr227,nsub112,nsamp1000,134,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.147440313667,p=0.120818257952
# allr227,nsub112,nsamp1000,135,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.135615015472,p=0.15395231873
# allr227,nsub112,nsamp1000,135,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.178040054942,p=0.0603681216639
# allr227,nsub112,nsamp1000,136,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0272936640868,p=0.775137182786
# allr227,nsub112,nsamp1000,136,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0416878247531,p=0.662529930913
# allr227,nsub112,nsamp1000,137,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.10718575713,p=0.26064586562
# allr227,nsub112,nsamp1000,137,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.146694930926,p=0.122729104445
# allr227,nsub112,nsamp1000,138,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0430571959005,p=0.652154085279
# allr227,nsub112,nsamp1000,138,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00161387109082,p=0.986525958939
# allr227,nsub112,nsamp1000,139,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0486007735469,p=0.610841247033
# allr227,nsub112,nsamp1000,139,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.120341326313,p=0.206271618996
# allr227,nsub112,nsamp1000,140,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.377257070963,p=4.12621891132e-05
# allr227,nsub112,nsamp1000,140,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.13381540605,p=0.159541071622
# allr227,nsub112,nsamp1000,141,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.114001735189,p=0.231364049448
# allr227,nsub112,nsamp1000,141,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00213827569562,p=0.982148391943
# allr227,nsub112,nsamp1000,142,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0745296041718,p=0.434810898454
# allr227,nsub112,nsamp1000,142,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.275040800887,p=0.00333624360859
# allr227,nsub112,nsamp1000,143,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.015639999622,p=0.869989879285
# allr227,nsub112,nsamp1000,143,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.164599586486,p=0.0828709203467
# allr227,nsub112,nsamp1000,144,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.23212014783,p=0.0137893300287
# allr227,nsub112,nsamp1000,144,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.236620142664,p=0.0120104445291
# allr227,nsub112,nsamp1000,145,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.11392563638,p=0.231677699407
# allr227,nsub112,nsamp1000,145,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0316903207357,p=0.740116000808
# allr227,nsub112,nsamp1000,146,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.172103353725,p=0.0696004736846
# allr227,nsub112,nsamp1000,146,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.297006964461,p=0.00147252815825
# allr227,nsub112,nsamp1000,147,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.191482800023,p=0.043126279076
# allr227,nsub112,nsamp1000,147,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.205743062526,p=0.0295334115883
# allr227,nsub112,nsamp1000,148,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.234623391533,p=0.0127733750702
# allr227,nsub112,nsamp1000,148,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.196902346091,p=0.0374468524063
# allr227,nsub112,nsamp1000,149,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.162106103156,p=0.0877035617548
# allr227,nsub112,nsamp1000,149,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.225590045556,p=0.0167773017944
# allr227,nsub112,nsamp1000,150,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0974914429895,p=0.306489347576
# allr227,nsub112,nsamp1000,150,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0895071672981,p=0.347980543107
# allr227,nsub112,nsamp1000,151,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.234521981803,p=0.0128132263796
# allr227,nsub112,nsamp1000,151,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0615950700717,p=0.518822798663
# allr227,nsub112,nsamp1000,152,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.180887878571,p=0.0563088327977
# allr227,nsub112,nsamp1000,152,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.130216160288,p=0.171170445005
# allr227,nsub112,nsamp1000,153,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.268163191788,p=0.00425395542716
# allr227,nsub112,nsamp1000,153,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.105522254479,p=0.268160257303
# allr227,nsub112,nsamp1000,154,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0777774764059,p=0.415002998279
# allr227,nsub112,nsamp1000,154,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.128997256902,p=0.175247364664
# allr227,nsub112,nsamp1000,155,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.148610510682,p=0.117864792924
# allr227,nsub112,nsamp1000,155,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.190400005599,p=0.0443430325052
# allr227,nsub112,nsamp1000,156,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0865165866619,p=0.364387728046
# allr227,nsub112,nsamp1000,156,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0739025501377,p=0.43869618707
# allr227,nsub112,nsamp1000,157,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.290199951057,p=0.00191043598764
# allr227,nsub112,nsamp1000,157,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.241478386383,p=0.0103183281992
# allr227,nsub112,nsamp1000,158,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0975129305996,p=0.306382239717
# allr227,nsub112,nsamp1000,158,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0182805824994,p=0.848283417996
# allr227,nsub112,nsamp1000,159,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.110116862838,p=0.247757849738
# allr227,nsub112,nsamp1000,159,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.241034086955,p=0.0104638682828
# allr227,nsub112,nsamp1000,160,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.123678688818,p=0.193874348928
# allr227,nsub112,nsamp1000,160,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.181307775082,p=0.0557297257457
# allr227,nsub112,nsamp1000,161,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.043201882341,p=0.651061608192
# allr227,nsub112,nsamp1000,161,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.18534552151,p=0.0504069204706
# allr227,nsub112,nsamp1000,162,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0324366420129,p=0.734221436466
# allr227,nsub112,nsamp1000,162,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.178136713692,p=0.0602265252744
# allr227,nsub112,nsamp1000,163,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.126777403044,p=0.182855008828
# allr227,nsub112,nsamp1000,163,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.235706141536,p=0.0123545811399
# allr227,nsub112,nsamp1000,164,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0286749351268,p=0.764082354604
# allr227,nsub112,nsamp1000,164,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0508576580607,p=0.594356469162
# allr227,nsub112,nsamp1000,165,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0509171438834,p=0.5939246969
# allr227,nsub112,nsamp1000,165,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0236950371463,p=0.804144985561
# allr227,nsub112,nsamp1000,166,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0350764783979,p=0.713497340055
# allr227,nsub112,nsamp1000,166,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0361280024117,p=0.705299072101
# allr227,nsub112,nsamp1000,167,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.316946123783,p=0.000662034606255
# allr227,nsub112,nsamp1000,167,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.227457993924,p=0.01587014096
# allr227,nsub112,nsamp1000,168,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0143314132842,p=0.880783851132
# allr227,nsub112,nsamp1000,168,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.204508822074,p=0.0305448081847
# allr227,nsub112,nsamp1000,169,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.31767783826,p=0.000642210504661
# allr227,nsub112,nsamp1000,169,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0908325298772,p=0.340859785997
# allr227,nsub112,nsamp1000,170,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.24644257884,p=0.00880912211594
# allr227,nsub112,nsamp1000,170,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0873903768358,p=0.359545281458
# allr227,nsub112,nsamp1000,171,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0531739420448,p=0.577649594343
# allr227,nsub112,nsamp1000,171,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.067791894624,p=0.477573285045
# allr227,nsub112,nsamp1000,172,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.295270987759,p=0.00157455887066
# allr227,nsub112,nsamp1000,172,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.386766380227,p=2.52704111851e-05
# allr227,nsub112,nsamp1000,173,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.204193084742,p=0.0308082015668
# allr227,nsub112,nsamp1000,173,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.229697113745,p=0.0148390462034
# allr227,nsub112,nsamp1000,174,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.134842188344,p=0.156334109193
# allr227,nsub112,nsamp1000,174,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.275427590893,p=0.00329035975856
# allr227,nsub112,nsamp1000,175,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.103583704734,p=0.277100632758
# allr227,nsub112,nsamp1000,175,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.035414382116,p=0.710859240673
# allr227,nsub112,nsamp1000,176,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0768432297542,p=0.420646131358
# allr227,nsub112,nsamp1000,176,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0512661505503,p=0.591394320822
# allr227,nsub112,nsamp1000,177,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0181872476672,p=0.849048828885
# allr227,nsub112,nsamp1000,177,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.070906894912,p=0.457526812921
# allr227,nsub112,nsamp1000,178,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.3071511877,p=0.000987293255365
# allr227,nsub112,nsamp1000,178,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.232362204952,p=0.013688107621
# allr227,nsub112,nsamp1000,179,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0594314763047,p=0.533640621141
# allr227,nsub112,nsamp1000,179,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0042021369018,p=0.964926301754
# allr227,nsub112,nsamp1000,180,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.351836544277,p=0.000142325216509
# allr227,nsub112,nsamp1000,180,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0500127579711,p=0.600504313695
# allr227,nsub112,nsamp1000,181,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0729494532652,p=0.444639184466
# allr227,nsub112,nsamp1000,181,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0993128832584,p=0.297496990411
# allr227,nsub112,nsamp1000,182,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0812589731899,p=0.394365979492
# allr227,nsub112,nsamp1000,182,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.103580537432,p=0.27711540199
# allr227,nsub112,nsamp1000,183,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.239476538917,p=0.0109884002215
# allr227,nsub112,nsamp1000,183,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.189812079274,p=0.0450155763504
# allr227,nsub112,nsamp1000,184,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.178639467712,p=0.0594944090898
# allr227,nsub112,nsamp1000,184,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.128183077694,p=0.178010112257
# allr227,nsub112,nsamp1000,185,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0683076779481,p=0.474221595834
# allr227,nsub112,nsamp1000,185,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0250479819801,p=0.793205617279
# allr227,nsub112,nsamp1000,186,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0479161957036,p=0.615880789845
# allr227,nsub112,nsamp1000,186,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.298373575136,p=0.00139647502949
# allr227,nsub112,nsamp1000,187,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.247783021547,p=0.0084365204424
# allr227,nsub112,nsamp1000,187,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.02677234058,p=0.779321375518
# allr227,nsub112,nsamp1000,188,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0832625788832,p=0.382772203023
# allr227,nsub112,nsamp1000,188,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.364613973764,p=7.73784152602e-05
# allr227,nsub112,nsamp1000,189,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.179408035665,p=0.0583893014541
# allr227,nsub112,nsamp1000,189,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.173908196319,p=0.0666800525696
# allr227,nsub112,nsamp1000,190,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0324426500271,p=0.734174046306
# allr227,nsub112,nsamp1000,190,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0305906365339,p=0.748828890494
# allr227,nsub112,nsamp1000,191,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.114730210814,p=0.228376602379
# allr227,nsub112,nsamp1000,191,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0721742740216,p=0.449506004241
# allr227,nsub112,nsamp1000,192,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.108301556175,p=0.25568682763
# allr227,nsub112,nsamp1000,192,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0890003541468,p=0.350727967411
# allr227,nsub112,nsamp1000,193,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.183089024535,p=0.0533272417178
# allr227,nsub112,nsamp1000,193,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.021187385523,p=0.824519694253
# allr227,nsub112,nsamp1000,194,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.142489120364,p=0.1339503291
# allr227,nsub112,nsamp1000,194,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0449269207317,p=0.638093895805
# allr227,nsub112,nsamp1000,195,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0480540692722,p=0.614864381099
# allr227,nsub112,nsamp1000,195,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=8.50979631706e-05,p=0.999289492787
# allr227,nsub112,nsamp1000,196,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0349677956478,p=0.7143465741
# allr227,nsub112,nsamp1000,196,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.163790172668,p=0.0844157514672
# allr227,nsub112,nsamp1000,197,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0475911171012,p=0.618280156114
# allr227,nsub112,nsamp1000,197,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0128657987129,p=0.892898975224
# allr227,nsub112,nsamp1000,198,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.128064457722,p=0.178415278238
# allr227,nsub112,nsamp1000,198,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.139576251496,p=0.142169440387
# allr227,nsub112,nsamp1000,199,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.227972835869,p=0.0156277145194
# allr227,nsub112,nsamp1000,199,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.106167530371,p=0.26522816792
# allr227,nsub112,nsamp1000,200,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0587179736398,p=0.538573020407
# allr227,nsub112,nsamp1000,200,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0237862982496,p=0.803405868183
# allr227,nsub112,nsamp1000,201,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0573527968636,p=0.548072812927
# allr227,nsub112,nsamp1000,201,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.134941493866,p=0.1560265233
# allr227,nsub112,nsamp1000,202,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.242629607658,p=0.00994945614327
# allr227,nsub112,nsamp1000,202,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.330822418831,p=0.000367086890464
# allr227,nsub112,nsamp1000,203,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0910597582994,p=0.339648267716
# allr227,nsub112,nsamp1000,203,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.162485319046,p=0.0869544706181
# allr227,nsub112,nsamp1000,204,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.216220063065,p=0.0220361545251
# allr227,nsub112,nsamp1000,204,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00681972319618,p=0.943107806686
# allr227,nsub112,nsamp1000,205,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.115154795384,p=0.226647951034
# allr227,nsub112,nsamp1000,205,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0370469441251,p=0.698161982116
# allr227,nsub112,nsamp1000,206,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0108802759363,p=0.909350662407
# allr227,nsub112,nsamp1000,206,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.245134322044,p=0.00918668295962
# allr227,nsub112,nsamp1000,207,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0707791932153,p=0.458339364184
# allr227,nsub112,nsamp1000,207,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.115903268007,p=0.223623081807
# allr227,nsub112,nsamp1000,208,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0315468177239,p=0.741251150081
# allr227,nsub112,nsamp1000,208,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.109352182324,p=0.25107691453
# allr227,nsub112,nsamp1000,209,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0918583270891,p=0.335412159211
# allr227,nsub112,nsamp1000,209,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.186129057107,p=0.0494243246684
# allr227,nsub112,nsamp1000,210,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.157906781925,p=0.0963463695634
# allr227,nsub112,nsamp1000,210,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0549836256994,p=0.564750426209
# allr227,nsub112,nsamp1000,211,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.108909293019,p=0.253013190898
# allr227,nsub112,nsamp1000,211,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.240873992923,p=0.0105167503496
# allr227,nsub112,nsamp1000,212,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.098150469776,p=0.30321547283
# allr227,nsub112,nsamp1000,212,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.154550297873,p=0.103726620943
# ...
# allr227,nsub112,nsamp1000,269,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.129616786596,p=0.173166355778
# allr227,nsub112,nsamp1000,270,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.301379013792,p=0.00124163311249
# allr227,nsub112,nsamp1000,270,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.227734937858,p=0.0157393325667
# allr227,nsub112,nsamp1000,271,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0382102494526,p=0.689164696487
# allr227,nsub112,nsamp1000,271,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.070922576778,p=0.457427086023
# allr227,nsub112,nsamp1000,272,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0381649687033,p=0.689514108852
# allr227,nsub112,nsamp1000,272,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.101000182187,p=0.289323639713
# allr227,nsub112,nsamp1000,273,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.197051560168,p=0.0372998229215
# allr227,nsub112,nsamp1000,273,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.156643263088,p=0.0990743960992
# allr227,nsub112,nsamp1000,274,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.141624181157,p=0.136352117435
# allr227,nsub112,nsamp1000,274,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0128903399813,p=0.892695900116
# allr227,nsub112,nsamp1000,275,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0245133472605,p=0.797523792112
# allr227,nsub112,nsamp1000,275,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.143779883396,p=0.130426301079
# allr227,nsub112,nsamp1000,276,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0893171307677,p=0.34900914193
# allr227,nsub112,nsamp1000,276,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.162118432359,p=0.0876791265508
# allr227,nsub112,nsamp1000,277,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.175592444931,p=0.0640453018693
# allr227,nsub112,nsamp1000,277,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.192363639977,p=0.0421571084871
# allr227,nsub112,nsamp1000,278,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.121478642925,p=0.201984625425
# allr227,nsub112,nsamp1000,278,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.4427323005,p=1.01897832698e-06
# allr227,nsub112,nsamp1000,279,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.255678934962,p=0.00651091485328
# allr227,nsub112,nsamp1000,279,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0701083070139,p=0.462621221919
# allr227,nsub112,nsamp1000,280,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.297362648908,p=0.00145237985443
# allr227,nsub112,nsamp1000,280,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.188770777264,p=0.0462275619175
# allr227,nsub112,nsamp1000,281,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.21656544185,p=0.0218197588673
# allr227,nsub112,nsamp1000,281,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0333986183437,p=0.726646367261
# allr227,nsub112,nsamp1000,282,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0123174843669,p=0.897437971591
# allr227,nsub112,nsamp1000,282,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00646073794287,p=0.946097947652
# allr227,nsub112,nsamp1000,283,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.129457589789,p=0.173699352561
# allr227,nsub112,nsamp1000,283,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.163860963085,p=0.0842797317483
# allr227,nsub112,nsamp1000,284,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.176123905539,p=0.0632317330268
# allr227,nsub112,nsamp1000,284,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0434084384403,p=0.64950325522
# allr227,nsub112,nsamp1000,285,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.132195425145,p=0.164700196373
# allr227,nsub112,nsamp1000,285,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0396048722781,p=0.678435316874
# allr227,nsub112,nsamp1000,286,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.139481986022,p=0.142441665858
# allr227,nsub112,nsamp1000,286,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.204152784862,p=0.0308419584039
# allr227,nsub112,nsamp1000,287,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.189453720105,p=0.0454296581153
# allr227,nsub112,nsamp1000,287,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.132400890204,p=0.164039078755
# allr227,nsub112,nsamp1000,288,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0920273276257,p=0.33451999563
# allr227,nsub112,nsamp1000,288,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0447217759645,p=0.639630430179
# allr227,nsub112,nsamp1000,289,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.111591035033,p=0.241445041435
# allr227,nsub112,nsamp1000,289,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0298149933124,p=0.754993527367
# allr227,nsub112,nsamp1000,290,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.128239301496,p=0.177818306769
# allr227,nsub112,nsamp1000,290,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.19279659292,p=0.0416874420893
# allr227,nsub112,nsamp1000,291,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.145892632856,p=0.124811788609
# allr227,nsub112,nsamp1000,291,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.272122659832,p=0.00370135482517
# allr227,nsub112,nsamp1000,292,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.058232075905,p=0.541944859148
# allr227,nsub112,nsamp1000,292,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.147654703121,p=0.120272928059
# allr227,nsub112,nsamp1000,293,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.173668898848,p=0.067061439667
# allr227,nsub112,nsamp1000,293,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.147799400568,p=0.119905945275
# allr227,nsub112,nsamp1000,294,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.354220946721,p=0.000127273839326
# allr227,nsub112,nsamp1000,294,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.243128792292,p=0.00979314325752
# allr227,nsub112,nsamp1000,295,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.108833002843,p=0.253347758429
# allr227,nsub112,nsamp1000,295,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.102652634096,p=0.28146503232
# allr227,nsub112,nsamp1000,296,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0264469489954,p=0.781936208565
# allr227,nsub112,nsamp1000,296,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0386699507731,p=0.685621088594
# allr227,nsub112,nsamp1000,297,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.18628718947,p=0.0492279527086
# allr227,nsub112,nsamp1000,297,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0667728414077,p=0.484232750193
# allr227,nsub112,nsamp1000,298,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.272229218587,p=0.0036874164436
# allr227,nsub112,nsamp1000,298,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.128153084126,p=0.17811249635
# allr227,nsub112,nsamp1000,299,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.071667540023,p=0.452703475671
# allr227,nsub112,nsamp1000,299,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.206742222311,p=0.0287355937963
# allr227,nsub112,nsamp1000,300,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.123543814645,p=0.194364661836
# allr227,nsub112,nsamp1000,300,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0721548479052,p=0.449628348958
# allr227,nsub112,nsamp1000,301,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.233722735367,p=0.0131311244719
# allr227,nsub112,nsamp1000,301,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0680057658092,p=0.476181947643
# allr227,nsub112,nsamp1000,302,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00330451695195,p=0.972415062031
# allr227,nsub112,nsamp1000,302,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.154695903872,p=0.103397525313
# allr227,nsub112,nsamp1000,303,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.191413056934,p=0.0432038030221
# allr227,nsub112,nsamp1000,303,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.319494126179,p=0.000595332751692
# allr227,nsub112,nsamp1000,304,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.306132903409,p=0.00102838020375
# allr227,nsub112,nsamp1000,304,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.276350221538,p=0.00318319140555
# allr227,nsub112,nsamp1000,305,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0616265274128,p=0.518608913255
# allr227,nsub112,nsamp1000,305,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0211582258558,p=0.824757332527
# allr227,nsub112,nsamp1000,306,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0145822563142,p=0.878712997801
# allr227,nsub112,nsamp1000,306,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.255530488448,p=0.00654317553253
# allr227,nsub112,nsamp1000,307,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.196475966211,p=0.0378696733538
# allr227,nsub112,nsamp1000,307,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.228033702139,p=0.0155992675989
# allr227,nsub112,nsamp1000,308,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.351956759403,p=0.000141528419201
# allr227,nsub112,nsamp1000,308,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.25004724271,p=0.00783863622989
# allr227,nsub112,nsamp1000,309,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.11361885687,p=0.232945146
# allr227,nsub112,nsamp1000,309,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00613554912796,p=0.948807231466
# allr227,nsub112,nsamp1000,310,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.198939020054,p=0.035481459045
# allr227,nsub112,nsamp1000,310,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.131852175481,p=0.165809069705
# allr227,nsub112,nsamp1000,311,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.104229475527,p=0.274100428513
# allr227,nsub112,nsamp1000,311,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.113274868246,p=0.234372080273
# allr227,nsub112,nsamp1000,312,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0831187291182,p=0.383597653603
# allr227,nsub112,nsamp1000,312,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.127365707553,p=0.180815717161
# allr227,nsub112,nsamp1000,313,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.181518005553,p=0.0554416265552
# allr227,nsub112,nsamp1000,313,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.225932063333,p=0.016607921019
# allr227,nsub112,nsamp1000,314,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.263277089899,p=0.00503689533641
# allr227,nsub112,nsamp1000,314,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.27766784045,p=0.00303558088113
# allr227,nsub112,nsamp1000,315,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0986446033481,p=0.300775840856
# allr227,nsub112,nsamp1000,315,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.123323463542,p=0.195167641918
# allr227,nsub112,nsamp1000,316,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.12708505131,p=0.181786493182
# allr227,nsub112,nsamp1000,316,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.118466528375,p=0.213480043822
# allr227,nsub112,nsamp1000,317,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.180696708245,p=0.0565741205351
# allr227,nsub112,nsamp1000,317,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.302874329765,p=0.00117057071559
# allr227,nsub112,nsamp1000,318,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.237723157796,p=0.0116063242811
# allr227,nsub112,nsamp1000,318,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.152407235784,p=0.108665874399
# allr227,nsub112,nsamp1000,319,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.243094836483,p=0.00980370722787
# allr227,nsub112,nsamp1000,319,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.041662674069,p=0.662721106262
# allr227,nsub112,nsamp1000,320,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0397843405624,p=0.677059199003
# allr227,nsub112,nsamp1000,320,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.000165876572669,p=0.99861504959
# allr227,nsub112,nsamp1000,321,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.26529426723,p=0.00469930337116
# allr227,nsub112,nsamp1000,321,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.220579533652,p=0.0194355569139
# allr227,nsub112,nsamp1000,322,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.198331229384,p=0.0360586776167
# allr227,nsub112,nsamp1000,322,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0824179881879,p=0.387634053148
# allr227,nsub112,nsamp1000,323,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0488590314348,p=0.608944769547
# allr227,nsub112,nsamp1000,323,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0198188010527,p=0.835689787137
# allr227,nsub112,nsamp1000,324,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.211188943358,p=0.0254032674373
# allr227,nsub112,nsamp1000,324,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.111454253688,p=0.242026031752
# allr227,nsub112,nsamp1000,325,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.131202985863,p=0.167921416057
# allr227,nsub112,nsamp1000,325,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0562717084206,p=0.5556532208
# allr227,nsub112,nsamp1000,326,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.16084007185,p=0.0902416821617
# allr227,nsub112,nsamp1000,326,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.217441287273,p=0.0212791614642
# allr227,nsub112,nsamp1000,327,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0801138889249,p=0.401085030872
# allr227,nsub112,nsamp1000,327,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0501738020932,p=0.599330304366
# allr227,nsub112,nsamp1000,328,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.179906392249,p=0.0576817546358
# allr227,nsub112,nsamp1000,328,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0334034660847,p=0.726608259753
# allr227,nsub112,nsamp1000,329,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0947909702379,p=0.320144985057
# allr227,nsub112,nsamp1000,329,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.143108992254,p=0.132249001355
# allr227,nsub112,nsamp1000,330,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.108366071755,p=0.255402086926
# allr227,nsub112,nsamp1000,330,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.264527299665,p=0.00482520523764
# allr227,nsub112,nsamp1000,331,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.209566434824,p=0.0265788001755
# allr227,nsub112,nsamp1000,331,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0745366158532,p=0.434767564462
# allr227,nsub112,nsamp1000,332,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.292719393014,p=0.0017362045857
# allr227,nsub112,nsamp1000,332,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.268678901875,p=0.004178029562
# allr227,nsub112,nsamp1000,333,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.150032102142,p=0.114352355197
# allr227,nsub112,nsamp1000,333,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.000456351548528,p=0.996189804276
# allr227,nsub112,nsamp1000,334,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.153614475196,p=0.10586138202
# allr227,nsub112,nsamp1000,334,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0731265345083,p=0.443531587573
# allr227,nsub112,nsamp1000,335,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.167439797347,p=0.0776281209223
# allr227,nsub112,nsamp1000,335,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.26544982195,p=0.00467412892056
# allr227,nsub112,nsamp1000,336,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.174020344673,p=0.0665019202167
# allr227,nsub112,nsamp1000,336,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.097862053082,p=0.304645420407
# allr227,nsub112,nsamp1000,337,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0403170880447,p=0.672980497948
# allr227,nsub112,nsamp1000,337,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0166662481299,p=0.861541372195
# allr227,nsub112,nsamp1000,338,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.187196069807,p=0.0481117690526
# allr227,nsub112,nsamp1000,338,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.203178683706,p=0.0316674841596
# allr227,nsub112,nsamp1000,339,Ciric6,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0633656211996,p=0.506854739938
# allr227,nsub112,nsamp1000,339,Ciric6,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.11572728002,p=0.224331743888
