# %% [markdown]
# # Load libraries & helper functions

# %%
from helpers import *
# %matplotlib inline

# %% [markdown]
# # Declare parameters

# %%
#config.DATADIR      = '/scratch/duboisjx/data/CamCAN/MRI'
config.DATADIR      = '/home/duboisjx/mnt10/LabUsers/duboisjx/data/HCP/MRI'

# fMRI runs
fmriRuns      = ['rfMRI_REST1_LR','rfMRI_REST1_RL']

# use volume or surface data
config.isCifti      = False

config.overwrite    = False

config.pipelineName = 'Finn'
# use ICA-FIX input
config.useFIX       = False
config.preWhitening = False
config.Operations   = config.operationDict[config.pipelineName]

# submit jobs with sge
config.queue        = False
# make sure to set memory requirements according to data size
# 15G for HCP data!
# config.maxvmem      = '20G'
# config.whichQueue   = 'verylong.q'
# whether to use memmapping (which involves unzipping)
config.useMemMap    = False

# parcellation for FC matrix
config.parcellationName = 'shen2013'
#config.parcellationFile = '/scratch/duboisjx/data/parcellations/shenetal_neuroimage2013_new/shen_3mm_268_parcellation.nii.gz'
config.parcellationFile = '/home/duboisjx/mnt10/LabUsers/duboisjx/data/parcellations/shenetal_neuroimage2013_new/shen_2mm_268_parcellation.nii.gz'
config.nParcels         = 268

# subject selection parameters
config.behavFile = '/home/duboisjx/mnt10/LabUsers/duboisjx/data/HCP/neuropsych/unrestricted_luckydjuju_11_17_2015_0_47_11.csv'
config.release   = 'Q2'
config.outScore  = 'PMAT24_A_CR'

# %% [markdown]
# # Subject selection

# %%
df = pd.read_csv(config.behavFile)
# select subjects according to release
if config.release == 'Q2':
    ind = (df['Release'] == 'Q2') | (df['Release'] == 'Q1')
elif config.release == 'S500':
    ind = (df['Release'] != 'Q2') & (df['Release'] != 'Q1')
else:
    sys.exit("Invalid release code")
# select subjects that have completed all fMRI
ind = ind & ((df['fMRI_WM_Compl']== True) & (df['fMRI_Mot_Compl']==True) 
             & (df['fMRI_Lang_Compl']==True) & (df['fMRI_Emo_Compl']==True)         
             & (df['RS-fMRI_Count']==4))
df = df[ind]  
# check if either of the two subjects recommended for exclusion by HCP are still present
df = df[~df['Subject'].isin(['209733','528446'])]
df.index = range(df.shape[0])
tmpAgeRanges = sorted(df['Age'].unique())
# list of all selected subjects
subjects = df['Subject']
# pull their IQ, Age, Gender
age = df['Age']
gender = df['Gender']
score = df[config.outScore]

print 'Selected', str(df.shape[0]), 'from the release',config.release
print 'Number of males is:', df[df['Gender']=='M'].shape[0]
print 'Age range is', tmpAgeRanges[0].split('-')[0], '-', tmpAgeRanges[-1].split('-')[1]

# Exclusion of high-motion subjects
# exclude subjects with >0.14 frame-to-frame head motion estimate averged across both rest runs (arbitrary threshold as in Finn et al 2015)
subjects   = [str(subject) for subject in subjects]
RelRMSMean = np.zeros([len(subjects), len(fmriRuns)],dtype=np.float32)
compSub    = np.zeros((len(subjects)),dtype=np.bool_)
keepSub    = np.zeros((len(subjects)),dtype=np.bool_)
iSub=0
for config.subject in subjects:
    i=0
    for config.fmriRun in fmriRuns:
        RelRMSMeanFile = op.join(buildpath(), 'Movement_RelativeRMS_mean.txt')
        #print RelRMSMeanFile
        if op.isfile(RelRMSMeanFile):
            with open(RelRMSMeanFile,'r') as tmp:
                RelRMSMean[iSub,i] = float(tmp.read())
        else:
            print RelRMSMeanFile+' File missing'
            break
        i=i+1
    if i==len(fmriRuns): # all RelRMSMeanFile exist
        compSub[iSub]=True
        if np.mean(RelRMSMean[iSub,:]) > 0.14:
            print config.subject, ': too much motion, exclude'
        else:
            keepSub[iSub]=True
    iSub=iSub+1

#### motion vs. score correlation
plt.scatter(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1),c='r')
plt.scatter(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1),c='b')
# fit a curve to the data using a least squares 1st order polynomial fit
z1 = np.polyfit(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1),1)
z2 = np.polyfit(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1),1)
p1 = np.poly1d(z1)
p2 = np.poly1d(z2)                
fit1 = p1(score[keepSub])
fit2 = p2(score[compSub])
# get the coordinates for the fit curve
c1_x = [np.min(score[keepSub]),np.max(score[keepSub])]
c1_y = p1(c1_x)
c2_x = [np.min(score[compSub]),np.max(score[compSub])]
c2_y = p2(c2_x)
# plot line of best fit
plt.plot(c2_x,c2_y,'r-',label='before exclusion')
plt.plot(c1_x,c1_y,'b-',label='after exclusion')
plt.xlabel('Score [{}]'.format(config.outScore))
plt.ylabel('RelRMSMean')
plt.legend(loc=0)
plt.show()
rho1,p1 = stats.pearsonr(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1))
rho2,p2 = stats.pearsonr(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1))            
print 'With all subjects: corr(IQ,motion) = {:.3f} (p = {:.3f})'.format(rho2,p2)
print 'After discarding high movers: corr(IQ,motion) = {:.3f} (p = {:.3f})'.format(rho1,p1)
    
subjects   = [subject for (subject, keep) in zip(subjects, keepSub) if keep]
age        = age[keepSub]
gender     = gender[keepSub]
score      = score[keepSub]
RelRMSMean = RelRMSMean[keepSub,:]
print 'Keeping {} subjects [{} M]'.format(len(subjects),sum([g=='M' for g in gender]))
# Out:
# Selected 125 from the release Q2
# Number of males is: 40
# Age range is 22 - 35
# 114924 : too much motion, exclude
# 123117 : too much motion, exclude
# 151223 : too much motion, exclude
# 156637 : too much motion, exclude
# 191437 : too much motion, exclude
# 199150 : too much motion, exclude
# 250427 : too much motion, exclude
# 298051 : too much motion, exclude
# 788876 : too much motion, exclude
# 937160 : too much motion, exclude
# With all subjects: corr(IQ,motion) = -0.154 (p = 0.087)
# After discarding high movers: corr(IQ,motion) = -0.073 (p = 0.441)
# Keeping 115 subjects [36 M]

# %% [markdown]
# # Do work

# %% [markdown]
# ### preprocess everybody

# %%
keepSub = np.zeros((len(subjects)),dtype=np.bool_)
iSub=0
for config.subject in subjects:
    iRun = 0
    for config.fmriRun in fmriRuns:
        if not config.queue:
            print 'SUB {}/{} [{}]: run {}/{} [{}]'.format(iSub+1,len(subjects),config.subject,iRun+1,len(fmriRuns),config.fmriRun)
        keepSub[iSub] = runPipelinePar(launchSubproc=True)
        if not keepSub[iSub]:
            break
        iRun+=1
    iSub+=1
print 'Keeping {}/{} subjects'.format(np.sum(keepSub),len(subjects))
score    = score[keepSub]

if config.queue:
    if len(config.joblist) != 0:
        while True:
            nleft = len(config.joblist)
            for i in range(nleft):
                myCmd = "qstat | grep ' {} '".format(config.joblist[i])
                isEmpty = False
                try:
                    cmdOut = check_output(myCmd, shell=True)
                except CalledProcessError as e:
                    isEmpty = True
                finally:
                    if isEmpty:
                        nleft = nleft-1
            if nleft == 0:
                break
            else:
                print 'Waiting for {} subjects to complete...'.format(nleft)
            sleep(10)
    print 'All done!!'
# Out:
# SUB 1/115 [100307]: run 1/2 [rfMRI_REST1_LR]
# SUB 1/115 [100307]: run 2/2 [rfMRI_REST1_RL]
# SUB 2/115 [103414]: run 1/2 [rfMRI_REST1_LR]
# SUB 2/115 [103414]: run 2/2 [rfMRI_REST1_RL]
# SUB 3/115 [103515]: run 1/2 [rfMRI_REST1_LR]
# SUB 3/115 [103515]: run 2/2 [rfMRI_REST1_RL]
# SUB 4/115 [103818]: run 1/2 [rfMRI_REST1_LR]
# SUB 4/115 [103818]: run 2/2 [rfMRI_REST1_RL]
# SUB 5/115 [105115]: run 1/2 [rfMRI_REST1_LR]
# SUB 5/115 [105115]: run 2/2 [rfMRI_REST1_RL]
# SUB 6/115 [110411]: run 1/2 [rfMRI_REST1_LR]
# SUB 6/115 [110411]: run 2/2 [rfMRI_REST1_RL]
# SUB 7/115 [111312]: run 1/2 [rfMRI_REST1_LR]
# SUB 7/115 [111312]: run 2/2 [rfMRI_REST1_RL]
# SUB 8/115 [113619]: run 1/2 [rfMRI_REST1_LR]
# SUB 8/115 [113619]: run 2/2 [rfMRI_REST1_RL]
# SUB 9/115 [115320]: run 1/2 [rfMRI_REST1_LR]
# SUB 9/115 [115320]: run 2/2 [rfMRI_REST1_RL]
# SUB 10/115 [117122]: run 1/2 [rfMRI_REST1_LR]
# SUB 10/115 [117122]: run 2/2 [rfMRI_REST1_RL]
# SUB 11/115 [118730]: run 1/2 [rfMRI_REST1_LR]
# SUB 11/115 [118730]: run 2/2 [rfMRI_REST1_RL]
# SUB 12/115 [118932]: run 1/2 [rfMRI_REST1_LR]
# SUB 12/115 [118932]: run 2/2 [rfMRI_REST1_RL]
# SUB 13/115 [119833]: run 1/2 [rfMRI_REST1_LR]
# SUB 13/115 [119833]: run 2/2 [rfMRI_REST1_RL]
# SUB 14/115 [120212]: run 1/2 [rfMRI_REST1_LR]
# SUB 14/115 [120212]: run 2/2 [rfMRI_REST1_RL]
# SUB 15/115 [124422]: run 1/2 [rfMRI_REST1_LR]
# SUB 15/115 [124422]: run 2/2 [rfMRI_REST1_RL]
# SUB 16/115 [125525]: run 1/2 [rfMRI_REST1_LR]
# SUB 16/115 [125525]: run 2/2 [rfMRI_REST1_RL]
# SUB 17/115 [128632]: run 1/2 [rfMRI_REST1_LR]
# SUB 17/115 [128632]: run 2/2 [rfMRI_REST1_RL]
# SUB 18/115 [129028]: run 1/2 [rfMRI_REST1_LR]
# SUB 18/115 [129028]: run 2/2 [rfMRI_REST1_RL]
# SUB 19/115 [130013]: run 1/2 [rfMRI_REST1_LR]
# SUB 19/115 [130013]: run 2/2 [rfMRI_REST1_RL]
# SUB 20/115 [133827]: run 1/2 [rfMRI_REST1_LR]
# SUB 20/115 [133827]: run 2/2 [rfMRI_REST1_RL]
# SUB 21/115 [133928]: run 1/2 [rfMRI_REST1_LR]
# SUB 21/115 [133928]: run 2/2 [rfMRI_REST1_RL]
# SUB 22/115 [134324]: run 1/2 [rfMRI_REST1_LR]
# SUB 22/115 [134324]: run 2/2 [rfMRI_REST1_RL]
# SUB 23/115 [135932]: run 1/2 [rfMRI_REST1_LR]
# SUB 23/115 [135932]: run 2/2 [rfMRI_REST1_RL]
# SUB 24/115 [136833]: run 1/2 [rfMRI_REST1_LR]
# SUB 24/115 [136833]: run 2/2 [rfMRI_REST1_RL]
# SUB 25/115 [137128]: run 1/2 [rfMRI_REST1_LR]
# SUB 25/115 [137128]: run 2/2 [rfMRI_REST1_RL]
# SUB 26/115 [138231]: run 1/2 [rfMRI_REST1_LR]
# SUB 26/115 [138231]: run 2/2 [rfMRI_REST1_RL]
# SUB 27/115 [139637]: run 1/2 [rfMRI_REST1_LR]
# SUB 27/115 [139637]: run 2/2 [rfMRI_REST1_RL]
# SUB 28/115 [142828]: run 1/2 [rfMRI_REST1_LR]
# SUB 28/115 [142828]: run 2/2 [rfMRI_REST1_RL]
# SUB 29/115 [143325]: run 1/2 [rfMRI_REST1_LR]
# SUB 29/115 [143325]: run 2/2 [rfMRI_REST1_RL]
# SUB 30/115 [149337]: run 1/2 [rfMRI_REST1_LR]
# SUB 30/115 [149337]: run 2/2 [rfMRI_REST1_RL]
# SUB 31/115 [149539]: run 1/2 [rfMRI_REST1_LR]
# SUB 31/115 [149539]: run 2/2 [rfMRI_REST1_RL]
# SUB 32/115 [150423]: run 1/2 [rfMRI_REST1_LR]
# SUB 32/115 [150423]: run 2/2 [rfMRI_REST1_RL]
# SUB 33/115 [151627]: run 1/2 [rfMRI_REST1_LR]
# SUB 33/115 [151627]: run 2/2 [rfMRI_REST1_RL]
# SUB 34/115 [153429]: run 1/2 [rfMRI_REST1_LR]
# SUB 34/115 [153429]: run 2/2 [rfMRI_REST1_RL]
# SUB 35/115 [157336]: run 1/2 [rfMRI_REST1_LR]
# SUB 35/115 [157336]: run 2/2 [rfMRI_REST1_RL]
# SUB 36/115 [158035]: run 1/2 [rfMRI_REST1_LR]
# SUB 36/115 [158035]: run 2/2 [rfMRI_REST1_RL]
# SUB 37/115 [158540]: run 1/2 [rfMRI_REST1_LR]
# SUB 37/115 [158540]: run 2/2 [rfMRI_REST1_RL]
# SUB 38/115 [159239]: run 1/2 [rfMRI_REST1_LR]
# SUB 38/115 [159239]: run 2/2 [rfMRI_REST1_RL]
# SUB 39/115 [161731]: run 1/2 [rfMRI_REST1_LR]
# SUB 39/115 [161731]: run 2/2 [rfMRI_REST1_RL]
# SUB 40/115 [162329]: run 1/2 [rfMRI_REST1_LR]
# SUB 40/115 [162329]: run 2/2 [rfMRI_REST1_RL]
# SUB 41/115 [163432]: run 1/2 [rfMRI_REST1_LR]
# SUB 41/115 [163432]: run 2/2 [rfMRI_REST1_RL]
# SUB 42/115 [167743]: run 1/2 [rfMRI_REST1_LR]
# SUB 42/115 [167743]: run 2/2 [rfMRI_REST1_RL]
# SUB 43/115 [169343]: run 1/2 [rfMRI_REST1_LR]
# SUB 43/115 [169343]: run 2/2 [rfMRI_REST1_RL]
# SUB 44/115 [172332]: run 1/2 [rfMRI_REST1_LR]
# SUB 44/115 [172332]: run 2/2 [rfMRI_REST1_RL]
# SUB 45/115 [175439]: run 1/2 [rfMRI_REST1_LR]
# SUB 45/115 [175439]: run 2/2 [rfMRI_REST1_RL]
# SUB 46/115 [182739]: run 1/2 [rfMRI_REST1_LR]
# SUB 46/115 [182739]: run 2/2 [rfMRI_REST1_RL]
# SUB 47/115 [185139]: run 1/2 [rfMRI_REST1_LR]
# SUB 47/115 [185139]: run 2/2 [rfMRI_REST1_RL]
# SUB 48/115 [192439]: run 1/2 [rfMRI_REST1_LR]
# SUB 48/115 [192439]: run 2/2 [rfMRI_REST1_RL]
# SUB 49/115 [192540]: run 1/2 [rfMRI_REST1_LR]
# SUB 49/115 [192540]: run 2/2 [rfMRI_REST1_RL]
# SUB 50/115 [193239]: run 1/2 [rfMRI_REST1_LR]
# SUB 50/115 [193239]: run 2/2 [rfMRI_REST1_RL]
# SUB 51/115 [194140]: run 1/2 [rfMRI_REST1_LR]
# SUB 51/115 [194140]: run 2/2 [rfMRI_REST1_RL]
# SUB 52/115 [196144]: run 1/2 [rfMRI_REST1_LR]
# SUB 52/115 [196144]: run 2/2 [rfMRI_REST1_RL]
# SUB 53/115 [197550]: run 1/2 [rfMRI_REST1_LR]
# SUB 53/115 [197550]: run 2/2 [rfMRI_REST1_RL]
# SUB 54/115 [199251]: run 1/2 [rfMRI_REST1_LR]
# SUB 54/115 [199251]: run 2/2 [rfMRI_REST1_RL]
# SUB 55/115 [200614]: run 1/2 [rfMRI_REST1_LR]
# SUB 55/115 [200614]: run 2/2 [rfMRI_REST1_RL]
# SUB 56/115 [201111]: run 1/2 [rfMRI_REST1_LR]
# SUB 56/115 [201111]: run 2/2 [rfMRI_REST1_RL]
# SUB 57/115 [205119]: run 1/2 [rfMRI_REST1_LR]
# SUB 57/115 [205119]: run 2/2 [rfMRI_REST1_RL]
# SUB 58/115 [205725]: run 1/2 [rfMRI_REST1_LR]
# SUB 58/115 [205725]: run 2/2 [rfMRI_REST1_RL]
# SUB 59/115 [210617]: run 1/2 [rfMRI_REST1_LR]
# SUB 59/115 [210617]: run 2/2 [rfMRI_REST1_RL]
# SUB 60/115 [212318]: run 1/2 [rfMRI_REST1_LR]
# SUB 60/115 [212318]: run 2/2 [rfMRI_REST1_RL]
# SUB 61/115 [214019]: run 1/2 [rfMRI_REST1_LR]
# SUB 61/115 [214019]: run 2/2 [rfMRI_REST1_RL]
# SUB 62/115 [214221]: run 1/2 [rfMRI_REST1_LR]
# SUB 62/115 [214221]: run 2/2 [rfMRI_REST1_RL]
# SUB 63/115 [214423]: run 1/2 [rfMRI_REST1_LR]
# SUB 63/115 [214423]: run 2/2 [rfMRI_REST1_RL]
# SUB 64/115 [217429]: run 1/2 [rfMRI_REST1_LR]
# SUB 64/115 [217429]: run 2/2 [rfMRI_REST1_RL]
# SUB 65/115 [221319]: run 1/2 [rfMRI_REST1_LR]
# SUB 65/115 [221319]: run 2/2 [rfMRI_REST1_RL]
# SUB 66/115 [249947]: run 1/2 [rfMRI_REST1_LR]
# SUB 66/115 [249947]: run 2/2 [rfMRI_REST1_RL]
# SUB 67/115 [255639]: run 1/2 [rfMRI_REST1_LR]
# SUB 67/115 [255639]: run 2/2 [rfMRI_REST1_RL]
# SUB 68/115 [293748]: run 1/2 [rfMRI_REST1_LR]
# SUB 68/115 [293748]: run 2/2 [rfMRI_REST1_RL]
# SUB 69/115 [304020]: run 1/2 [rfMRI_REST1_LR]
# SUB 69/115 [304020]: run 2/2 [rfMRI_REST1_RL]
# SUB 70/115 [307127]: run 1/2 [rfMRI_REST1_LR]
# SUB 70/115 [307127]: run 2/2 [rfMRI_REST1_RL]
# SUB 71/115 [329440]: run 1/2 [rfMRI_REST1_LR]
# SUB 71/115 [329440]: run 2/2 [rfMRI_REST1_RL]
# SUB 72/115 [397760]: run 1/2 [rfMRI_REST1_LR]
# SUB 72/115 [397760]: run 2/2 [rfMRI_REST1_RL]
# SUB 73/115 [414229]: run 1/2 [rfMRI_REST1_LR]
# SUB 73/115 [414229]: run 2/2 [rfMRI_REST1_RL]
# SUB 74/115 [448347]: run 1/2 [rfMRI_REST1_LR]
# SUB 74/115 [448347]: run 2/2 [rfMRI_REST1_RL]
# SUB 75/115 [485757]: run 1/2 [rfMRI_REST1_LR]
# SUB 75/115 [485757]: run 2/2 [rfMRI_REST1_RL]
# SUB 76/115 [499566]: run 1/2 [rfMRI_REST1_LR]
# SUB 76/115 [499566]: run 2/2 [rfMRI_REST1_RL]
# SUB 77/115 [530635]: run 1/2 [rfMRI_REST1_LR]
# SUB 77/115 [530635]: run 2/2 [rfMRI_REST1_RL]
# SUB 78/115 [552544]: run 1/2 [rfMRI_REST1_LR]
# SUB 78/115 [552544]: run 2/2 [rfMRI_REST1_RL]
# SUB 79/115 [559053]: run 1/2 [rfMRI_REST1_LR]
# SUB 79/115 [559053]: run 2/2 [rfMRI_REST1_RL]
# SUB 80/115 [579665]: run 1/2 [rfMRI_REST1_LR]
# SUB 80/115 [579665]: run 2/2 [rfMRI_REST1_RL]
# SUB 81/115 [581349]: run 1/2 [rfMRI_REST1_LR]
# SUB 81/115 [581349]: run 2/2 [rfMRI_REST1_RL]
# SUB 82/115 [585862]: run 1/2 [rfMRI_REST1_LR]
# SUB 82/115 [585862]: run 2/2 [rfMRI_REST1_RL]
# SUB 83/115 [598568]: run 1/2 [rfMRI_REST1_LR]
# SUB 83/115 [598568]: run 2/2 [rfMRI_REST1_RL]
# SUB 84/115 [627549]: run 1/2 [rfMRI_REST1_LR]
# SUB 84/115 [627549]: run 2/2 [rfMRI_REST1_RL]
# SUB 85/115 [638049]: run 1/2 [rfMRI_REST1_LR]
# SUB 85/115 [638049]: run 2/2 [rfMRI_REST1_RL]
# SUB 86/115 [645551]: run 1/2 [rfMRI_REST1_LR]
# SUB 86/115 [645551]: run 2/2 [rfMRI_REST1_RL]
# SUB 87/115 [654754]: run 1/2 [rfMRI_REST1_LR]
# SUB 87/115 [654754]: run 2/2 [rfMRI_REST1_RL]
# SUB 88/115 [665254]: run 1/2 [rfMRI_REST1_LR]
# SUB 88/115 [665254]: run 2/2 [rfMRI_REST1_RL]
# SUB 89/115 [672756]: run 1/2 [rfMRI_REST1_LR]
# SUB 89/115 [672756]: run 2/2 [rfMRI_REST1_RL]
# SUB 90/115 [677968]: run 1/2 [rfMRI_REST1_LR]
# SUB 90/115 [677968]: run 2/2 [rfMRI_REST1_RL]
# SUB 91/115 [702133]: run 1/2 [rfMRI_REST1_LR]
# SUB 91/115 [702133]: run 2/2 [rfMRI_REST1_RL]
# SUB 92/115 [729557]: run 1/2 [rfMRI_REST1_LR]
# SUB 92/115 [729557]: run 2/2 [rfMRI_REST1_RL]
# SUB 93/115 [732243]: run 1/2 [rfMRI_REST1_LR]
# SUB 93/115 [732243]: run 2/2 [rfMRI_REST1_RL]
# SUB 94/115 [734045]: run 1/2 [rfMRI_REST1_LR]
# SUB 94/115 [734045]: run 2/2 [rfMRI_REST1_RL]
# SUB 95/115 [748258]: run 1/2 [rfMRI_REST1_LR]
# SUB 95/115 [748258]: run 2/2 [rfMRI_REST1_RL]
# SUB 96/115 [753251]: run 1/2 [rfMRI_REST1_LR]
# SUB 96/115 [753251]: run 2/2 [rfMRI_REST1_RL]
# SUB 97/115 [792564]: run 1/2 [rfMRI_REST1_LR]
# SUB 97/115 [792564]: run 2/2 [rfMRI_REST1_RL]
# SUB 98/115 [826353]: run 1/2 [rfMRI_REST1_LR]
# SUB 98/115 [826353]: run 2/2 [rfMRI_REST1_RL]
# SUB 99/115 [856766]: run 1/2 [rfMRI_REST1_LR]
# SUB 99/115 [856766]: run 2/2 [rfMRI_REST1_RL]
# SUB 100/115 [857263]: run 1/2 [rfMRI_REST1_LR]
# SUB 100/115 [857263]: run 2/2 [rfMRI_REST1_RL]
# SUB 101/115 [859671]: run 1/2 [rfMRI_REST1_LR]
# SUB 101/115 [859671]: run 2/2 [rfMRI_REST1_RL]
# SUB 102/115 [861456]: run 1/2 [rfMRI_REST1_LR]
# SUB 102/115 [861456]: run 2/2 [rfMRI_REST1_RL]
# SUB 103/115 [865363]: run 1/2 [rfMRI_REST1_LR]
# SUB 103/115 [865363]: run 2/2 [rfMRI_REST1_RL]
# SUB 104/115 [872158]: run 1/2 [rfMRI_REST1_LR]
# SUB 104/115 [872158]: run 2/2 [rfMRI_REST1_RL]
# SUB 105/115 [885975]: run 1/2 [rfMRI_REST1_LR]
# SUB 105/115 [885975]: run 2/2 [rfMRI_REST1_RL]
# SUB 106/115 [887373]: run 1/2 [rfMRI_REST1_LR]
# SUB 106/115 [887373]: run 2/2 [rfMRI_REST1_RL]
# SUB 107/115 [889579]: run 1/2 [rfMRI_REST1_LR]
# SUB 107/115 [889579]: run 2/2 [rfMRI_REST1_RL]
# SUB 108/115 [894673]: run 1/2 [rfMRI_REST1_LR]
# SUB 108/115 [894673]: run 2/2 [rfMRI_REST1_RL]
# SUB 109/115 [896778]: run 1/2 [rfMRI_REST1_LR]
# SUB 109/115 [896778]: run 2/2 [rfMRI_REST1_RL]
# SUB 110/115 [896879]: run 1/2 [rfMRI_REST1_LR]
# SUB 110/115 [896879]: run 2/2 [rfMRI_REST1_RL]
# SUB 111/115 [901139]: run 1/2 [rfMRI_REST1_LR]
# SUB 111/115 [901139]: run 2/2 [rfMRI_REST1_RL]
# SUB 112/115 [917255]: run 1/2 [rfMRI_REST1_LR]
# SUB 112/115 [917255]: run 2/2 [rfMRI_REST1_RL]
# SUB 113/115 [932554]: run 1/2 [rfMRI_REST1_LR]
# SUB 113/115 [932554]: run 2/2 [rfMRI_REST1_RL]
# SUB 114/115 [984472]: run 1/2 [rfMRI_REST1_LR]
# SUB 114/115 [984472]: run 2/2 [rfMRI_REST1_RL]
# SUB 115/115 [992774]: run 1/2 [rfMRI_REST1_LR]
# SUB 115/115 [992774]: run 2/2 [rfMRI_REST1_RL]
# Keeping 115/115 subjects

# %% [markdown]
# ### look at QC

# %%
fdScores     = np.zeros((len(subjects),len(fmriRuns)),dtype=np.float32)
fcMats       = np.zeros((config.nParcels,config.nParcels,len(subjects),len(fmriRuns)),dtype=np.float32)
fcMats_dn    = np.zeros((config.nParcels,config.nParcels,len(subjects),len(fmriRuns)),dtype=np.float32)
config.queue =False
iSub= 0
for config.subject in subjects:
    if keepSub[iSub]:
        print 'SUB {}/{}: {}'.format(iSub+1,len(subjects),config.subject)
        iRun = 0
        for config.fmriRun in fmriRuns:
            runPipelinePar(launchSubproc=False)
            fcMats[:,:,iSub,iRun],fcMats_dn[:,:,iSub,iRun] = plotFC(displayPlot=False)
            fdScores[iSub,iRun]=np.mean(computeFD())
            iRun = iRun+1
    iSub = iSub + 1

fdScores  = np.squeeze(np.mean(fdScores[keepSub,:],1))
fcMats    = np.squeeze(np.tanh(np.mean(np.arctanh(fcMats[:,:,keepSub,:]),3)))
fcMats_dn = np.squeeze(np.tanh(np.mean(np.arctanh(fcMats_dn[:,:,keepSub,:]),3)))

# rsFC/mean FD plot
# since this is a correlation across subjects, it makes most sense if we have enough subjects
if len(subjects)>20:    
    plotQCrsFC(fcMats,fcMats_dn,fdScores)
    
# deltaR plot
plotDeltaR(fcMats,fcMats_dn)
# Out:
# SUB 1/115: 100307
# SUB 2/115: 103414
# SUB 3/115: 103515
# SUB 4/115: 103818
# SUB 5/115: 105115
# SUB 6/115: 110411
# SUB 7/115: 111312
# SUB 8/115: 113619
# SUB 9/115: 115320
# SUB 10/115: 117122
# SUB 11/115: 118730
# SUB 12/115: 118932
# SUB 13/115: 119833
# SUB 14/115: 120212
# SUB 15/115: 124422
# SUB 16/115: 125525
# SUB 17/115: 128632
# SUB 18/115: 129028
# SUB 19/115: 130013
# SUB 20/115: 133827
# SUB 21/115: 133928
# SUB 22/115: 134324
# SUB 23/115: 135932
# SUB 24/115: 136833
# SUB 25/115: 137128
# SUB 26/115: 138231
# SUB 27/115: 139637
# SUB 28/115: 142828
# SUB 29/115: 143325
# SUB 30/115: 149337
# SUB 31/115: 149539
# SUB 32/115: 150423
# SUB 33/115: 151627
# SUB 34/115: 153429
# SUB 35/115: 157336
# SUB 36/115: 158035
# SUB 37/115: 158540
# SUB 38/115: 159239
# SUB 39/115: 161731
# SUB 40/115: 162329
# SUB 41/115: 163432
# SUB 42/115: 167743
# SUB 43/115: 169343
# SUB 44/115: 172332
# SUB 45/115: 175439
# SUB 46/115: 182739
# SUB 47/115: 185139
# SUB 48/115: 192439
# SUB 49/115: 192540
# SUB 50/115: 193239
# SUB 51/115: 194140
# SUB 52/115: 196144
# SUB 53/115: 197550
# SUB 54/115: 199251
# SUB 55/115: 200614
# SUB 56/115: 201111
# SUB 57/115: 205119
# SUB 58/115: 205725
# SUB 59/115: 210617
# SUB 60/115: 212318
# SUB 61/115: 214019
# SUB 62/115: 214221
# SUB 63/115: 214423
# SUB 64/115: 217429
# SUB 65/115: 221319
# SUB 66/115: 249947
# SUB 67/115: 255639
# SUB 68/115: 293748
# SUB 69/115: 304020
# SUB 70/115: 307127
# SUB 71/115: 329440
# SUB 72/115: 397760
# SUB 73/115: 414229
# SUB 74/115: 448347
# SUB 75/115: 485757
# SUB 76/115: 499566
# SUB 77/115: 530635
# SUB 78/115: 552544
# SUB 79/115: 559053
# SUB 80/115: 579665
# SUB 81/115: 581349
# SUB 82/115: 585862
# SUB 83/115: 598568
# SUB 84/115: 627549
# SUB 85/115: 638049
# SUB 86/115: 645551
# SUB 87/115: 654754
# SUB 88/115: 665254
# SUB 89/115: 672756
# SUB 90/115: 677968
# SUB 91/115: 702133
# SUB 92/115: 729557
# SUB 93/115: 732243
# SUB 94/115: 734045
# SUB 95/115: 748258
# SUB 96/115: 753251
# SUB 97/115: 792564
# SUB 98/115: 826353
# SUB 99/115: 856766
# SUB 100/115: 857263
# SUB 101/115: 859671
# SUB 102/115: 861456
# SUB 103/115: 865363
# SUB 104/115: 872158
# SUB 105/115: 885975
# SUB 106/115: 887373
# SUB 107/115: 889579
# SUB 108/115: 894673
# SUB 109/115: 896778
# SUB 110/115: 896879
# SUB 111/115: 901139
# SUB 112/115: 917255
# SUB 113/115: 932554
# SUB 114/115: 984472
# SUB 115/115: 992774

# %% [markdown]
# # IQ prediction

# %%
score=np.asarray(score)

# threshold for feature selection
thresh = 0.01

n_subs  = np.sum(keepSub)
n_nodes = config.nParcels

behav_pred_pos = np.zeros([n_subs,1])
behav_pred_neg = np.zeros([n_subs,1])

triu_idx = np.triu_indices(n_nodes,1)
n_edges = len(triu_idx[1]);
edges = np.zeros([n_subs,n_edges])
for iSub in range(n_subs):
    edges[iSub,] = fcMats_dn[:,:,iSub][triu_idx]

loo = cross_validation.LeaveOneOut()
lr = linear_model.LinearRegression()
errors_pos = np.zeros([n_subs,1])
errors_neg = np.zeros([n_subs,1])
predictions_pos = np.zeros([n_subs,1])
predictions_neg = np.zeros([n_subs,1])

t=time()
i=0
for train_index, test_index in loo.split(np.arange(n_subs)):
    pears = [stats.pearsonr(np.squeeze(edges[train_index,j]),score[train_index]) for j in range(0,n_edges)]
    # select edges (positively and negatively) correlated with score with threshold thresh
    idx_filtered_pos = np.array([idx for idx in range(1,n_edges) if pears[idx][1]<thresh and pears[idx][0]>0])
    idx_filtered_neg = np.array([idx for idx in range(1,n_edges) if pears[idx][1]<thresh and pears[idx][0]<0])
    filtered_pos = edges[np.ix_(train_index,idx_filtered_pos)]
    filtered_neg = edges[np.ix_(train_index,idx_filtered_neg)]
    # compute network statistic for each subject in training
    strength_pos = filtered_pos.sum(axis=1) 
    strength_neg = filtered_neg.sum(axis=1)
    # compute network statistic for test subject
    str_pos_test = edges[test_index,idx_filtered_pos].sum()
    str_neg_test = edges[test_index,idx_filtered_neg].sum()
    # regression
    lr_pos = lr.fit(strength_pos.reshape(-1,1),score[train_index])
    predictions_pos[i] = lr_pos.predict(str_pos_test)
    lr_neg = lr.fit(strength_neg.reshape(-1,1),score[train_index])
    predictions_neg[i] = lr_neg.predict(str_neg_test) 
    errors_pos[i] = abs(predictions_pos[i]-score[test_index])
    errors_neg[i] = abs(predictions_neg[i]-score[test_index])
    i=i+1
print 'Cross-validation completed in {:0.1f}s'.format(time()-t)

# plot
x = np.ravel(score)
# positive
fig = plt.figure(figsize=(10,20))
y = np.ravel(predictions_pos)
plot_corrs(x,y,'Using positive edges')
# negative
fig2 = plt.figure(figsize=(10,20))
y = np.ravel(predictions_neg)
plot_corrs(x,y,'Using negative edges')
# Out:
# Cross-validation completed in 420.4s
