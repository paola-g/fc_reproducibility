# %% [markdown]
# This notebook runs a defined pipeline on HCP subjects, on the Cedars-Sinai cluster.
# After it is done preprocessing all subjects, it runs the leave-one-out IQ prediction a la Finn.

# %% [markdown]
# # Load libraries & helper functions

# %%
from helpers import *
# %matplotlib inline

# %% [markdown]
# # Declare parameters

# %%
config.DATADIR                 = '/scratch/duboisjx/data/HCP/MRI'
# fMRI runs
session                        = 'REST1'
fmriRuns                       = ['rfMRI_'+session+'_LR','rfMRI_'+session+'_RL']
# use volume or surface data
config.fmriFileTemplate        = '#fMRIrun#.nii.gz'
#config.fmriFileTemplate        = '#fMRIrun#_Atlas.dtseries.nii'
#config.fmriFileTemplate        = '#fMRIrun#_Atlas_MSMAll.dtseries.nii'
config.overwrite               = False
config.pipelineName            = 'Finn'
config.Operations              = config.operationDict[config.pipelineName]
config.melodicFolder           = op.join('#fMRIrun#_hp2000.ica','filtered_func_data.ica') #the code #fMRIrun# will be replaced
config.movementRelativeRMSFile = 'Movement_RelativeRMS.txt'
config.movementRegressorsFile  = 'Movement_Regressors_dt.txt'
# parcellation for FC matrix
config.parcellationName        = 'shen2013'
config.parcellationFile        = '/scratch/duboisjx/data/parcellations/shenetal_neuroimage2013_new/shen_2mm_268_parcellation.nii.gz'
config.nParcels                = 268
config.maskParcelswithAll      = True
config.maskParcelswithGM       = False
# subject selection parameters
config.behavFile               = '/scratch/duboisjx/data/HCP/neuropsych/unrestricted_luckydjuju_6_7_2017_0_44_41.csv'
config.release                 = 'all'
config.outScore                = 'PMAT24_A_CR'
# submit jobs with sge
config.queue        = True

# do not alter the following lines
if config.maskParcelswithGM:
    config.parcellationName = config.parcellationName + '_GM'
tmp = config.fmriFileTemplate.split('.')
if tmp[1]=='nii':
    config.isCifti = False
elif tmp[1]=='dtseries':
    config.isCifti = True
else:
    print 'unknown file extension'

if config.pipelineName is 'SiegelB':
    config.useFIX              = True
else:
    config.useFIX              = False
config.preWhitening            = False

# whether to use memmapping (which involves unzipping)
# deprecated
config.useMemMap               = False

# %% [markdown]
# # Subject selection

# %%
df = pd.read_csv(config.behavFile)
# select subjects according to release
if config.release == 'Q2':
    ind = (df['Release'] == 'Q2') | (df['Release'] == 'Q1')
elif config.release == 'S500':
    ind = (df['Release'] == 'Q3') | (df['Release'] == 'S500')
elif config.release == 'Q2+S500':
    ind = (df['Release'] == 'Q2') | (df['Release'] == 'Q1') | (df['Release'] == 'Q3') | (df['Release'] == 'S500')
elif config.release == 'S900':
    ind = (df['Release'] == 'S900')
elif config.release == 'S1200':
    ind = (df['Release'] == 'S1200')
elif config.release == 'all':
    ind = ((df['Release'] == 'Q1') | (df['Release'] == 'Q2') | (df['Release'] == 'Q3') 
           | (df['Release'] == 'S500') | (df['Release'] == 'S900') | (df['Release'] == 'S1200'))
else:
    sys.exit("Invalid release code")
# select subjects that have completed all fMRI
ind = ind & ((df['fMRI_WM_PctCompl']==100) & (df['fMRI_Mot_PctCompl']==100) 
             & (df['fMRI_Lang_PctCompl']==100) & (df['fMRI_Emo_PctCompl']==100)         
             & (df['3T_RS-fMRI_PctCompl']==100) & (df['PMAT_Compl']==True))
df = df[ind]  
# check if either of the two subjects recommended for exclusion by HCP are still present
df = df[~df['Subject'].isin(['209733','528446'])]
df.index     = range(df.shape[0])
tmpAgeRanges = sorted(df['Age'].unique())
# list of all selected subjects
subjects     = [str(subject) for subject in df['Subject']]
# pull their IQ, Age, Gender
age          = [str(a) for a in df['Age']]
gender       = [str(g) for g in df['Gender']]
score        = np.asarray([s for s in df[config.outScore]])

print 'Selected', str(df.shape[0]), 'from the release',config.release
print 'Number of males is:', df[df['Gender']=='M'].shape[0]
try:
    print 'Age range is', tmpAgeRanges[0].split('-')[0], '-', tmpAgeRanges[-1].split('-')[1]
except:
    print 'Age range is', tmpAgeRanges[0].split('-')[0], '-', tmpAgeRanges[-1]
# Exclusion of high-motion subjects
# exclude subjects with >0.14 frame-to-frame head motion estimate averged across both rest runs (arbitrary threshold as in Finn et al 2015)
RelRMSMean = np.zeros([len(subjects), len(fmriRuns)],dtype=np.float32)
compSub    = np.zeros((len(subjects)),dtype=np.bool_)
keepSub    = np.zeros((len(subjects)),dtype=np.bool_)
iSub=0
for config.subject in subjects:
    i=0
    for config.fmriRun in fmriRuns:
        RelRMSMeanFile = op.join(buildpath(), 'Movement_RelativeRMS_mean.txt')
        #print RelRMSMeanFile
        if op.isfile(RelRMSMeanFile):
            with open(RelRMSMeanFile,'r') as tmp:
                RelRMSMean[iSub,i] = float(tmp.read())
        else:
            print RelRMSMeanFile+' File missing'
            break
        i=i+1
    if i==len(fmriRuns): # all RelRMSMeanFile exist
        compSub[iSub]=True
        if np.mean(RelRMSMean[iSub,:]) > 0.14:
            print config.subject, ': too much motion, exclude'
        else:
            keepSub[iSub]=True
    iSub=iSub+1

#### motion vs. score correlation
plt.scatter(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1),c='r')
plt.scatter(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1),c='b')
# fit a curve to the data using a least squares 1st order polynomial fit
z1 = np.polyfit(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1),1)
z2 = np.polyfit(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1),1)
p1 = np.poly1d(z1)
p2 = np.poly1d(z2)                
fit1 = p1(score[keepSub])
fit2 = p2(score[compSub])
# get the coordinates for the fit curve
c1_x = [np.min(score[keepSub]),np.max(score[keepSub])]
c1_y = p1(c1_x)
c2_x = [np.min(score[compSub]),np.max(score[compSub])]
c2_y = p2(c2_x)
# plot line of best fit
plt.plot(c2_x,c2_y,'r-',label='before exclusion')
plt.plot(c1_x,c1_y,'b-',label='after exclusion')
plt.xlabel('Score [{}]'.format(config.outScore))
plt.ylabel('RelRMSMean')
plt.legend(loc=0)
plt.show()
rho1,p1 = stats.pearsonr(score[keepSub],np.mean(RelRMSMean[keepSub,:],axis=1))
rho2,p2 = stats.pearsonr(score[compSub],np.mean(RelRMSMean[compSub,:],axis=1))            
print 'With all subjects: corr(IQ,motion) = {:.3f} (p = {:.3f})'.format(rho2,p2)
print 'After discarding high movers: corr(IQ,motion) = {:.3f} (p = {:.3f})'.format(rho1,p1)
    
subjects   = [subject for (subject, keep) in zip(subjects, keepSub) if keep]
age        = [a for (a, keep) in zip(age, keepSub) if keep]
gender     = [g for (g, keep) in zip(gender, keepSub) if keep]
score      = score[keepSub]
RelRMSMean = RelRMSMean[keepSub,:]
print 'Keeping {} subjects [{} M]'.format(len(subjects),sum([g=='M' for g in gender]))
# Out:
# Selected 957 from the release all
# Number of males is: 452
# Age range is 22 - Age range is 22 - 36+
# 104820 : too much motion, exclude
# 108121 : too much motion, exclude
# 114924 : too much motion, exclude
# 123117 : too much motion, exclude
# 124220 : too much motion, exclude
# 136732 : too much motion, exclude
# 140824 : too much motion, exclude
# 140925 : too much motion, exclude
# 147030 : too much motion, exclude
# 151223 : too much motion, exclude
# 151324 : too much motion, exclude
# 151526 : too much motion, exclude
# 151728 : too much motion, exclude
# 153833 : too much motion, exclude
# 156637 : too much motion, exclude
# 159138 : too much motion, exclude
# 161327 : too much motion, exclude
# 161832 : too much motion, exclude
# 163331 : too much motion, exclude
# 163836 : too much motion, exclude
# 166640 : too much motion, exclude
# /scratch/duboisjx/data/HCP/MRI/169040/MNINonLinear/Results/rfMRI_REST1_LR/Movement_RelativeRMS_mean.txt File missing
# 171532 : too much motion, exclude
# 176239 : too much motion, exclude
# 180129 : too much motion, exclude
# 181636 : too much motion, exclude
# 191437 : too much motion, exclude
# 197348 : too much motion, exclude
# 198249 : too much motion, exclude
# 199150 : too much motion, exclude
# 205220 : too much motion, exclude
# 207123 : too much motion, exclude
# 207426 : too much motion, exclude
# 209834 : too much motion, exclude
# 212217 : too much motion, exclude
# 223929 : too much motion, exclude
# 233326 : too much motion, exclude
# 250427 : too much motion, exclude
# 295146 : too much motion, exclude
# 298051 : too much motion, exclude
# 311320 : too much motion, exclude
# 346137 : too much motion, exclude
# 352132 : too much motion, exclude
# 366446 : too much motion, exclude
# 378756 : too much motion, exclude
# 382242 : too much motion, exclude
# 392447 : too much motion, exclude
# 397861 : too much motion, exclude
# 453542 : too much motion, exclude
# 465852 : too much motion, exclude
# 468050 : too much motion, exclude
# 555348 : too much motion, exclude
# 562345 : too much motion, exclude
# 576255 : too much motion, exclude
# 609143 : too much motion, exclude
# 633847 : too much motion, exclude
# 680250 : too much motion, exclude
# 686969 : too much motion, exclude
# 698168 : too much motion, exclude
# 748662 : too much motion, exclude
# 779370 : too much motion, exclude
# 788876 : too much motion, exclude
# 833249 : too much motion, exclude
# 837964 : too much motion, exclude
# 901038 : too much motion, exclude
# 919966 : too much motion, exclude
# 922854 : too much motion, exclude
# 937160 : too much motion, exclude
# 947668 : too much motion, exclude
# With all subjects: corr(IQ,motion) = -0.147 (p = 0.000)
# After discarding high movers: corr(IQ,motion) = -0.134 (p = 0.000)
# Keeping 888 subjects [420 M]

# %% [markdown]
# # Do work

# %% [markdown]
# ### preprocess everybody

# %%
keepSub = np.zeros((len(subjects)),dtype=np.bool_)
iSub    = 0
for config.subject in subjects:
    iRun = 0
    for config.fmriRun in fmriRuns:
        keepSub[iSub] = runPipelinePar(launchSubproc=False)
        if not keepSub[iSub]:
            break
        iRun=iRun+1
    iSub = iSub + 1
print 'Keeping {}/{} subjects'.format(np.sum(keepSub),len(subjects))
subjects   = [subject for (subject, keep) in zip(subjects, keepSub) if keep]
age        = [a for (a, keep) in zip(age, keepSub) if keep]
gender     = [g for (g, keep) in zip(gender, keepSub) if keep]
score      = score[keepSub]
RelRMSMean = RelRMSMean[keepSub,:]

# launch array job (if there is something to do)
if len(config.scriptlist)>0:
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    JobID = fnSubmitJobArrayFromJobList()
    print 'Running array job {} ({} sub jobs)'.format(JobID.split('.')[0],JobID.split('.')[1].split('-')[1].split(':')[0])
    config.joblist.append(JobID.split('.')[0])
    checkProgress()
# Out:
# Keeping 888/888 subjects

# %% [markdown]
# ### run prediction in Q2 (sanity check)

# %%
#----------------------
# prepare
#----------------------
config.queue        = True
config.sgeopts      = '-l mem_free=25G -pe smp 6' 
config.overwrite    = False
config.fmriFile_dn  = ''
newdf = df[df['Subject'].isin([int(s) for s in subjects])]  
idx_smpl      = np.where(np.ravel(newdf['Release'].isin(['Q1','Q2'])))[0]
# define nSubPerSample
nSubPerSample = idx_smpl.shape[0]
outDir = op.join(config.DATADIR,'Results','samples_nsub{}_{}'.format(nSubPerSample,0))
if not op.isdir(outDir):
    mkdir(outDir)
smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
smpl_score    = score[idx_smpl]
smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
motFile = op.join(outDir,'RMS_{}.txt'.format(session))
np.savetxt(motFile, smpl_motscore)
fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
    session,config.pipelineName, config.parcellationName, config.release))
overwrite = False
if not op.isfile(fcMatFile) or overwrite:
    fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
    iSub= 0
    for config.subject in smpl_subjects:
        iRun = 0
        for config.fmriRun in fmriRuns:
            # set the global variable config
            runPipelinePar(launchSubproc=False)
            #print 'Found denoised data: {}'.format(config.fmriFile_dn)
            tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
            rstring = get_rcode(config.fmriFile_dn)
            fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
            fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
            iRun = iRun+1
        iSub = iSub + 1
    fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
    results = {}
    results['fcMats']        = fcMats_dn
    results['subjects']      = smpl_subjects
    results[config.outScore] = np.asarray(smpl_score)
    sio.savemat(fcMatFile, results)
fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
#----------------------
# predict!
#----------------------
idcode           = session
predict          = 'IQ'
config.queue     = True
launchSubproc    = False
config.sgeopts   = '-l mem_free=2G' 
config.overwrite = False
newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
# run the IQ prediction for each subject
for model in ['IQ']:
    for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
        for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
            resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                config.release))
            if not op.isfile(resFile) or config.overwrite:
                runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                 regression=regression, outDir=outDir)
                checkProgress(pause=10,verbose=False)
                # merge cross-validation folds, save results
                n_subs          = fcMats_dn.shape[-1]
                predictions_pos = np.zeros([n_subs,1])
                predictions_neg = np.zeros([n_subs,1])
                iSub = 0
                for subject in smpl_subjects:
                    subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                        model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                        config.release))
                    while not op.isfile(subResFile):
                        sleep(.1)
                    results = sio.loadmat(subResFile) 
                    if regression=='Finn':
                        predictions_neg[iSub] = results['pred_neg']
                        predictions_pos[iSub] = results['pred_pos']
                    else:
                        predictions_pos[iSub] = results['pred']
                    iSub = iSub + 1
                if predict=='IQ':
                    rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                elif predict=='motion':
                    rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                if regression=='Finn':
                    results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                else:
                    results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                if regression=='Finn':
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                    results['rho_neg'] = rho
                    results['p_neg'] = p
                # save result
                sio.savemat(resFile,results)

            while not op.isfile(resFile):
                sleep(.1)
            results = sio.loadmat(resFile)

            if regression=='Finn':
                print ('{},nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                    config.release,nSubPerSample,0,0,config.pipelineName,config.parcellationName,
                    config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                      )
                print ('{},nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                    config.release,nSubPerSample,0,0,config.pipelineName,config.parcellationName,
                    config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                      )
            else:
                print ('{},nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                    config.release,nSubPerSample,0,0,config.pipelineName,config.parcellationName,
                    config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                      )
# Out:
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:38: RuntimeWarning: divide by zero encountered in arctanh
# all,nsub113,nsamp0,0,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.416559318575,p=4.44893205694e-06
# all,nsub113,nsamp0,0,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.285969182043,p=0.00213712098351

# %% [markdown]
# ### run prediction in random samples (from all subjects)

# %%
# Generate random samples from all subjects
nRep = 1000
sampleFile = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}.txt'.format(nSubPerSample,nRep))
if not op.isfile(sampleFile) or config.overwrite:
    samples = np.vstack([random.sample(range(len(subjects)),nSubPerSample) for i in range(nRep)])
    np.savetxt(sampleFile, samples)
else:
    samples = np.loadtxt(sampleFile,dtype=np.int16)

#do work
outDir_ = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}'.format(nSubPerSample,nRep))
if not op.isdir(outDir_):
    mkdir(outDir_)
for iSample in range(500):#nRep):
    outDir = op.join(outDir_,'{}'.format(iSample+1))
    if not op.isdir(outDir):
        mkdir(outDir)
    #----------------------
    # prepare
    #----------------------
    config.queue        = True
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    config.overwrite    = False
    config.fmriFile_dn  = ''
    idx_smpl      = samples[iSample,:]
    # reorder indices!
    idx_smpl      = np.sort(idx_smpl)
    smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
    smpl_score    = score[idx_smpl]
    smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
    motFile = op.join(outDir,'RMS_{}.txt'.format(session))
    np.savetxt(motFile, smpl_motscore)
    fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
        session,config.pipelineName, config.parcellationName, config.release))
    overwrite = False
    if not op.isfile(fcMatFile) or overwrite:
        fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
        iSub= 0
        for config.subject in smpl_subjects:
            iRun = 0
            for config.fmriRun in fmriRuns:
                # set the global variable config
                runPipelinePar(launchSubproc=False)
                #print 'Found denoised data: {}'.format(config.fmriFile_dn)
                tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
                rstring = get_rcode(config.fmriFile_dn)
                fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
                fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
                iRun = iRun+1
            iSub = iSub + 1
        fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
        results = {}
        results['fcMats']        = fcMats_dn
        results['subjects']      = smpl_subjects
        results[config.outScore] = np.asarray(smpl_score)
        sio.savemat(fcMatFile, results)
    fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
    #----------------------
    # predict!
    #----------------------
    idcode           = session
    predict          = 'IQ'
    config.queue     = True
    launchSubproc    = False
    config.sgeopts   = '-l mem_free=2G' 
    config.overwrite = False
    newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
    # run the IQ prediction for each subject
    for model in ['IQ']:
        for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
            for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
                resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                    model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                    config.release))
                if not op.isfile(resFile) or config.overwrite:
                    runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                     regression=regression, outDir=outDir)
                    checkProgress(pause=10,verbose=False)
                    # merge cross-validation folds, save results
                    n_subs          = fcMats_dn.shape[-1]
                    predictions_pos = np.zeros([n_subs,1])
                    predictions_neg = np.zeros([n_subs,1])
                    iSub = 0
                    for subject in smpl_subjects:
                        subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                            model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                            config.release))
                        while not op.isfile(subResFile):
                            sleep(.1)
                        results = sio.loadmat(subResFile) 
                        if regression=='Finn':
                            predictions_neg[iSub] = results['pred_neg']
                            predictions_pos[iSub] = results['pred_pos']
                        else:
                            predictions_pos[iSub] = results['pred']
                        iSub = iSub + 1
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                    if regression=='Finn':
                        results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                    else:
                        results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                    if regression=='Finn':
                        if predict=='IQ':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                        elif predict=='motion':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                        results['rho_neg'] = rho
                        results['p_neg'] = p
                    # save result
                    sio.savemat(resFile,results)

                while not op.isfile(resFile):
                    sleep(.1)
                results = sio.loadmat(resFile)

                if regression=='Finn':
                    print ('{},nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                          )
                    print ('{},nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                          )
                else:
                    print ('{},nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                          )
# Out:
# all,nsub113,nsamp1000,1,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.293388325682,p=0.00161164792616
# all,nsub113,nsamp1000,1,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.214308879921,p=0.0226459231498
# all,nsub113,nsamp1000,2,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.055955641108,p=0.556086319587
# all,nsub113,nsamp1000,2,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0231962469011,p=0.807330989701
# all,nsub113,nsamp1000,3,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.134056167873,p=0.156895472332
# all,nsub113,nsamp1000,3,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.252495117394,p=0.00697405038701
# all,nsub113,nsamp1000,4,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.264420745422,p=0.00465284951355
# all,nsub113,nsamp1000,4,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.158173648225,p=0.0942751516997
# all,nsub113,nsamp1000,5,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.242823274945,p=0.00955711994372
# all,nsub113,nsamp1000,5,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.12601149741,p=0.18353971353
# all,nsub113,nsamp1000,6,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0657292992883,p=0.489130884264
# all,nsub113,nsamp1000,6,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0400388638728,p=0.673714508422
# all,nsub113,nsamp1000,7,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.364068115201,p=7.37058521903e-05
# all,nsub113,nsamp1000,7,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.224450480526,p=0.016848784894
# all,nsub113,nsamp1000,8,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0432419580025,p=0.649274538285
# all,nsub113,nsamp1000,8,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.108340820147,p=0.253354526929
# all,nsub113,nsamp1000,9,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0483625080749,p=0.610974982937
# all,nsub113,nsamp1000,9,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0177166223524,p=0.852248003446
# all,nsub113,nsamp1000,10,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.183097860939,p=0.0522389303073
# all,nsub113,nsamp1000,10,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.164840494381,p=0.0810280597393
# all,nsub113,nsamp1000,11,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.132494015622,p=0.161828996016
# all,nsub113,nsamp1000,11,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.109045476354,p=0.250262059357
# all,nsub113,nsamp1000,12,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.157376682939,p=0.0959672045447
# all,nsub113,nsamp1000,12,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0701160972644,p=0.460535089127
# all,nsub113,nsamp1000,13,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.117546662288,p=0.214994390542
# all,nsub113,nsamp1000,13,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.291140497956,p=0.00175689462188
# all,nsub113,nsamp1000,14,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0962255163955,p=0.310643314369
# all,nsub113,nsamp1000,14,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.275643402561,p=0.00312648176552
# all,nsub113,nsamp1000,15,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.102987841471,p=0.277703504911
# all,nsub113,nsamp1000,15,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.171073502992,p=0.0700330595393
# all,nsub113,nsamp1000,16,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.214662915372,p=0.0224179133754
# all,nsub113,nsamp1000,16,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.173825341792,p=0.06557943455
# all,nsub113,nsamp1000,17,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.356030537995,p=0.000108752403946
# all,nsub113,nsamp1000,17,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.175875815898,p=0.062412943196
# all,nsub113,nsamp1000,18,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.202253840735,p=0.0316869372138
# all,nsub113,nsamp1000,18,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.191229571554,p=0.0424622507131
# all,nsub113,nsamp1000,19,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00920351297616,p=0.922925777256
# all,nsub113,nsamp1000,19,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.141048322252,p=0.136183808695
# all,nsub113,nsamp1000,20,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0269547168107,p=0.776871599978
# all,nsub113,nsamp1000,20,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0762480377796,p=0.422156697264
# all,nsub113,nsamp1000,21,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0781171812499,p=0.410836819985
# all,nsub113,nsamp1000,21,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.201733107359,p=0.0321380207128
# all,nsub113,nsamp1000,22,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00643696321325,p=0.946051715406
# all,nsub113,nsamp1000,22,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.119888689246,p=0.205931658828
# all,nsub113,nsamp1000,23,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.116078570205,p=0.220817922233
# all,nsub113,nsamp1000,23,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.14149204928,p=0.134943319439
# all,nsub113,nsamp1000,24,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.078227539543,p=0.410174077178
# all,nsub113,nsamp1000,24,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.159338661179,p=0.091844238178
# all,nsub113,nsamp1000,25,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0136434819282,p=0.885953509623
# all,nsub113,nsamp1000,25,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0319652912453,p=0.736792783022
# all,nsub113,nsamp1000,26,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.186607924788,p=0.047812214155
# all,nsub113,nsamp1000,26,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0741330802848,p=0.435180148077
# all,nsub113,nsamp1000,27,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.313644973411,p=0.000717506066498
# all,nsub113,nsamp1000,27,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.292223128292,p=0.00168551884727
# all,nsub113,nsamp1000,28,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.316192642569,p=0.000645419696389
# all,nsub113,nsamp1000,28,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.24530301728,p=0.00882517668787
# all,nsub113,nsamp1000,29,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0803384090718,p=0.397618585692
# all,nsub113,nsamp1000,29,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.121158066448,p=0.201135643615
# all,nsub113,nsamp1000,30,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00454047896325,p=0.96193178957
# all,nsub113,nsamp1000,30,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.10023301739,p=0.290827722069
# all,nsub113,nsamp1000,31,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0763492560999,p=0.421539120525
# all,nsub113,nsamp1000,31,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0745912453923,p=0.432339623379
# all,nsub113,nsamp1000,32,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.264094057073,p=0.00470585921142
# all,nsub113,nsamp1000,32,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.180859579454,p=0.0552343831491
# all,nsub113,nsamp1000,33,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.218496537392,p=0.020072384881
# all,nsub113,nsamp1000,33,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0566383809367,p=0.551269688953
# all,nsub113,nsamp1000,34,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.109170970006,p=0.249714055128
# all,nsub113,nsamp1000,34,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.101075708916,p=0.286770106254
# all,nsub113,nsamp1000,35,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.178847931391,p=0.0580456905265
# all,nsub113,nsamp1000,35,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.195719863712,p=0.0377521574679
# all,nsub113,nsamp1000,36,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0463803398915,p=0.625684003946
# all,nsub113,nsamp1000,36,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.285591058733,p=0.00216764807461
# all,nsub113,nsamp1000,37,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.134826340967,p=0.15450494092
# all,nsub113,nsamp1000,37,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.168454743797,p=0.0744956604406
# all,nsub113,nsamp1000,38,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.216375186973,p=0.0213427388821
# all,nsub113,nsamp1000,38,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.214941215084,p=0.0222400643968
# all,nsub113,nsamp1000,39,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0807003012924,p=0.395489231749
# all,nsub113,nsamp1000,39,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.149329367679,p=0.114425958828
# all,nsub113,nsamp1000,40,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.012622651157,p=0.894435395585
# all,nsub113,nsamp1000,40,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0212312439208,p=0.823374412662
# all,nsub113,nsamp1000,41,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.244341701175,p=0.00910284758479
# all,nsub113,nsamp1000,41,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.119531282211,p=0.207296694395
# all,nsub113,nsamp1000,42,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.173571375544,p=0.0659805629142
# all,nsub113,nsamp1000,42,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0497889775605,p=0.600484174549
# all,nsub113,nsamp1000,43,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0379170702623,p=0.690095184121
# all,nsub113,nsamp1000,43,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.122925110367,p=0.194593913947
# all,nsub113,nsamp1000,44,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0711377613473,p=0.454010246161
# all,nsub113,nsamp1000,44,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.10007252352,p=0.291604807777
# all,nsub113,nsamp1000,45,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00517287124388,p=0.956634534306
# all,nsub113,nsamp1000,45,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.152101815761,p=0.107778394955
# all,nsub113,nsamp1000,46,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.15809990127,p=0.0944307279653
# all,nsub113,nsamp1000,46,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0535072663225,p=0.573523869899
# all,nsub113,nsamp1000,47,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.116541404454,p=0.218970065202
# all,nsub113,nsamp1000,47,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.126875744101,p=0.180528205518
# all,nsub113,nsamp1000,48,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.152174895838,p=0.107607339495
# all,nsub113,nsamp1000,48,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.21014152156,p=0.0254827527939
# all,nsub113,nsamp1000,49,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0475937738106,p=0.616661575933
# all,nsub113,nsamp1000,49,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0396556333407,p=0.676662129301
# all,nsub113,nsamp1000,50,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0519485609492,p=0.584756642523
# all,nsub113,nsamp1000,50,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.209793870234,p=0.025732547583
# all,nsub113,nsamp1000,51,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0588315732824,p=0.535935332645
# all,nsub113,nsamp1000,51,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.099916759079,p=0.292360309532
# all,nsub113,nsamp1000,52,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.213175236745,p=0.0233894464435
# all,nsub113,nsamp1000,52,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.130912679312,p=0.166939829845
# all,nsub113,nsamp1000,53,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.188574084874,p=0.045471579223
# all,nsub113,nsamp1000,53,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.16554919422,p=0.079712234578
# all,nsub113,nsamp1000,54,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.158147797654,p=0.0943296628679
# all,nsub113,nsamp1000,54,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0835053725325,p=0.379216040244
# all,nsub113,nsamp1000,55,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.223799551631,p=0.0171778759325
# all,nsub113,nsamp1000,55,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0238766946332,p=0.801793641089
# all,nsub113,nsamp1000,56,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.141802196295,p=0.13408139571
# all,nsub113,nsamp1000,56,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0787540755162,p=0.40702067179
# all,nsub113,nsamp1000,57,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0767483007066,p=0.419109475035
# all,nsub113,nsamp1000,57,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0553082587541,p=0.560672133919
# all,nsub113,nsamp1000,58,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0717606256074,p=0.450057701174
# all,nsub113,nsamp1000,58,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.160302460886,p=0.0898709565105
# all,nsub113,nsamp1000,59,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.114494567877,p=0.227225398392
# all,nsub113,nsamp1000,59,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0598685983824,p=0.528759181916
# all,nsub113,nsamp1000,60,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0457305891658,p=0.630538136973
# all,nsub113,nsamp1000,60,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.118632794037,p=0.210756840516
# all,nsub113,nsamp1000,61,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.129001644709,p=0.173274742949
# all,nsub113,nsamp1000,61,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.209499643361,p=0.0259455849764
# all,nsub113,nsamp1000,62,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.180660686807,p=0.0555072543874
# all,nsub113,nsamp1000,62,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0914217635685,p=0.335527510532
# all,nsub113,nsamp1000,63,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0138031662395,p=0.884627863455
# all,nsub113,nsamp1000,63,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.102566827954,p=0.279683067299
# all,nsub113,nsamp1000,64,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0122014318013,p=0.897938754988
# all,nsub113,nsamp1000,64,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0339258023715,p=0.721294575393
# all,nsub113,nsamp1000,65,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.014244236952,p=0.88096790668
# all,nsub113,nsamp1000,65,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00760905391713,p=0.936247462619
# all,nsub113,nsamp1000,66,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.273443809589,p=0.00338422843699
# all,nsub113,nsamp1000,66,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.303094469264,p=0.00110149755209
# all,nsub113,nsamp1000,67,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.183043004862,p=0.0523107076594
# all,nsub113,nsamp1000,67,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0368860119371,p=0.698107750562
# all,nsub113,nsamp1000,68,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.186152042128,p=0.0483689560769
# all,nsub113,nsamp1000,68,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.167291239009,p=0.0765505693961
# all,nsub113,nsamp1000,69,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.205641107697,p=0.0288815436228
# all,nsub113,nsamp1000,69,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.273772510902,p=0.00334453701423
# all,nsub113,nsamp1000,70,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0969764432501,p=0.306864892825
# all,nsub113,nsamp1000,70,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.102293869892,p=0.28097153138
# all,nsub113,nsamp1000,71,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0672976412678,p=0.478800500379
# all,nsub113,nsamp1000,71,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0195167196546,p=0.837432766671
# all,nsub113,nsamp1000,72,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.109244653481,p=0.249392680615
# all,nsub113,nsamp1000,72,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.188115974663,p=0.0460082500781
# all,nsub113,nsamp1000,73,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0820337854724,p=0.387701947346
# all,nsub113,nsamp1000,73,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00478431539217,p=0.959889076472
# all,nsub113,nsamp1000,74,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.230372052585,p=0.0140973457481
# all,nsub113,nsamp1000,74,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.109675779663,p=0.247518015624
# all,nsub113,nsamp1000,75,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.145750398163,p=0.123472828565
# all,nsub113,nsamp1000,75,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.191578028453,p=0.042079985173
# all,nsub113,nsamp1000,76,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.134437182544,p=0.155709411061
# all,nsub113,nsamp1000,76,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.133193231529,p=0.159606667861
# all,nsub113,nsamp1000,77,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.280795565266,p=0.00259050920211
# all,nsub113,nsamp1000,77,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.235814797533,p=0.0119221191451
# all,nsub113,nsamp1000,78,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.109920729175,p=0.246457248285
# all,nsub113,nsamp1000,78,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0783265889612,p=0.409579782457
# all,nsub113,nsamp1000,79,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.154761438304,p=0.101688591389
# all,nsub113,nsamp1000,79,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.148952921489,p=0.115352598039
# all,nsub113,nsamp1000,80,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.343264673874,p=0.000197542477403
# all,nsub113,nsamp1000,80,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.226805735182,p=0.0157032247482
# all,nsub113,nsamp1000,81,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.246428881841,p=0.00850948876341
# all,nsub113,nsamp1000,81,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.367297278495,p=6.28577526118e-05
# all,nsub113,nsamp1000,82,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0646021274348,p=0.496627856268
# all,nsub113,nsamp1000,82,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.133122149023,p=0.159831545231
# all,nsub113,nsamp1000,83,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.191836504891,p=0.0417982895601
# all,nsub113,nsamp1000,83,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.161175788782,p=0.0881121184906
# all,nsub113,nsamp1000,84,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00461263756578,p=0.961327262467
# all,nsub113,nsamp1000,84,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.145505515764,p=0.124111416343
# all,nsub113,nsamp1000,85,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.105381622154,p=0.266627310895
# all,nsub113,nsamp1000,85,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0974481760557,p=0.304506707855
# all,nsub113,nsamp1000,86,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.249681135227,p=0.00765280502825
# all,nsub113,nsamp1000,86,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0546765059681,p=0.565164576776
# all,nsub113,nsamp1000,87,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0823131260756,p=0.386082411022
# all,nsub113,nsamp1000,87,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.142907840322,p=0.131042870342
# all,nsub113,nsamp1000,88,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.305082037018,p=0.00101726827545
# all,nsub113,nsamp1000,88,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.242699016892,p=0.0095951623939
# all,nsub113,nsamp1000,89,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.10461129973,p=0.270158439665
# all,nsub113,nsamp1000,89,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.140380195592,p=0.138067987789
# all,nsub113,nsamp1000,90,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0099119212736,p=0.917013649406
# all,nsub113,nsamp1000,90,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0215181061722,p=0.821027589518
# all,nsub113,nsamp1000,91,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.448982700001,p=6.10457704099e-07
# all,nsub113,nsamp1000,91,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00649648161904,p=0.945553651716
# all,nsub113,nsamp1000,92,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00537396036061,p=0.954950489313
# all,nsub113,nsamp1000,92,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.245529037437,p=0.00876098604988
# all,nsub113,nsamp1000,93,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0980573595469,p=0.301479013848
# all,nsub113,nsamp1000,93,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0142707330869,p=0.880748123673
# all,nsub113,nsamp1000,94,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.297001759885,p=0.00140086850879
# all,nsub113,nsamp1000,94,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.25840034525,p=0.00572047771891
# all,nsub113,nsamp1000,95,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0532880776956,p=0.575097335115
# all,nsub113,nsamp1000,95,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.123506195332,p=0.192476713594
# all,nsub113,nsamp1000,96,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.180416911876,p=0.0558432122367
# all,nsub113,nsamp1000,96,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0176091622223,p=0.853134108868
# all,nsub113,nsamp1000,97,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.118807922176,p=0.210079195735
# all,nsub113,nsamp1000,97,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0588510279035,p=0.535800263955
# all,nsub113,nsamp1000,98,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.111826984342,p=0.238309459718
# all,nsub113,nsamp1000,98,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.289088582515,p=0.00189973960645
# all,nsub113,nsamp1000,99,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.174871803127,p=0.0639474659734
# all,nsub113,nsamp1000,99,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.131425552852,p=0.165269292457
# all,nsub113,nsamp1000,100,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0439588887409,p=0.643853753013
# all,nsub113,nsamp1000,100,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.200583361986,p=0.033153236493
# all,nsub113,nsamp1000,101,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.113556708857,p=0.231080201938
# all,nsub113,nsamp1000,101,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.249045906732,p=0.00781387557445
# all,nsub113,nsamp1000,102,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.135640058699,p=0.152009016021
# all,nsub113,nsamp1000,102,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0275615797369,p=0.771983719658
# all,nsub113,nsamp1000,103,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.138692893044,p=0.142914511091
# all,nsub113,nsamp1000,103,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0756091784572,p=0.426066706535
# all,nsub113,nsamp1000,104,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0025781314824,p=0.978378986538
# all,nsub113,nsamp1000,104,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.019829432676,p=0.834864697007
# all,nsub113,nsamp1000,105,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0486715694692,p=0.608695230346
# all,nsub113,nsamp1000,105,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0230811357269,p=0.808268692264
# all,nsub113,nsamp1000,106,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.224204340734,p=0.0169725786638
# all,nsub113,nsamp1000,106,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.239487412415,p=0.0106257291149
# all,nsub113,nsamp1000,107,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0962914578832,p=0.310310310262
# all,nsub113,nsamp1000,107,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.215233383477,p=0.0220546561443
# all,nsub113,nsamp1000,108,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0518273991263,p=0.58563400206
# all,nsub113,nsamp1000,108,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0345323891517,p=0.716521832065
# all,nsub113,nsamp1000,109,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.165337461365,p=0.0801035464338
# all,nsub113,nsamp1000,109,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0495250044894,p=0.602419470256
# all,nsub113,nsamp1000,110,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0912577924776,p=0.336398659725
# all,nsub113,nsamp1000,110,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.085505543044,p=0.367864430688
# all,nsub113,nsamp1000,111,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.255727674142,p=0.00626060625692
# all,nsub113,nsamp1000,111,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.230279838371,p=0.0141369958667
# all,nsub113,nsamp1000,112,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.239646718387,p=0.0105724088409
# all,nsub113,nsamp1000,112,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.254510318268,p=0.00652129622959
# all,nsub113,nsamp1000,113,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0857457281242,p=0.366515484578
# all,nsub113,nsamp1000,113,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0197305562401,p=0.835676506123
# all,nsub113,nsamp1000,114,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0584403366375,p=0.538655177938
# all,nsub113,nsamp1000,114,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.104434124954,p=0.270975056136
# all,nsub113,nsamp1000,115,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.148810880558,p=0.115703746795
# all,nsub113,nsamp1000,115,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.000797697701947,p=0.993309528209
# all,nsub113,nsamp1000,116,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00505631939147,p=0.957610699702
# all,nsub113,nsamp1000,116,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.000249579929604,p=0.997906694619
# all,nsub113,nsamp1000,117,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0944184222612,p=0.319859633328
# all,nsub113,nsamp1000,117,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.136513106791,p=0.149364911004
# all,nsub113,nsamp1000,118,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0828638935384,p=0.382901180693
# all,nsub113,nsamp1000,118,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.139314394685,p=0.141114576053
# all,nsub113,nsamp1000,119,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0336410793963,p=0.723538541993
# all,nsub113,nsamp1000,119,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0380177108112,p=0.689314900817
# all,nsub113,nsamp1000,120,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0192824053686,p=0.839358130147
# all,nsub113,nsamp1000,120,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.13027352931,p=0.169039155995
# all,nsub113,nsamp1000,121,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0434438298317,p=0.647746295232
# all,nsub113,nsamp1000,121,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.10134981078,p=0.285458454068
# all,nsub113,nsamp1000,122,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0273302686586,p=0.773845736689
# all,nsub113,nsamp1000,122,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0818910454868,p=0.388531087112
# all,nsub113,nsamp1000,123,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0496156584842,p=0.601754535894
# all,nsub113,nsamp1000,123,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.121022585485,p=0.201643658022
# all,nsub113,nsamp1000,124,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.110648495926,p=0.243324168151
# all,nsub113,nsamp1000,124,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.148262184194,p=0.11706800556
# all,nsub113,nsamp1000,125,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.187108828289,p=0.0472066272654
# all,nsub113,nsamp1000,125,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0692951536248,p=0.465815295404
# all,nsub113,nsamp1000,126,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.14935795614,p=0.114355823829
# all,nsub113,nsamp1000,126,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.160260806514,p=0.0899555378049
# all,nsub113,nsamp1000,127,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.179997474778,p=0.0564251678269
# all,nsub113,nsamp1000,127,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.153091125113,p=0.105480711007
# all,nsub113,nsamp1000,128,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.149645870545,p=0.113651353498
# all,nsub113,nsamp1000,128,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.126435713384,p=0.182056957862
# all,nsub113,nsamp1000,129,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.215120349419,p=0.0221262289608
# all,nsub113,nsamp1000,129,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.189263894179,p=0.0446733006852
# all,nsub113,nsamp1000,130,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0628888472161,p=0.50813781401
# all,nsub113,nsamp1000,130,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0599479903752,p=0.528211789209
# all,nsub113,nsamp1000,131,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0473530978805,p=0.618446633458
# all,nsub113,nsamp1000,131,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.101081969326,p=0.28674010376
# all,nsub113,nsamp1000,132,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0846070468264,p=0.372937624333
# all,nsub113,nsamp1000,132,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0907568863317,p=0.339068765042
# all,nsub113,nsamp1000,133,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.138613472058,p=0.143145769443
# all,nsub113,nsamp1000,133,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0436730584903,p=0.646012725128
# all,nsub113,nsamp1000,134,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.158718954249,p=0.0931310579171
# all,nsub113,nsamp1000,134,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00351475380936,p=0.970527235296
# all,nsub113,nsamp1000,135,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.234138541588,p=0.0125584260965
# all,nsub113,nsamp1000,135,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.198006825441,p=0.0355269441432
# all,nsub113,nsamp1000,136,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0188733358937,p=0.842721726727
# all,nsub113,nsamp1000,136,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.238940037521,p=0.0108107394189
# all,nsub113,nsamp1000,137,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0615145974069,p=0.517468906009
# all,nsub113,nsamp1000,137,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.208674312984,p=0.0265512164348
# all,nsub113,nsamp1000,138,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0789737438818,p=0.405709314064
# all,nsub113,nsamp1000,138,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0627649278068,p=0.508975634491
# all,nsub113,nsamp1000,139,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.114542334267,p=0.227030285807
# all,nsub113,nsamp1000,139,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.158861271292,p=0.0928342817241
# all,nsub113,nsamp1000,140,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.248390151357,p=0.00798328644671
# all,nsub113,nsamp1000,140,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.127071567692,p=0.179850908509
# all,nsub113,nsamp1000,141,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0296106146724,p=0.755546975351
# all,nsub113,nsamp1000,141,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.108483658697,p=0.252725551395
# all,nsub113,nsamp1000,142,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0361954338435,p=0.703493061743
# all,nsub113,nsamp1000,142,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0751009091985,p=0.429192297233
# all,nsub113,nsamp1000,143,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0894259015483,p=0.346228605334
# all,nsub113,nsamp1000,143,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0703461165326,p=0.459061578385
# all,nsub113,nsamp1000,144,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0831368847173,p=0.381330274906
# all,nsub113,nsamp1000,144,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.130793882868,p=0.167328554308
# all,nsub113,nsamp1000,145,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.314916841428,p=0.000680643933269
# all,nsub113,nsamp1000,145,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.30254898424,p=0.00112570138805
# all,nsub113,nsamp1000,146,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.066326174535,p=0.485185475813
# all,nsub113,nsamp1000,146,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0598894338546,p=0.528615497731
# all,nsub113,nsamp1000,147,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.168603237884,p=0.0742366289679
# all,nsub113,nsamp1000,147,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.10354304389,p=0.275107421813
# all,nsub113,nsamp1000,148,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0279800051257,p=0.768618757992
# all,nsub113,nsamp1000,148,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0255216624456,p=0.788448224347
# all,nsub113,nsamp1000,149,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.136928791528,p=0.148118205276
# all,nsub113,nsamp1000,149,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.301484376277,p=0.00117434142119
# all,nsub113,nsamp1000,150,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0224455483611,p=0.813451083095
# all,nsub113,nsamp1000,150,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0463498931502,p=0.625911109389
# all,nsub113,nsamp1000,151,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.184443515191,p=0.05050347098
# all,nsub113,nsamp1000,151,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.041312145157,p=0.663956698599
# all,nsub113,nsamp1000,152,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.129135710574,p=0.172824627055
# all,nsub113,nsamp1000,152,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0774213982513,p=0.41502968001
# all,nsub113,nsamp1000,153,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.033969789596,p=0.720948112453
# all,nsub113,nsamp1000,153,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.12262160165,p=0.19570643418
# all,nsub113,nsamp1000,154,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.209869132526,p=0.0256782936006
# all,nsub113,nsamp1000,154,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.152095787556,p=0.107792514396
# all,nsub113,nsamp1000,155,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.27120560308,p=0.00366593310527
# all,nsub113,nsamp1000,155,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.289767390658,p=0.00185136002972
# all,nsub113,nsamp1000,156,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.161657746059,p=0.0871532692109
# all,nsub113,nsamp1000,156,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.179721558065,p=0.0568107019229
# all,nsub113,nsamp1000,157,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.105714451549,p=0.265111367489
# all,nsub113,nsamp1000,157,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.102008219496,p=0.282324158161
# all,nsub113,nsamp1000,158,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0577073990989,p=0.543768806453
# all,nsub113,nsamp1000,158,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.377582046519,p=3.74277570694e-05
# all,nsub113,nsamp1000,159,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.291067741293,p=0.00176178822796
# all,nsub113,nsamp1000,159,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0143560544889,p=0.880040452115
# all,nsub113,nsamp1000,160,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0373598551459,p=0.694421230482
# all,nsub113,nsamp1000,160,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0910822360918,p=0.337332949062
# all,nsub113,nsamp1000,161,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.168870556245,p=0.073772152051
# all,nsub113,nsamp1000,161,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.168170837167,p=0.0749929315062
# all,nsub113,nsamp1000,162,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0239540382201,p=0.801164849882
# all,nsub113,nsamp1000,162,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0781762485468,p=0.410482020795
# all,nsub113,nsamp1000,163,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.106883099963,p=0.25983495587
# all,nsub113,nsamp1000,163,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.219849412432,p=0.0192966796903
# all,nsub113,nsamp1000,164,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00713019035476,p=0.940251971243
# all,nsub113,nsamp1000,164,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.136673776755,p=0.1488821026
# all,nsub113,nsamp1000,165,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.121915195843,p=0.198313577189
# all,nsub113,nsamp1000,165,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.18662018067,p=0.0477973204321
# all,nsub113,nsamp1000,166,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.189462943224,p=0.0444451320255
# all,nsub113,nsamp1000,166,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.181288911857,p=0.0546491184872
# all,nsub113,nsamp1000,167,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.129771267231,p=0.170702524431
# all,nsub113,nsamp1000,167,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.09268054282,p=0.328887626075
# all,nsub113,nsamp1000,168,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.191602404011,p=0.0420533524437
# all,nsub113,nsamp1000,168,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.166534048717,p=0.077912187454
# all,nsub113,nsamp1000,169,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.17959868112,p=0.0569830904242
# all,nsub113,nsamp1000,169,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0652694534502,p=0.492182099238
# all,nsub113,nsamp1000,170,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0937154278756,p=0.323492132237
# all,nsub113,nsamp1000,170,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.136106205775,p=0.150592907238
# all,nsub113,nsamp1000,171,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0610498294623,p=0.520644336859
# all,nsub113,nsamp1000,171,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0937800217926,p=0.323157261733
# all,nsub113,nsamp1000,172,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0760025550329,p=0.42365666458
# all,nsub113,nsamp1000,172,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0388336445688,p=0.683000919883
# all,nsub113,nsamp1000,173,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.208141174599,p=0.0269488061474
# all,nsub113,nsamp1000,173,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0245835228139,p=0.796051997646
# all,nsub113,nsamp1000,174,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0211272143888,p=0.824225865668
# all,nsub113,nsamp1000,174,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.172973549431,p=0.0669326788232
# all,nsub113,nsamp1000,175,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.244656645018,p=0.00901104211088
# all,nsub113,nsamp1000,175,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.304510406998,p=0.00104086941084
# all,nsub113,nsamp1000,176,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.074787195751,p=0.431128014391
# all,nsub113,nsamp1000,176,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.182247042747,p=0.0533613824917
# all,nsub113,nsamp1000,177,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.130784656023,p=0.167358774339
# all,nsub113,nsamp1000,177,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.160987299846,p=0.0884893900494
# all,nsub113,nsamp1000,178,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.188876499248,p=0.0451201637509
# all,nsub113,nsamp1000,178,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.104549551942,p=0.270442852269
# all,nsub113,nsamp1000,179,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.343424154847,p=0.000196105511493
# all,nsub113,nsamp1000,179,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00569858693104,p=0.952232286831
# all,nsub113,nsamp1000,180,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.256590256449,p=0.00608153236567
# all,nsub113,nsamp1000,180,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0750366480107,p=0.429588403963
# all,nsub113,nsamp1000,181,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.133577275469,p=0.158395783721
# all,nsub113,nsamp1000,181,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0505807430945,p=0.594696115666
# all,nsub113,nsamp1000,182,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.212668061981,p=0.0237287959164
# all,nsub113,nsamp1000,182,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.190534384426,p=0.0432335460891
# all,nsub113,nsamp1000,183,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0196588039409,p=0.836265725057
# all,nsub113,nsamp1000,183,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.129000538966,p=0.173278458986
# all,nsub113,nsamp1000,184,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.231781361346,p=0.0135033086406
# all,nsub113,nsamp1000,184,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.272619255001,p=0.00348566322345
# all,nsub113,nsamp1000,185,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.267612418159,p=0.0041623440532
# all,nsub113,nsamp1000,185,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0813182682675,p=0.391868900408
# all,nsub113,nsamp1000,186,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.147677351598,p=0.118535793442
# all,nsub113,nsamp1000,186,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0588403535088,p=0.535874371581
# all,nsub113,nsamp1000,187,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.103991424933,p=0.273022792181
# all,nsub113,nsamp1000,187,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.153924941664,p=0.103574087407
# all,nsub113,nsamp1000,188,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.199419836269,p=0.0342080494582
# all,nsub113,nsamp1000,188,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0906543431796,p=0.339617025919
# all,nsub113,nsamp1000,189,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.168546463061,p=0.0743355804886
# all,nsub113,nsamp1000,189,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.200353970339,p=0.0333589940037
# all,nsub113,nsamp1000,190,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.262332260901,p=0.00500113868015
# all,nsub113,nsamp1000,190,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.204678000992,p=0.0296568805956
# all,nsub113,nsamp1000,191,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.191715546048,p=0.0419299176246
# all,nsub113,nsamp1000,191,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.264401494466,p=0.00465595839679
# all,nsub113,nsamp1000,192,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0382783546571,p=0.687295601104
# all,nsub113,nsamp1000,192,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.023829234754,p=0.802179545178
# all,nsub113,nsamp1000,193,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0590348308083,p=0.534525000458
# all,nsub113,nsamp1000,193,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0795621710671,p=0.402208859839
# all,nsub113,nsamp1000,194,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.265113613357,p=0.00454218347908
# all,nsub113,nsamp1000,194,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.217728374902,p=0.0205246658547
# all,nsub113,nsamp1000,195,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.127255441716,p=0.179216639046
# all,nsub113,nsamp1000,195,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.179507739089,p=0.0571109525055
# all,nsub113,nsamp1000,196,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.253709134186,p=0.00669807721296
# all,nsub113,nsamp1000,196,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.209540263096,p=0.0259160847223
# all,nsub113,nsamp1000,197,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0955276336841,p=0.314181871926
# all,nsub113,nsamp1000,197,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.199002777483,p=0.0345929652116
# all,nsub113,nsamp1000,198,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.196078215598,p=0.0373959427851
# all,nsub113,nsamp1000,198,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.274302719619,p=0.00328139375258
# all,nsub113,nsamp1000,199,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.242674009895,p=0.00960283453375
# all,nsub113,nsamp1000,199,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.255364547544,p=0.00633738197943
# all,nsub113,nsamp1000,200,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.201028357938,p=0.0327571424769
# all,nsub113,nsamp1000,200,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0300418996193,p=0.752100922761
# all,nsub113,nsamp1000,201,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.171209552852,p=0.0698072648955
# all,nsub113,nsamp1000,201,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.192953441821,p=0.0405990562015
# all,nsub113,nsamp1000,202,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.112008651752,p=0.237542876871
# all,nsub113,nsamp1000,202,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0701769779301,p=0.460144831941
# all,nsub113,nsamp1000,203,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.326168657323,p=0.000422527147703
# all,nsub113,nsamp1000,203,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.202647065004,p=0.0313498673637
# all,nsub113,nsamp1000,204,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0453023908426,p=0.633745741846
# all,nsub113,nsamp1000,204,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.144062729358,p=0.12792554723
# all,nsub113,nsamp1000,205,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.125964633087,p=0.183704057385
# all,nsub113,nsamp1000,205,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.101465608206,p=0.284905535788
# all,nsub113,nsamp1000,206,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.175797432058,p=0.0625316528526
# all,nsub113,nsamp1000,206,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.028100143988,p=0.767653396653
# all,nsub113,nsamp1000,207,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00896377352384,p=0.924927526831
# all,nsub113,nsamp1000,207,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0302592840255,p=0.750365819214
# all,nsub113,nsamp1000,208,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.103411251732,p=0.275722187434
# all,nsub113,nsamp1000,208,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0617603224794,p=0.515794045359
# all,nsub113,nsamp1000,209,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.179908241439,p=0.0565496164353
# all,nsub113,nsamp1000,209,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0825749845111,p=0.384567937581
# all,nsub113,nsamp1000,210,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.10714555292,p=0.258659919356
# all,nsub113,nsamp1000,210,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0488643969417,p=0.607274758117
# all,nsub113,nsamp1000,211,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.1962553757,p=0.0372208842205
# all,nsub113,nsamp1000,211,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0150369088006,p=0.874396751427
# all,nsub113,nsamp1000,212,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0593341081312,p=0.532451789008
# all,nsub113,nsamp1000,212,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.247008350517,p=0.00835092385325
# all,nsub113,nsamp1000,213,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0942001027621,p=0.320984901473
# all,nsub113,nsamp1000,213,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.274413541707,p=0.00326833193671
# all,nsub113,nsamp1000,214,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.235555881892,p=0.012018523584
# all,nsub113,nsamp1000,214,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0933210317553,p=0.325541614219
# all,nsub113,nsamp1000,215,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.293333760813,p=0.00161504052323
# all,nsub113,nsamp1000,215,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.132149027777,p=0.162933927741
# all,nsub113,nsamp1000,216,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.122315504083,p=0.196833094268
# all,nsub113,nsamp1000,216,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0874566885256,p=0.356994521935
# all,nsub113,nsamp1000,217,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0973393518525,p=0.305049662411
# all,nsub113,nsamp1000,217,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.201109059225,p=0.0326857395697
# all,nsub113,nsamp1000,218,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0718536366221,p=0.44946913107
# all,nsub113,nsamp1000,218,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0183785858495,p=0.846793615973
# all,nsub113,nsamp1000,219,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.267450714781,p=0.00418603554436
# all,nsub113,nsamp1000,219,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0781306969217,p=0.410755619631
# all,nsub113,nsamp1000,220,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.000292147288379,p=0.997549669816
# all,nsub113,nsamp1000,220,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.146518550795,p=0.121486102242
# all,nsub113,nsamp1000,221,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.137845566442,p=0.145396388661
# all,nsub113,nsamp1000,221,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0319087210023,p=0.73724158769
# all,nsub113,nsamp1000,222,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.186269412685,p=0.0482251076229
# all,nsub113,nsamp1000,222,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0515187355161,p=0.587871822974
# all,nsub113,nsamp1000,223,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.242178930171,p=0.00975583950422
# all,nsub113,nsamp1000,223,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.138001177888,p=0.144938168242
# all,nsub113,nsamp1000,224,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.114532945705,p=0.227068626197
# all,nsub113,nsamp1000,224,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.110627943249,p=0.243412268064
# all,nsub113,nsamp1000,225,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.204181122787,p=0.0300637430467
# all,nsub113,nsamp1000,225,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.198900801407,p=0.0346876351777
# ...
# all,nsub113,nsamp1000,426,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00615277021093,p=0.948430191179
# all,nsub113,nsamp1000,427,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0273486141155,p=0.773698011679
# all,nsub113,nsamp1000,427,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.200102649566,p=0.0335856574313
# all,nsub113,nsamp1000,428,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.142293736696,p=0.132723976614
# all,nsub113,nsamp1000,428,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.171449102783,p=0.0694111296553
# all,nsub113,nsamp1000,429,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0514907294305,p=0.588075060843
# all,nsub113,nsamp1000,429,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0182218674102,p=0.848084286589
# all,nsub113,nsamp1000,430,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.133019290224,p=0.16015736873
# all,nsub113,nsamp1000,430,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.111805343862,p=0.23840089085
# all,nsub113,nsamp1000,431,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.116171803958,p=0.220444804017
# all,nsub113,nsamp1000,431,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0895283357803,p=0.345674225
# all,nsub113,nsamp1000,432,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0515387712506,p=0.587726444953
# all,nsub113,nsamp1000,432,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0462049257372,p=0.626992916473
# all,nsub113,nsamp1000,433,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0687054882058,p=0.469628325564
# all,nsub113,nsamp1000,433,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0781689082596,p=0.410526101882
# all,nsub113,nsamp1000,434,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.160144878536,p=0.0901912681401
# all,nsub113,nsamp1000,434,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0391820132552,p=0.680311740169
# all,nsub113,nsamp1000,435,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00513532373436,p=0.95694900182
# all,nsub113,nsamp1000,435,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.106571861719,p=0.261233128506
# all,nsub113,nsamp1000,436,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0719636635409,p=0.448773441258
# all,nsub113,nsamp1000,436,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.333936614094,p=0.000300737527199
# all,nsub113,nsamp1000,437,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0550773702196,p=0.562312020874
# all,nsub113,nsamp1000,437,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.132418286067,p=0.162071064399
# all,nsub113,nsamp1000,438,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0774345769989,p=0.414950032473
# all,nsub113,nsamp1000,438,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.147098763062,p=0.120001877362
# all,nsub113,nsamp1000,439,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.151298119714,p=0.109673611852
# all,nsub113,nsamp1000,439,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.126697551736,p=0.181146143408
# all,nsub113,nsamp1000,440,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.116680532896,p=0.218416745049
# all,nsub113,nsamp1000,440,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0425583914938,p=0.654460176498
# all,nsub113,nsamp1000,441,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.186612938832,p=0.0478061204705
# all,nsub113,nsamp1000,441,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00617648379934,p=0.948231709147
# all,nsub113,nsamp1000,442,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.134334562572,p=0.156028194492
# all,nsub113,nsamp1000,442,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0620118731413,p=0.514082356017
# all,nsub113,nsamp1000,443,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.268675918625,p=0.00400949571806
# all,nsub113,nsamp1000,443,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.13853550223,p=0.143373077707
# all,nsub113,nsamp1000,444,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.025703423451,p=0.786977294258
# all,nsub113,nsamp1000,444,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.24132475116,p=0.0100248675745
# all,nsub113,nsamp1000,445,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0895937279789,p=0.345320610412
# all,nsub113,nsamp1000,445,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.139664134277,p=0.140109278965
# all,nsub113,nsamp1000,446,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0142285678625,p=0.881097884596
# all,nsub113,nsamp1000,446,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.046199948241,p=0.62703007469
# all,nsub113,nsamp1000,447,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0820709121521,p=0.387486462503
# all,nsub113,nsamp1000,447,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0263843481389,p=0.781473504055
# all,nsub113,nsamp1000,448,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0032653842066,p=0.972617468752
# all,nsub113,nsamp1000,448,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.113557454168,p=0.231077120466
# all,nsub113,nsamp1000,449,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00193447540145,p=0.983776030878
# all,nsub113,nsamp1000,449,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.202227748225,p=0.0317094116237
# all,nsub113,nsamp1000,450,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0732924842455,p=0.440419191203
# all,nsub113,nsamp1000,450,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.118296121291,p=0.212063948041
# all,nsub113,nsamp1000,451,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.147569431615,p=0.118808195368
# all,nsub113,nsamp1000,451,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0450194945713,p=0.635868634083
# all,nsub113,nsamp1000,452,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0201524945995,p=0.83221346311
# all,nsub113,nsamp1000,452,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.116019327925,p=0.221055239712
# all,nsub113,nsamp1000,453,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.159558190306,p=0.0913917815968
# all,nsub113,nsamp1000,453,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.171226289086,p=0.0697795294302
# all,nsub113,nsamp1000,454,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.207425507994,p=0.027490478945
# all,nsub113,nsamp1000,454,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0483936946876,p=0.610744769485
# all,nsub113,nsamp1000,455,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.198361944338,p=0.0351915170934
# all,nsub113,nsamp1000,455,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0637586929193,p=0.502276925301
# all,nsub113,nsamp1000,456,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.269168629957,p=0.00394040145401
# all,nsub113,nsamp1000,456,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.124040915487,p=0.19054324641
# all,nsub113,nsamp1000,457,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.125403961369,p=0.185678565079
# all,nsub113,nsamp1000,457,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.147549645951,p=0.118858189031
# all,nsub113,nsamp1000,458,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0314478063976,p=0.740901573558
# all,nsub113,nsamp1000,458,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0906620030863,p=0.339576051819
# all,nsub113,nsamp1000,459,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0810032577566,p=0.393711890412
# all,nsub113,nsamp1000,459,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.168729331713,p=0.0740172427368
# all,nsub113,nsamp1000,460,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.209055136785,p=0.0262702855943
# all,nsub113,nsamp1000,460,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0796297280592,p=0.401808121342
# all,nsub113,nsamp1000,461,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.127851310034,p=0.177172478683
# all,nsub113,nsamp1000,461,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.122132337352,p=0.197509516543
# all,nsub113,nsamp1000,462,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.116544377479,p=0.218958230972
# all,nsub113,nsamp1000,462,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.00688835292863,p=0.942274915586
# all,nsub113,nsamp1000,463,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.205723472104,p=0.0288160435934
# all,nsub113,nsamp1000,463,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.225741982746,p=0.016211967899
# all,nsub113,nsamp1000,464,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.167257484277,p=0.0766108585526
# all,nsub113,nsamp1000,464,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.152467140325,p=0.106925413918
# all,nsub113,nsamp1000,465,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0102840860435,p=0.913909484648
# all,nsub113,nsamp1000,465,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0400023229013,p=0.673995351443
# all,nsub113,nsamp1000,466,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0149407087594,p=0.87519379208
# all,nsub113,nsamp1000,466,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.242934856935,p=0.00952307147169
# all,nsub113,nsamp1000,467,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0220519089142,p=0.816664762328
# all,nsub113,nsamp1000,467,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0540097515382,p=0.569924352145
# all,nsub113,nsamp1000,468,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.183528341304,p=0.0516784768417
# all,nsub113,nsamp1000,468,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0359730524611,p=0.705230393918
# all,nsub113,nsamp1000,469,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.105160735573,p=0.267636627999
# all,nsub113,nsamp1000,469,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0723913916252,p=0.446074691908
# all,nsub113,nsamp1000,470,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0972735012791,p=0.30537851698
# all,nsub113,nsamp1000,470,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0522037894566,p=0.582910451822
# all,nsub113,nsamp1000,471,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.074700038024,p=0.43166669193
# all,nsub113,nsamp1000,471,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0560179454939,p=0.555645932694
# all,nsub113,nsamp1000,472,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.000573772622927,p=0.995187611853
# all,nsub113,nsamp1000,472,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0636766218077,p=0.502828396982
# all,nsub113,nsamp1000,473,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.226983078998,p=0.0156197708007
# all,nsub113,nsamp1000,473,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.201939134656,p=0.0319589054619
# all,nsub113,nsamp1000,474,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.136828936054,p=0.148416969973
# all,nsub113,nsamp1000,474,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0148768919505,p=0.87572259877
# all,nsub113,nsamp1000,475,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.248131573637,p=0.00805097534722
# all,nsub113,nsamp1000,475,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0877137986578,p=0.355577184793
# all,nsub113,nsamp1000,476,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.132716462615,p=0.161119504476
# all,nsub113,nsamp1000,476,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.193079973527,p=0.0404650341834
# all,nsub113,nsamp1000,477,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.198443442351,p=0.0351149155725
# all,nsub113,nsamp1000,477,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.206389845897,p=0.0282907364292
# all,nsub113,nsamp1000,478,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.104528391334,p=0.270540365388
# all,nsub113,nsamp1000,478,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.092715401296,p=0.328704956241
# all,nsub113,nsamp1000,479,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.106534067104,p=0.261403261613
# all,nsub113,nsamp1000,479,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.109790206902,p=0.247022090409
# all,nsub113,nsamp1000,480,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0544541743967,p=0.566749644081
# all,nsub113,nsamp1000,480,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0941776054778,p=0.321101002383
# all,nsub113,nsamp1000,481,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0560371690309,p=0.555510088634
# all,nsub113,nsamp1000,481,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.104009423872,p=0.272939333936
# all,nsub113,nsamp1000,482,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0614505547585,p=0.517905876013
# all,nsub113,nsamp1000,482,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.19508653778,p=0.0383886690774
# all,nsub113,nsamp1000,483,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.321728380823,p=0.000511121717463
# all,nsub113,nsamp1000,483,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.25508332651,p=0.0063974135335
# all,nsub113,nsamp1000,484,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0545830572318,p=0.565830544235
# all,nsub113,nsamp1000,484,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.129068124736,p=0.173051433427
# all,nsub113,nsamp1000,485,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.285274376873,p=0.00219351759857
# all,nsub113,nsamp1000,485,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.178376221134,p=0.0587216120775
# all,nsub113,nsamp1000,486,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.215913461499,p=0.021628212431
# all,nsub113,nsamp1000,486,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.220243360414,p=0.0190757151239
# all,nsub113,nsamp1000,487,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.123263308579,p=0.193359638062
# all,nsub113,nsamp1000,487,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.000510104576264,p=0.995721607836
# all,nsub113,nsamp1000,488,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.117299284525,p=0.215967946303
# all,nsub113,nsamp1000,488,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0605758597801,p=0.523892804415
# all,nsub113,nsamp1000,489,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.205582153547,p=0.0289285043169
# all,nsub113,nsamp1000,489,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.228380661407,p=0.0149754628455
# all,nsub113,nsamp1000,490,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.168735050416,p=0.0740073053701
# all,nsub113,nsamp1000,490,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0370706675016,p=0.696670281138
# all,nsub113,nsamp1000,491,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.220506394855,p=0.0189293974599
# all,nsub113,nsamp1000,491,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.163788189716,p=0.0830138735263
# all,nsub113,nsamp1000,492,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0717088742156,p=0.45038536843
# all,nsub113,nsamp1000,492,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.162536580117,p=0.0854262355425
# all,nsub113,nsamp1000,493,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0143510857905,p=0.880081660837
# all,nsub113,nsamp1000,493,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0963147353053,p=0.310192814957
# all,nsub113,nsamp1000,494,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.193697437578,p=0.039816315099
# all,nsub113,nsamp1000,494,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.110761601996,p=0.242839729757
# all,nsub113,nsamp1000,495,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.307087387622,p=0.000938283757577
# all,nsub113,nsamp1000,495,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.21953981337,p=0.0194718781087
# all,nsub113,nsamp1000,496,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0817191309833,p=0.389531106821
# all,nsub113,nsamp1000,496,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.110959194748,p=0.241995036829
# all,nsub113,nsamp1000,497,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.187463726108,p=0.0467814223852
# all,nsub113,nsamp1000,497,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0702153113498,p=0.459899200767
# all,nsub113,nsamp1000,498,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.175467030641,p=0.0630340607186
# all,nsub113,nsamp1000,498,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.150284437268,p=0.11210093923
# all,nsub113,nsamp1000,499,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.138351037625,p=0.143911941423
# all,nsub113,nsamp1000,499,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0624620612849,p=0.511026319227
# all,nsub113,nsamp1000,500,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0478669248167,p=0.614638360647
# all,nsub113,nsamp1000,500,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0235576871019,p=0.804388456466

# %% [markdown]
# ### The recon algorithm changed after Q3
# This could be important, and explain why the random sampling typically gives worse performance
# https://wiki.humanconnectome.org/display/PublicData/Ramifications+of+Image+Reconstruction+Version+Differences

# %% [markdown]
# ### r177 recon

# %%
# Generate random samples from r177 subjects
newdf       = df[df['Subject'].isin([int(s) for s in subjects])]  
idx_smpl  = np.where(np.ravel(newdf['fMRI_3T_ReconVrs'].isin(['r177'])))[0]
print "{} subjects with r177 recon".format(idx_smpl.shape[0])
nRep = 1000
sampleFile = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_r177.txt'.format(nSubPerSample,nRep))
if not op.isfile(sampleFile) or config.overwrite:
    samples = np.vstack([random.sample(idx_smpl,nSubPerSample) for i in range(nRep)])
    np.savetxt(sampleFile, samples)
else:
    samples = np.loadtxt(sampleFile,dtype=np.int16)
    
# do work
outDir_ = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_r177'.format(nSubPerSample,nRep))
if not op.isdir(outDir_):
    mkdir(outDir_)
for iSample in range(100):#nRep):
    outDir = op.join(outDir_,'{}'.format(iSample+1))
    if not op.isdir(outDir):
        mkdir(outDir)
    #----------------------
    # prepare
    #----------------------
    config.queue        = True
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    config.overwrite    = False
    config.fmriFile_dn  = ''
    idx_smpl      = samples[iSample,:]
    # reorder indices!
    idx_smpl      = np.sort(idx_smpl)
    smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
    smpl_score    = score[idx_smpl]
    smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
    motFile = op.join(outDir,'RMS_{}.txt'.format(session))
    np.savetxt(motFile, smpl_motscore)
    fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
        session,config.pipelineName, config.parcellationName, config.release))
    overwrite = False
    if not op.isfile(fcMatFile) or overwrite:
        fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
        iSub= 0
        for config.subject in smpl_subjects:
            iRun = 0
            for config.fmriRun in fmriRuns:
                # set the global variable config
                runPipelinePar(launchSubproc=False)
                #print 'Found denoised data: {}'.format(config.fmriFile_dn)
                tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
                rstring = get_rcode(config.fmriFile_dn)
                fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
                fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
                iRun = iRun+1
            iSub = iSub + 1
        fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
        results = {}
        results['fcMats']        = fcMats_dn
        results['subjects']      = smpl_subjects
        results[config.outScore] = np.asarray(smpl_score)
        sio.savemat(fcMatFile, results)
    fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
    #----------------------
    # predict!
    #----------------------
    idcode           = session
    predict          = 'IQ'
    config.queue     = True
    launchSubproc    = False
    config.sgeopts   = '-l mem_free=2G' 
    config.overwrite = False
    newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
    # run the IQ prediction for each subject
    for model in ['IQ']:
        for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
            for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
                resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                    model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                    config.release))
                if not op.isfile(resFile) or config.overwrite:
                    runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                     regression=regression, outDir=outDir)
                    checkProgress(pause=10,verbose=False)
                    # merge cross-validation folds, save results
                    n_subs          = fcMats_dn.shape[-1]
                    predictions_pos = np.zeros([n_subs,1])
                    predictions_neg = np.zeros([n_subs,1])
                    iSub = 0
                    for subject in smpl_subjects:
                        subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                            model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                            config.release))
                        while not op.isfile(subResFile):
                            sleep(.1)
                        results = sio.loadmat(subResFile) 
                        if regression=='Finn':
                            predictions_neg[iSub] = results['pred_neg']
                            predictions_pos[iSub] = results['pred_pos']
                        else:
                            predictions_pos[iSub] = results['pred']
                        iSub = iSub + 1
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                    if regression=='Finn':
                        results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                    else:
                        results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                    if regression=='Finn':
                        if predict=='IQ':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                        elif predict=='motion':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                        results['rho_neg'] = rho
                        results['p_neg'] = p
                    # save result
                    sio.savemat(resFile,results)

                while not op.isfile(resFile):
                    sleep(.1)
                results = sio.loadmat(resFile)

                if regression=='Finn':
                    print ('{}r177,nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                          )
                    print ('{}r177,nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                          )
                else:
                    print ('{}r177,nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                          )
# Out:
# 163 subjects with r177 recon
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:54: RuntimeWarning: divide by zero encountered in arctanh
# allr177,nsub113,nsamp1000,1,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.224309748147,p=0.016919468905
# allr177,nsub113,nsamp1000,1,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.156459496279,p=0.0979440781604
# allr177,nsub113,nsamp1000,2,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.254517839265,p=0.00651965652521
# allr177,nsub113,nsamp1000,2,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.129075210291,p=0.173027645239
# allr177,nsub113,nsamp1000,3,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.374158557937,p=4.4564366642e-05
# allr177,nsub113,nsamp1000,3,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.453944654564,p=4.42184661485e-07
# allr177,nsub113,nsamp1000,4,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.184825710712,p=0.0500193438685
# allr177,nsub113,nsamp1000,4,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.243695084267,p=0.0092939201017
# allr177,nsub113,nsamp1000,5,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.309295870157,p=0.000857812209429
# allr177,nsub113,nsamp1000,5,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.175208686572,p=0.0634291869896
# allr177,nsub113,nsamp1000,6,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.306649647246,p=0.000955030647238
# allr177,nsub113,nsamp1000,6,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0256541365485,p=0.787376082579
# allr177,nsub113,nsamp1000,7,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.272253390099,p=0.00353153879616
# allr177,nsub113,nsamp1000,7,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.258595079808,p=0.00568279385444
# allr177,nsub113,nsamp1000,8,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.21715608157,p=0.0208672955695
# allr177,nsub113,nsamp1000,8,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.252986382682,p=0.0068611841116
# allr177,nsub113,nsamp1000,9,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.202437313898,p=0.0315292853895
# allr177,nsub113,nsamp1000,9,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.239578253814,p=0.0105952953452
# allr177,nsub113,nsamp1000,10,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.319326051282,p=0.00056588724205
# allr177,nsub113,nsamp1000,10,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.261803198585,p=0.00509298015064
# allr177,nsub113,nsamp1000,11,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.339708065548,p=0.00023223703492
# allr177,nsub113,nsamp1000,11,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.206578563224,p=0.0281434564284
# allr177,nsub113,nsamp1000,12,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.192230879193,p=0.0413715232528
# allr177,nsub113,nsamp1000,12,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.183563529497,p=0.0516328846981
# allr177,nsub113,nsamp1000,13,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.249503585397,p=0.00769752687573
# allr177,nsub113,nsamp1000,13,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.115265195048,p=0.224091974884
# allr177,nsub113,nsamp1000,14,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.265288504946,p=0.00451462390271
# allr177,nsub113,nsamp1000,14,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.172948339531,p=0.0669730727575
# allr177,nsub113,nsamp1000,15,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.21657179922,p=0.021222164499
# allr177,nsub113,nsamp1000,15,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.292052410968,p=0.0016965962687
# allr177,nsub113,nsamp1000,16,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.125799653342,p=0.184283463956
# allr177,nsub113,nsamp1000,16,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.136316825111,p=0.149956329766
# allr177,nsub113,nsamp1000,17,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.185548579728,p=0.0491141786473
# allr177,nsub113,nsamp1000,17,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.210268008565,p=0.0253923840996
# allr177,nsub113,nsamp1000,18,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.355317412314,p=0.000112515340978
# allr177,nsub113,nsamp1000,18,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.106611370931,p=0.26105535786
# allr177,nsub113,nsamp1000,19,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.424004278775,p=2.87084847231e-06
# allr177,nsub113,nsamp1000,19,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.27893397849,p=0.00277377248388
# allr177,nsub113,nsamp1000,20,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.394202787221,p=1.55946115336e-05
# allr177,nsub113,nsamp1000,20,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.327661273821,p=0.000396079339156
# allr177,nsub113,nsamp1000,21,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.300113693394,p=0.00123978483957
# allr177,nsub113,nsamp1000,21,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.167948259083,p=0.0753846506797
# allr177,nsub113,nsamp1000,22,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.370081237537,p=5.47213133409e-05
# allr177,nsub113,nsamp1000,22,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.31470803919,p=0.000686573910512
# allr177,nsub113,nsamp1000,23,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.232386503388,p=0.0132550065993
# allr177,nsub113,nsamp1000,23,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.308818847633,p=0.000874639107076
# allr177,nsub113,nsamp1000,24,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.321437855603,p=0.000517475405489
# allr177,nsub113,nsamp1000,24,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.298997432787,p=0.0012955162967
# allr177,nsub113,nsamp1000,25,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.176300818103,p=0.0617724890628
# allr177,nsub113,nsamp1000,25,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0904385257883,p=0.340772753751
# allr177,nsub113,nsamp1000,26,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.123919231341,p=0.190981993221
# allr177,nsub113,nsamp1000,26,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.111856129332,p=0.238186360594
# allr177,nsub113,nsamp1000,27,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.255201225373,p=0.00637218478643
# allr177,nsub113,nsamp1000,27,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.26598959182,p=0.00440564002673
# allr177,nsub113,nsamp1000,28,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.187886340736,p=0.0462792372418
# allr177,nsub113,nsamp1000,28,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.259285761149,p=0.0055509118862
# allr177,nsub113,nsamp1000,29,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.246906770887,p=0.00837853004541
# allr177,nsub113,nsamp1000,29,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.110092795816,p=0.245713985853
# allr177,nsub113,nsamp1000,30,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.237086768324,p=0.0114582723945
# allr177,nsub113,nsamp1000,30,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.367874597501,p=6.10829048416e-05
# allr177,nsub113,nsamp1000,31,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.378655160311,p=3.54209962742e-05
# allr177,nsub113,nsamp1000,31,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.206478614956,p=0.0282213773105
# allr177,nsub113,nsamp1000,32,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.202057920532,p=0.0318560199848
# allr177,nsub113,nsamp1000,32,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.280550516625,p=0.0026139918853
# allr177,nsub113,nsamp1000,33,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.288387622811,p=0.00195089722431
# allr177,nsub113,nsamp1000,33,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0675718884357,p=0.477006236701
# allr177,nsub113,nsamp1000,34,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.168838397839,p=0.0738279043106
# allr177,nsub113,nsamp1000,34,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.175558331752,p=0.0628949004326
# allr177,nsub113,nsamp1000,35,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.281235243357,p=0.00254885188963
# allr177,nsub113,nsamp1000,35,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.167902627303,p=0.0754651620214
# allr177,nsub113,nsamp1000,36,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.440001635822,p=1.08041015261e-06
# allr177,nsub113,nsamp1000,36,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.170497423397,p=0.0709957083139
# allr177,nsub113,nsamp1000,37,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.288217813541,p=0.0019634765223
# allr177,nsub113,nsamp1000,37,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.123202445843,p=0.193581340941
# allr177,nsub113,nsamp1000,38,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.265401894114,p=0.00449683587259
# allr177,nsub113,nsamp1000,38,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.275547677383,p=0.00313732050118
# allr177,nsub113,nsamp1000,39,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.310136852129,p=0.000828866149102
# allr177,nsub113,nsamp1000,39,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.229023223431,p=0.0146870654469
# allr177,nsub113,nsamp1000,40,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.278647438214,p=0.00280299538344
# allr177,nsub113,nsamp1000,40,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.295338584023,p=0.00149455679885
# allr177,nsub113,nsamp1000,41,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.442567545259,p=9.19339207763e-07
# allr177,nsub113,nsamp1000,41,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.384494906233,p=2.61543160699e-05
# allr177,nsub113,nsamp1000,42,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.28382081742,p=0.00231587523594
# allr177,nsub113,nsamp1000,42,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.131666581648,p=0.164488511234
# allr177,nsub113,nsamp1000,43,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.382601744994,p=2.88747885824e-05
# allr177,nsub113,nsamp1000,43,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0300462218433,p=0.752066411861
# allr177,nsub113,nsamp1000,44,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.36183471303,p=8.22044577962e-05
# allr177,nsub113,nsamp1000,44,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.325366344296,p=0.000437406470991
# allr177,nsub113,nsamp1000,45,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.349846280799,p=0.00014567773888
# allr177,nsub113,nsamp1000,45,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.215439593057,p=0.0219245965673
# allr177,nsub113,nsamp1000,46,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.222242253044,p=0.0179878548058
# allr177,nsub113,nsamp1000,46,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.136154027967,p=0.150448191077
# allr177,nsub113,nsamp1000,47,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.459514224186,p=3.06016121262e-07
# allr177,nsub113,nsamp1000,47,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.109736781138,p=0.247253551031
# allr177,nsub113,nsamp1000,48,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.28318803232,p=0.00237104231104
# allr177,nsub113,nsamp1000,48,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.300210794914,p=0.00123504162545
# allr177,nsub113,nsamp1000,49,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.188085228587,p=0.0460444563961
# allr177,nsub113,nsamp1000,49,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.230005654817,p=0.0142554627966
# allr177,nsub113,nsamp1000,50,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.216862881273,p=0.0210447304202
# allr177,nsub113,nsamp1000,50,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.133575187103,p=0.1584023497
# allr177,nsub113,nsamp1000,51,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.119811066789,p=0.206227571363
# allr177,nsub113,nsamp1000,51,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0747326856263,p=0.431464868666
# allr177,nsub113,nsamp1000,52,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.219002521605,p=0.0197791796277
# allr177,nsub113,nsamp1000,52,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.267715409716,p=0.00414731717199
# allr177,nsub113,nsamp1000,53,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.187606683178,p=0.0466110453189
# allr177,nsub113,nsamp1000,53,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.189530306489,p=0.0443681339517
# allr177,nsub113,nsamp1000,54,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.210152084362,p=0.0254751957068
# allr177,nsub113,nsamp1000,54,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.132135269061,p=0.16297811043
# allr177,nsub113,nsamp1000,55,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.119567981917,p=0.207156230536
# allr177,nsub113,nsamp1000,55,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.22487712243,p=0.0166360606296
# allr177,nsub113,nsamp1000,56,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.287697023006,p=0.0020025155271
# allr177,nsub113,nsamp1000,56,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.321217583188,p=0.000522340996143
# allr177,nsub113,nsamp1000,57,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.291041732958,p=0.00176354054279
# allr177,nsub113,nsamp1000,57,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.288642824776,p=0.00193212934497
# allr177,nsub113,nsamp1000,58,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.409218646625,p=6.78338235108e-06
# allr177,nsub113,nsamp1000,58,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.31588878443,p=0.000653653933418
# allr177,nsub113,nsamp1000,59,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.237807140355,p=0.0112026472323
# allr177,nsub113,nsamp1000,59,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.282488689882,p=0.00243339022549
# allr177,nsub113,nsamp1000,60,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.23010111314,p=0.0142141203059
# allr177,nsub113,nsamp1000,60,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.24670951541,p=0.00843236804195
# allr177,nsub113,nsamp1000,61,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.285850375296,p=0.00214667047313
# allr177,nsub113,nsamp1000,61,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.315849637306,p=0.00065472175765
# allr177,nsub113,nsamp1000,62,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.425820605463,p=2.5757589232e-06
# allr177,nsub113,nsamp1000,62,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.293976015856,p=0.00157551595452
# allr177,nsub113,nsamp1000,63,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.257064354919,p=0.0059850591462
# allr177,nsub113,nsamp1000,63,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0981921418272,p=0.300811814934
# allr177,nsub113,nsamp1000,64,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.373502620548,p=4.60694692269e-05
# allr177,nsub113,nsamp1000,64,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.246505306458,p=0.00848842517064
# allr177,nsub113,nsamp1000,65,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.291565731334,p=0.00172853919856
# allr177,nsub113,nsamp1000,65,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.232069005352,p=0.0133847814609
# allr177,nsub113,nsamp1000,66,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.321080677551,p=0.000525386255699
# allr177,nsub113,nsamp1000,66,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.181106171801,p=0.0548976025257
# allr177,nsub113,nsamp1000,67,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.195263105712,p=0.0382103148479
# allr177,nsub113,nsamp1000,67,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.108231681451,p=0.253835832576
# allr177,nsub113,nsamp1000,68,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.161647644442,p=0.0871732806997
# allr177,nsub113,nsamp1000,68,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.118689068876,p=0.210538919526
# allr177,nsub113,nsamp1000,69,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.29149552238,p=0.00173319207554
# allr177,nsub113,nsamp1000,69,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.127439044259,p=0.178584944613
# allr177,nsub113,nsamp1000,70,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.248457477575,p=0.00796574488731
# allr177,nsub113,nsamp1000,70,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0913130800032,p=0.336104766698
# allr177,nsub113,nsamp1000,71,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.179373119466,p=0.0573006561831
# allr177,nsub113,nsamp1000,71,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.235866366816,p=0.0119029988514
# allr177,nsub113,nsamp1000,72,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.267158651813,p=0.00422913224741
# allr177,nsub113,nsamp1000,72,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.238522268025,p=0.0109538382404
# allr177,nsub113,nsamp1000,73,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.503624879852,p=1.30084709974e-08
# allr177,nsub113,nsamp1000,73,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.285731205206,p=0.00215628791782
# allr177,nsub113,nsamp1000,74,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.138455662553,p=0.143606120137
# allr177,nsub113,nsamp1000,74,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0706741241478,p=0.45696486587
# allr177,nsub113,nsamp1000,75,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.389142866156,p=2.04599841712e-05
# allr177,nsub113,nsamp1000,75,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.334046250171,p=0.000299278484789
# allr177,nsub113,nsamp1000,76,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.27912831815,p=0.00275410920349
# allr177,nsub113,nsamp1000,76,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.285175574422,p=0.00220164564102
# allr177,nsub113,nsamp1000,77,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.192601037739,p=0.0409742793255
# allr177,nsub113,nsamp1000,77,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0692300780699,p=0.466235267367
# allr177,nsub113,nsamp1000,78,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.260755188929,p=0.00527935820905
# allr177,nsub113,nsamp1000,78,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.190198208338,p=0.0436106945849
# allr177,nsub113,nsamp1000,79,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.308492827802,p=0.000886312470944
# allr177,nsub113,nsamp1000,79,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.195852820844,p=0.0376196624692
# allr177,nsub113,nsamp1000,80,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.309419077225,p=0.000853514483147
# allr177,nsub113,nsamp1000,80,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.224730451771,p=0.0167089269358
# allr177,nsub113,nsamp1000,81,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.233026985313,p=0.0129965500616
# allr177,nsub113,nsamp1000,81,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.157831940946,p=0.0949977253169
# allr177,nsub113,nsamp1000,82,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.385094379257,p=2.53442759004e-05
# allr177,nsub113,nsamp1000,82,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.202510191702,p=0.0314668485488
# allr177,nsub113,nsamp1000,83,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.361912752409,p=8.18927079156e-05
# allr177,nsub113,nsamp1000,83,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.253582715702,p=0.00672635617119
# allr177,nsub113,nsamp1000,84,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.216016547448,p=0.0215641942172
# allr177,nsub113,nsamp1000,84,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.169095409063,p=0.0733832781736
# allr177,nsub113,nsamp1000,85,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.30886833674,p=0.000872879458286
# allr177,nsub113,nsamp1000,85,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0607301116042,p=0.522834477571
# allr177,nsub113,nsamp1000,86,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.3446542332,p=0.000185343415362
# allr177,nsub113,nsamp1000,86,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.24498395016,p=0.00891649845105
# allr177,nsub113,nsamp1000,87,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.229105376811,p=0.0146505434581
# allr177,nsub113,nsamp1000,87,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.296293386554,p=0.00144009866827
# allr177,nsub113,nsamp1000,88,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.368282985231,p=5.98557838501e-05
# allr177,nsub113,nsamp1000,88,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.269728152612,p=0.00386323290396
# allr177,nsub113,nsamp1000,89,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.335636495941,p=0.000278837617947
# allr177,nsub113,nsamp1000,89,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.341451650775,p=0.000214578811283
# allr177,nsub113,nsamp1000,90,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.121128912462,p=0.20124488478
# allr177,nsub113,nsamp1000,90,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0553938125744,p=0.560065068124
# allr177,nsub113,nsamp1000,91,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.315233199458,p=0.000671748804238
# allr177,nsub113,nsamp1000,91,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.204754579887,p=0.0295945922275
# allr177,nsub113,nsamp1000,92,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.321537743591,p=0.000515282744037
# allr177,nsub113,nsamp1000,92,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.123945736222,p=0.190886364265
# allr177,nsub113,nsamp1000,93,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.345685998332,p=0.000176741461449
# allr177,nsub113,nsamp1000,93,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00314391927103,p=0.973635664411
# allr177,nsub113,nsamp1000,94,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.240085748586,p=0.0104266768849
# allr177,nsub113,nsamp1000,94,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.293883026985,p=0.00158118359591
# allr177,nsub113,nsamp1000,95,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.211540819472,p=0.0244981482322
# allr177,nsub113,nsamp1000,95,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.252124718056,p=0.00706023265493
# allr177,nsub113,nsamp1000,96,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.405286908098,p=8.46845378377e-06
# allr177,nsub113,nsamp1000,96,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.230397596904,p=0.0140863793798
# allr177,nsub113,nsamp1000,97,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.277166494831,p=0.00295849688242
# allr177,nsub113,nsamp1000,97,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.232517377996,p=0.0132018328091
# allr177,nsub113,nsamp1000,98,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.334980231225,p=0.000287111545042
# allr177,nsub113,nsamp1000,98,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.152034214209,p=0.107936816074
# allr177,nsub113,nsamp1000,99,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.164093750318,p=0.0824332808527
# allr177,nsub113,nsamp1000,99,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.211674955991,p=0.0244054954717
# allr177,nsub113,nsamp1000,100,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.272815473144,p=0.00346128057023
# allr177,nsub113,nsamp1000,100,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.150262721794,p=0.11215339186

# %% [markdown]
# ### r227 recon

# %%
# Generate random samples from r227 subjects
newdf       = df[df['Subject'].isin([int(s) for s in subjects])]  
idx_smpl    = np.where(np.ravel(newdf['fMRI_3T_ReconVrs'].isin(['r227'])))[0]
print "{} subjects with r227 recon".format(idx_smpl.shape[0])
nRep = 1000
sampleFile = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_r227.txt'.format(nSubPerSample,nRep))
if not op.isfile(sampleFile) or config.overwrite:
    samples = np.vstack([random.sample(idx_smpl,nSubPerSample) for i in range(nRep)])
    np.savetxt(sampleFile, samples)
else:
    samples = np.loadtxt(sampleFile,dtype=np.int16)
    
# do work    
outDir_ = op.join(config.DATADIR,'Results','samples_nsub{}_nsamp{}_r227'.format(nSubPerSample,nRep))
if not op.isdir(outDir_):
    mkdir(outDir_)
for iSample in range(500):#nRep):
    outDir = op.join(outDir_,'{}'.format(iSample+1))
    if not op.isdir(outDir):
        mkdir(outDir)
    #----------------------
    # prepare
    #----------------------
    config.queue        = True
    config.sgeopts      = '-l mem_free=25G -pe smp 6' 
    config.overwrite    = False
    config.fmriFile_dn  = ''
    idx_smpl      = samples[iSample,:]
    # reorder indices!
    idx_smpl      = np.sort(idx_smpl)
    smpl_subjects = [subject for (i,subject) in enumerate(subjects) if i in idx_smpl]
    smpl_score    = score[idx_smpl]
    smpl_motscore = np.mean(RelRMSMean[idx_smpl,:], axis=1)
    motFile = op.join(outDir,'RMS_{}.txt'.format(session))
    np.savetxt(motFile, smpl_motscore)
    fcMatFile =  op.join(outDir,'fcMats_{}_{}_{}_{}.mat'.format(
        session,config.pipelineName, config.parcellationName, config.release))
    overwrite = False
    if not op.isfile(fcMatFile) or overwrite:
        fcMats_dn = np.zeros((config.nParcels,config.nParcels,len(smpl_subjects),len(fmriRuns)),dtype=np.float32)
        iSub= 0
        for config.subject in smpl_subjects:
            iRun = 0
            for config.fmriRun in fmriRuns:
                # set the global variable config
                runPipelinePar(launchSubproc=False)
                #print 'Found denoised data: {}'.format(config.fmriFile_dn)
                tsDir = op.join(buildpath(),config.parcellationName,config.fmriRun+config.ext)
                rstring = get_rcode(config.fmriFile_dn)
                fcFile_dn = op.join(tsDir,'allParcels_{}_Pearson.txt'.format(rstring))
                fcMats_dn[:,:,iSub,iRun] = np.genfromtxt(fcFile_dn,delimiter=",")
                iRun = iRun+1
            iSub = iSub + 1
        fcMats_dn = np.squeeze(np.mean(np.arctanh(fcMats_dn),3))
        results = {}
        results['fcMats']        = fcMats_dn
        results['subjects']      = smpl_subjects
        results[config.outScore] = np.asarray(smpl_score)
        sio.savemat(fcMatFile, results)
    fcMats_dn = sio.loadmat(fcMatFile)['fcMats']
    #----------------------
    # predict!
    #----------------------
    idcode           = session
    predict          = 'IQ'
    config.queue     = True
    launchSubproc    = False
    config.sgeopts   = '-l mem_free=2G' 
    config.overwrite = False
    newdf            = df[df['Subject'].isin([int(s) for s in smpl_subjects])]
    # run the IQ prediction for each subject
    for model in ['IQ']:
        for config.outScore in ['PMAT24_A_CR']: #,'NEOFAC_A','NEOFAC_O','NEOFAC_C','NEOFAC_N','NEOFAC_E'
            for regression in ['Finn']:#,'lasso', 'svm', 'elnet'
                resFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}.mat'.format(
                    model,config.outScore,config.pipelineName,config.parcellationName, session, regression,
                    config.release))
                if not op.isfile(resFile) or config.overwrite:
                    runPredictionPar(fcMatFile,thresh=0.01, model=model,predict=predict, motFile='',idcode=idcode, 
                                     regression=regression, outDir=outDir)
                    checkProgress(pause=10,verbose=False)
                    # merge cross-validation folds, save results
                    n_subs          = fcMats_dn.shape[-1]
                    predictions_pos = np.zeros([n_subs,1])
                    predictions_neg = np.zeros([n_subs,1])
                    iSub = 0
                    for subject in smpl_subjects:
                        subResFile = op.join(outDir,'{}_{}pred_{}_{}_{}_{}_{}_{}.mat'.format(
                            model,config.outScore,config.pipelineName, config.parcellationName, subject, session, regression,
                            config.release))
                        while not op.isfile(subResFile):
                            sleep(.1)
                        results = sio.loadmat(subResFile) 
                        if regression=='Finn':
                            predictions_neg[iSub] = results['pred_neg']
                            predictions_pos[iSub] = results['pred_pos']
                        else:
                            predictions_pos[iSub] = results['pred']
                        iSub = iSub + 1
                    if predict=='IQ':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(newdf[config.outScore])))
                    elif predict=='motion':
                        rho,p   = stats.pearsonr(np.ravel(predictions_pos),np.squeeze(np.ravel(RelRMSMean)))
                    if regression=='Finn':
                        results = {'pred_pos':predictions_pos, 'pred_neg':predictions_neg, 'rho_pos':rho, 'p_pos': p}
                    else:
                        results = {'pred':predictions_pos, 'rho':rho, 'p': p}
                    if regression=='Finn':
                        if predict=='IQ':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(newdf[config.outScore])))
                        elif predict=='motion':
                            rho,p   = stats.pearsonr(np.ravel(predictions_neg),np.squeeze(np.ravel(RelRMSMean)))
                        results['rho_neg'] = rho
                        results['p_neg'] = p
                    # save result
                    sio.savemat(resFile,results)

                while not op.isfile(resFile):
                    sleep(.1)
                results = sio.loadmat(resFile)

                if regression=='Finn':
                    print ('{}r227,nsub{},nsamp{},{},{},{},{},{}_pos,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_pos'][0][0],results['p_pos'][0][0])
                          )
                    print ('{}r227,nsub{},nsamp{},{},{},{},{},{}_neg,model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho_neg'][0][0],results['p_neg'][0][0])
                          )
                else:
                    print ('{}r227,nsub{},nsamp{},{},{},{},{},{},model:{},rho={},p={}'.format(
                        config.release,nSubPerSample,nRep,iSample+1,config.pipelineName,config.parcellationName,
                        config.outScore,regression,model, results['rho'][0][0],results['p'][0][0])
                          )
# Out:
# 720 subjects with r227 recon
# /hpc/home/duboisjx/software/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:54: RuntimeWarning: divide by zero encountered in arctanh
# allr227,nsub113,nsamp1000,1,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.166415563985,p=0.0781270021622
# allr227,nsub113,nsamp1000,1,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0575804306644,p=0.544657066643
# allr227,nsub113,nsamp1000,2,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.104289210528,p=0.271644220588
# allr227,nsub113,nsamp1000,2,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.198911929883,p=0.0346772934059
# allr227,nsub113,nsamp1000,3,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.132886315424,p=0.16057932374
# allr227,nsub113,nsamp1000,3,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0460522482439,p=0.628133115444
# allr227,nsub113,nsamp1000,4,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.187493029716,p=0.0467464561183
# allr227,nsub113,nsamp1000,4,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.258274873254,p=0.00574487590797
# allr227,nsub113,nsamp1000,5,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0991782425017,p=0.295959961744
# allr227,nsub113,nsamp1000,5,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.00532250310598,p=0.95538140569
# allr227,nsub113,nsamp1000,6,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0954507538479,p=0.314573277599
# allr227,nsub113,nsamp1000,6,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.125135618844,p=0.186629040358
# allr227,nsub113,nsamp1000,7,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0100196199797,p=0.916115221899
# allr227,nsub113,nsamp1000,7,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.226963390377,p=0.0156290167822
# allr227,nsub113,nsamp1000,8,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.146926144312,p=0.12044197736
# allr227,nsub113,nsamp1000,8,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.102468298945,p=0.280147703373
# allr227,nsub113,nsamp1000,9,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.16994946933,p=0.0719212616112
# allr227,nsub113,nsamp1000,9,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.110246856847,p=0.245049817638
# allr227,nsub113,nsamp1000,10,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.298691228025,p=0.00131119777257
# allr227,nsub113,nsamp1000,10,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.28298574348,p=0.00238892682966
# allr227,nsub113,nsamp1000,11,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.105372568982,p=0.26666862754
# allr227,nsub113,nsamp1000,11,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0614480448774,p=0.517923005039
# allr227,nsub113,nsamp1000,12,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0770689124108,p=0.417163280829
# allr227,nsub113,nsamp1000,12,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.132038231075,p=0.16328997686
# allr227,nsub113,nsamp1000,13,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.235154489452,p=0.0121693252195
# allr227,nsub113,nsamp1000,13,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.198324459011,p=0.0352267974679
# allr227,nsub113,nsamp1000,14,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.010059143281,p=0.915785543168
# allr227,nsub113,nsamp1000,14,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.080257976907,p=0.398092768442
# allr227,nsub113,nsamp1000,15,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.121068958961,p=0.201469667125
# allr227,nsub113,nsamp1000,15,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.214538292886,p=0.0224979485698
# allr227,nsub113,nsamp1000,16,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.177790313152,p=0.0595701323292
# allr227,nsub113,nsamp1000,16,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0780409635088,p=0.411294902014
# allr227,nsub113,nsamp1000,17,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0388222251162,p=0.683089138069
# allr227,nsub113,nsamp1000,17,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0169985032073,p=0.858172981421
# allr227,nsub113,nsamp1000,18,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.188177746149,p=0.0459355799954
# allr227,nsub113,nsamp1000,18,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0572073380672,p=0.547271297642
# allr227,nsub113,nsamp1000,19,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0504537252869,p=0.595622961725
# allr227,nsub113,nsamp1000,19,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.17618180034,p=0.0619512987741
# allr227,nsub113,nsamp1000,20,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0209243899166,p=0.825886513989
# allr227,nsub113,nsamp1000,20,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0340293008565,p=0.720479465226
# allr227,nsub113,nsamp1000,21,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.177509014142,p=0.0599810641828
# allr227,nsub113,nsamp1000,21,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.167689648744,p=0.0758418510799
# allr227,nsub113,nsamp1000,22,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.25089203534,p=0.0073538779711
# allr227,nsub113,nsamp1000,22,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0578034089621,p=0.543097602112
# allr227,nsub113,nsamp1000,23,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0639309238694,p=0.501120657056
# allr227,nsub113,nsamp1000,23,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.165991071995,p=0.0789005201037
# allr227,nsub113,nsamp1000,24,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0087660309047,p=0.926578969451
# allr227,nsub113,nsamp1000,24,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0114645172051,p=0.904072492284
# allr227,nsub113,nsamp1000,25,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.225552457183,p=0.0163040931
# allr227,nsub113,nsamp1000,25,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.133976501114,p=0.1571443189
# allr227,nsub113,nsamp1000,26,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.173801984044,p=0.0656162440664
# allr227,nsub113,nsamp1000,26,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.151349403184,p=0.109551908042
# allr227,nsub113,nsamp1000,27,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0798889256517,p=0.400272792095
# allr227,nsub113,nsamp1000,27,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.115282026111,p=0.224023880362
# allr227,nsub113,nsamp1000,28,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.233792061832,p=0.0126935876971
# allr227,nsub113,nsamp1000,28,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.119644512661,p=0.206863537212
# allr227,nsub113,nsamp1000,29,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00415927577441,p=0.965125766726
# allr227,nsub113,nsamp1000,29,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0389843806655,p=0.681836845695
# allr227,nsub113,nsamp1000,30,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0935347280976,p=0.324430108047
# allr227,nsub113,nsamp1000,30,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0279675251661,p=0.768719059526
# allr227,nsub113,nsamp1000,31,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.244068808896,p=0.00918306009072
# allr227,nsub113,nsamp1000,31,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.239469169179,p=0.0106318502189
# allr227,nsub113,nsamp1000,32,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0846135812995,p=0.372900575026
# allr227,nsub113,nsamp1000,32,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.1151910791,p=0.224392004234
# allr227,nsub113,nsamp1000,33,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0231148032519,p=0.807994406403
# allr227,nsub113,nsamp1000,33,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0664228367596,p=0.48454813159
# allr227,nsub113,nsamp1000,34,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0139601697346,p=0.88332478305
# allr227,nsub113,nsamp1000,34,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.044444663261,p=0.64019133397
# allr227,nsub113,nsamp1000,35,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.094190082657,p=0.32103660852
# allr227,nsub113,nsamp1000,35,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0663725058265,p=0.484879933694
# allr227,nsub113,nsamp1000,36,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.00459922215326,p=0.961439651859
# allr227,nsub113,nsamp1000,36,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.174582929478,p=0.0643946266933
# allr227,nsub113,nsamp1000,37,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.118144156918,p=0.212655827378
# allr227,nsub113,nsamp1000,37,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.145317102441,p=0.124604475773
# allr227,nsub113,nsamp1000,38,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.200361264014,p=0.033352435244
# allr227,nsub113,nsamp1000,38,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0354775284668,p=0.709107071454
# allr227,nsub113,nsamp1000,39,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0421937465197,p=0.657233190001
# allr227,nsub113,nsamp1000,39,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.134652834398,p=0.155041089442
# allr227,nsub113,nsamp1000,40,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.128388269651,p=0.175345129367
# allr227,nsub113,nsamp1000,40,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0690858733541,p=0.46716664616
# allr227,nsub113,nsamp1000,41,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0262546862273,p=0.782520715014
# allr227,nsub113,nsamp1000,41,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0534656316298,p=0.573822593353
# allr227,nsub113,nsamp1000,42,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0611928271716,p=0.519666280977
# allr227,nsub113,nsamp1000,42,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0719989507285,p=0.448550451452
# allr227,nsub113,nsamp1000,43,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.111228912764,p=0.240845309053
# allr227,nsub113,nsamp1000,43,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0498382249499,p=0.600123428663
# allr227,nsub113,nsamp1000,44,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.185786861512,p=0.0488187940557
# allr227,nsub113,nsamp1000,44,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.137736920181,p=0.145716961425
# allr227,nsub113,nsamp1000,45,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.192730520005,p=0.0408360773159
# allr227,nsub113,nsamp1000,45,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.144443302869,p=0.126910846452
# allr227,nsub113,nsamp1000,46,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.122628962449,p=0.195679398655
# allr227,nsub113,nsamp1000,46,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.137448563165,p=0.146570378575
# allr227,nsub113,nsamp1000,47,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.184421144948,p=0.0505319269242
# allr227,nsub113,nsamp1000,47,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.243384748409,p=0.00938687017503
# allr227,nsub113,nsamp1000,48,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.141490124558,p=0.134948681554
# allr227,nsub113,nsamp1000,48,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0911186491111,p=0.337139028387
# allr227,nsub113,nsamp1000,49,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.259389547818,p=0.00553133160333
# allr227,nsub113,nsamp1000,49,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.179077461416,p=0.0577191070868
# allr227,nsub113,nsamp1000,50,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.139294508872,p=0.141171900041
# allr227,nsub113,nsamp1000,50,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.155688195241,p=0.0996312354596
# allr227,nsub113,nsamp1000,51,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0441161603038,p=0.642667089608
# allr227,nsub113,nsamp1000,51,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.110006774916,p=0.24608536938
# allr227,nsub113,nsamp1000,52,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.17063785516,p=0.0707600612524
# allr227,nsub113,nsamp1000,52,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.202367431716,p=0.03158925419
# allr227,nsub113,nsamp1000,53,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0507684156435,p=0.59332786429
# allr227,nsub113,nsamp1000,53,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.177923117143,p=0.0593769295634
# allr227,nsub113,nsamp1000,54,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.255575960243,p=0.00629258205079
# allr227,nsub113,nsamp1000,54,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.108247552717,p=0.253765800728
# allr227,nsub113,nsamp1000,55,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0485332659682,p=0.609714947015
# allr227,nsub113,nsamp1000,55,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0709406953964,p=0.455264787575
# allr227,nsub113,nsamp1000,56,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0592742975864,p=0.532865798861
# allr227,nsub113,nsamp1000,56,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0989564284809,p=0.297046810141
# allr227,nsub113,nsamp1000,57,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0766466579067,p=0.41972757062
# allr227,nsub113,nsamp1000,57,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.120352768888,p=0.204168839261
# allr227,nsub113,nsamp1000,58,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0414268658422,p=0.663080258239
# allr227,nsub113,nsamp1000,58,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0495394731368,p=0.60231332286
# allr227,nsub113,nsamp1000,59,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.17283025422,p=0.0671625449805
# allr227,nsub113,nsamp1000,59,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.213811760539,p=0.0229694370369
# allr227,nsub113,nsamp1000,60,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.283529254468,p=0.0023411484055
# allr227,nsub113,nsamp1000,60,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0376299816239,p=0.692322815084
# allr227,nsub113,nsamp1000,61,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0183376657727,p=0.84713057846
# allr227,nsub113,nsamp1000,61,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0411956140495,p=0.664847434622
# allr227,nsub113,nsamp1000,62,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0337496188721,p=0.722682839943
# allr227,nsub113,nsamp1000,62,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.221732661833,p=0.018259971508
# allr227,nsub113,nsamp1000,63,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.36374264399,p=7.48911153611e-05
# allr227,nsub113,nsamp1000,63,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.308751237148,p=0.000877048328016
# allr227,nsub113,nsamp1000,64,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.202340914329,p=0.0316120351008
# allr227,nsub113,nsamp1000,64,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.186151858277,p=0.0483691816817
# allr227,nsub113,nsamp1000,65,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.290116160017,p=0.00182693945526
# allr227,nsub113,nsamp1000,65,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.194569611945,p=0.0389148422732
# allr227,nsub113,nsamp1000,66,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.126756298863,p=0.180942248426
# allr227,nsub113,nsamp1000,66,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0576257329972,p=0.544340053862
# allr227,nsub113,nsamp1000,67,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.220672579127,p=0.0188374543262
# allr227,nsub113,nsamp1000,67,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0840657512621,p=0.376014479487
# allr227,nsub113,nsamp1000,68,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0978441959546,p=0.302536198363
# allr227,nsub113,nsamp1000,68,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.214999249885,p=0.0222031298296
# allr227,nsub113,nsamp1000,69,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.147481576173,p=0.119030309411
# allr227,nsub113,nsamp1000,69,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.237963117279,p=0.0111479611696
# allr227,nsub113,nsamp1000,70,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.225539139396,p=0.0163105836811
# allr227,nsub113,nsamp1000,70,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.120489278463,p=0.203652371225
# allr227,nsub113,nsamp1000,71,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0545842807469,p=0.565821822387
# allr227,nsub113,nsamp1000,71,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0350298353451,p=0.712615953669
# allr227,nsub113,nsamp1000,72,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.355205575959,p=0.000113116338121
# allr227,nsub113,nsamp1000,72,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.302221809664,p=0.0011404502041
# allr227,nsub113,nsamp1000,73,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.129388684633,p=0.17197763594
# allr227,nsub113,nsamp1000,73,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.178813988236,p=0.0580941143548
# allr227,nsub113,nsamp1000,74,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0237186208329,p=0.803079149779
# allr227,nsub113,nsamp1000,74,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.147226570372,p=0.119676827474
# allr227,nsub113,nsamp1000,75,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.132085200555,p=0.163138968188
# allr227,nsub113,nsamp1000,75,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0727329645769,p=0.443926101549
# allr227,nsub113,nsamp1000,76,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0448786865231,p=0.636926379271
# allr227,nsub113,nsamp1000,76,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.035587518012,p=0.708245934298
# allr227,nsub113,nsamp1000,77,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.244516829693,p=0.00905169684496
# allr227,nsub113,nsamp1000,77,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.136935112104,p=0.148099309557
# allr227,nsub113,nsamp1000,78,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0355136422834,p=0.708824286365
# allr227,nsub113,nsamp1000,78,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.181181964657,p=0.0547944292937
# allr227,nsub113,nsamp1000,79,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.123650663182,p=0.19195294285
# allr227,nsub113,nsamp1000,79,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0219014338198,p=0.81789405051
# allr227,nsub113,nsamp1000,80,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.213003635411,p=0.0235037964081
# allr227,nsub113,nsamp1000,80,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.213501997667,p=0.0231730194926
# allr227,nsub113,nsamp1000,81,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.174800319548,p=0.0640578824712
# allr227,nsub113,nsamp1000,81,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.0898330173647,p=0.344028570297
# allr227,nsub113,nsamp1000,82,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.215405368098,p=0.0219461371121
# allr227,nsub113,nsamp1000,82,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.145205718405,p=0.124896664929
# allr227,nsub113,nsamp1000,83,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.158665552263,p=0.0932426115884
# allr227,nsub113,nsamp1000,83,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.14786270423,p=0.118069070629
# allr227,nsub113,nsamp1000,84,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.201643871796,p=0.0322158629644
# allr227,nsub113,nsamp1000,84,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.177507090286,p=0.0599838825857
# allr227,nsub113,nsamp1000,85,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.00486232177788,p=0.959235640687
# allr227,nsub113,nsamp1000,85,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.146050189053,p=0.122694502501
# allr227,nsub113,nsamp1000,86,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0632083086798,p=0.505981227438
# allr227,nsub113,nsamp1000,86,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.110259614869,p=0.244994872646
# allr227,nsub113,nsamp1000,87,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.197864563911,p=0.0356620698278
# allr227,nsub113,nsamp1000,87,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.106022265227,p=0.26371458684
# allr227,nsub113,nsamp1000,88,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0863450091036,p=0.363163046292
# allr227,nsub113,nsamp1000,88,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.272832661507,p=0.00345915200415
# allr227,nsub113,nsamp1000,89,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.0776794129847,p=0.413471954594
# allr227,nsub113,nsamp1000,89,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.132437825825,p=0.162008580068
# allr227,nsub113,nsamp1000,90,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.134535941403,p=0.15540308261
# allr227,nsub113,nsamp1000,90,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.140959879441,p=0.136432095191
# allr227,nsub113,nsamp1000,91,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.111968263415,p=0.237713155014
# allr227,nsub113,nsamp1000,91,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.0242764635666,p=0.798544955538
# allr227,nsub113,nsamp1000,92,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.278534512213,p=0.00281458815564
# allr227,nsub113,nsamp1000,92,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.273173567733,p=0.00341717705861
# allr227,nsub113,nsamp1000,93,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.08282748347,p=0.383110994724
# allr227,nsub113,nsamp1000,93,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.218087115973,p=0.0203123657338
# allr227,nsub113,nsamp1000,94,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.246992146694,p=0.00835532216226
# allr227,nsub113,nsamp1000,94,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.238750353635,p=0.0108755075135
# allr227,nsub113,nsamp1000,95,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=0.102826049912,p=0.278463115893
# allr227,nsub113,nsamp1000,95,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=0.132019290072,p=0.163350902315
# allr227,nsub113,nsamp1000,96,Finn,shen2013,PMAT24_A_CR,Finn_pos,model:IQ,rho=-0.0280262645824,p=0.768247003713
# allr227,nsub113,nsamp1000,96,Finn,shen2013,PMAT24_A_CR,Finn_neg,model:IQ,rho=-0.065860881352,p=0.488259650886
